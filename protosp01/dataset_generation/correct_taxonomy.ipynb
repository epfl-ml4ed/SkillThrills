# %% [markdown]
# # Translate the taxonomy
#
#
# The taxonomy is currently in german and we would like to use the same one for the pipeline.

# %%
import pandas as pd
import os
import sys

# %%
taxonomy_de = pd.read_csv("../../data/taxonomy/taxonomy_V4.csv")
taxonomy_de.sample(5)
# Out:
#      unique_id ElementID Dimension FE               Type Level 1  \
# 329         40       NaN    Kompetenz              Fachkompetenz
# 371         96     7.2.4    Kompetenz  Sozial- & Selbstkompetenz
# 310         50       NaN    Kompetenz              Fachkompetenz
# 106         88       NaN    Kompetenz              Fachkompetenz
# 27          63   2.1.8.1   Deskriptor          Kompetenzelemente
#
#                      Type Level 1 E                        Type Level 1 F  \
# 329         Professional Competency            Compétence Professionnelle
# 371  Social & Personal Competencies  Compétences Sociales et Personnelles
# 310         Professional Competency            Compétence Professionnelle
# 106         Professional Competency            Compétence Professionnelle
# 27      General Skills & Attitudes                 Éléments de Compétence
#
#               Type Level 2         Type Level 2 E  \
# 329      Gebäudeautomation    Building Automation
# 371     Selbstorganisation      Self-Organisation
# 310  ICT Service Operation  ICT Service Operation
# 106      Projektmanagement     Project Management
# 27    Kognitive Fertigkeit        Cognitive Skill
#
#                   Type Level 2 F       Type Level 3  ... Unnamed: 34  \
# 329  Automatisation de Bâtiments                NaN  ...         NaN
# 371            Auto-Organisation  Ressourcenakquise  ...         NaN
# 310        ICT Service Operation                NaN  ...         NaN
# 106            Gestion de Projet                NaN  ...         NaN
# 27            Aptitude Cognitive     Aufmerksamkeit  ...         NaN
#
#     Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40  \
# 329         NaN         NaN         NaN         NaN         NaN         NaN
# 371         NaN         NaN         NaN         NaN         NaN         NaN
# 310         NaN         NaN         NaN         NaN         NaN         NaN
# 106         NaN         NaN         NaN         NaN         NaN         NaN
# 27          NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 41 Unnamed: 42 Unnamed: 43
# 329         NaN         NaN         NaN
# 371         NaN         NaN         NaN
# 310         NaN         NaN         NaN
# 106         NaN         NaN         NaN
# 27          NaN         NaN         NaN
#
# [5 rows x 45 columns]

# %%
taxonomy_de.columns
# Out:
# Index(['unique_id', 'ElementID', 'Dimension FE', 'Type Level 1',
#        'Type Level 1 E', 'Type Level 1 F', 'Type Level 2', 'Type Level 2 E',
#        'Type Level 2 F', 'Type Level 3', 'Type Level 4', 'Example',
#        'Definition', 'Industry', 'Bildungsweg 1', 'Bildungsweg 2',
#        'Bildungsweg 3', 'Bildungsweg 4', 'Bildungsweg 5', 'Bildungsweg 6',
#        'Bildungsweg 7', 'Bildungsweg 8', 'Bildungsweg 9', 'Bildungsweg 10',
#        'Frontend', 'Source', 'Connection SwissICT Model', 'Internal Reference',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42',
#        'Unnamed: 43'],
#       dtype='object')

# %%
ESCO_DIR = "../../../esco/"
files = os.listdir(ESCO_DIR)
display(files)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /mnt/u14157_ic_nlp_001_files_nfs/nlpdata1/home/magron/SkillThrills/protosp01/dataset_generation/correct_taxonomy.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2Biccluster130.iccluster.epfl.ch/mnt/u14157_ic_nlp_001_files_nfs/nlpdata1/home/magron/SkillThrills/protosp01/dataset_generation/correct_taxonomy.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> ESCO_DIR = "../../../esco/"
# ----> <a href='vscode-notebook-cell://ssh-remote%2Biccluster130.iccluster.epfl.ch/mnt/u14157_ic_nlp_001_files_nfs/nlpdata1/home/magron/SkillThrills/protosp01/dataset_generation/correct_taxonomy.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> files = os.listdir(ESCO_DIR)
#       <a href='vscode-notebook-cell://ssh-remote%2Biccluster130.iccluster.epfl.ch/mnt/u14157_ic_nlp_001_files_nfs/nlpdata1/home/magron/SkillThrills/protosp01/dataset_generation/correct_taxonomy.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> display(files)
#
# NameError: name 'os' is not defined

# %%
len(taxonomy_de.index)
# Out:
# 373

# %%
files[:-2]
# Out:
# ['broaderRelationsOccPillar_en.csv',
#  'broaderRelationsSkillPillar_en.csv',
#  'conceptSchemes_en.csv',
#  'digCompSkillsCollection_en.csv',
#  'digitalSkillsCollection_en.csv',
#  'greenSkillsCollection_en.csv',
#  'ISCOGroups_en.csv',
#  'languageSkillsCollection_en.csv',
#  'occupationSkillRelations_en.csv',
#  'occupations_en.csv',
#  'researchOccupationsCollection_en.csv',
#  'researchSkillsCollection_en.csv',
#  'skillGroups_en.csv',
#  'skillsHierarchy_en.csv',
#  'skillSkillRelations_en.csv',
#  'skills_en.csv',
#  'transversalSkillsCollection_en.csv',
#  'tech_managment_taxonomy.csv',
#  'tech_managment_taxonomy_narrow.csv']

# %%
dfs = []
for file in files[:-2]:
    df = pd.read_csv(ESCO_DIR + file)
    dfs.append(df)
    print(file)
    display(df.sample(5))
# Out:
# broaderRelationsOccPillar_en.csv
#      conceptType                                         conceptUri  \
# 2600  Occupation  http://data.europa.eu/esco/occupation/2dcb5dad...
# 1602  Occupation  http://data.europa.eu/esco/occupation/89a6d6e5...
# 2488  Occupation  http://data.europa.eu/esco/occupation/16cb1f72...
# 1049  Occupation  http://data.europa.eu/esco/occupation/3ce4691e...
# 440    ISCOGroup              http://data.europa.eu/esco/isco/C7212
#
#      broaderType                                         broaderUri
# 2600  Occupation  http://data.europa.eu/esco/occupation/c2a29b8d...
# 1602   ISCOGroup              http://data.europa.eu/esco/isco/C7126
# 2488  Occupation  http://data.europa.eu/esco/occupation/579254cf...
# 1049   ISCOGroup              http://data.europa.eu/esco/isco/C1330
# 440    ISCOGroup               http://data.europa.eu/esco/isco/C721
# broaderRelationsSkillPillar_en.csv
#                     conceptType  \
# 4699   KnowledgeSkillCompetence
# 5219   KnowledgeSkillCompetence
# 2734   KnowledgeSkillCompetence
# 19448  KnowledgeSkillCompetence
# 20589  KnowledgeSkillCompetence
#
#                                               conceptUri  \
# 4699   http://data.europa.eu/esco/skill/4d51a8b4-f051...
# 5219   http://data.europa.eu/esco/skill/56a7f561-1d55...
# 2734   http://data.europa.eu/esco/skill/27ddcef9-8522...
# 19448  http://data.europa.eu/esco/skill/d1041406-2c24...
# 20589  http://data.europa.eu/esco/skill/fd9694e7-5e7a...
#
#                     broaderType  \
# 4699                 SkillGroup
# 5219                 SkillGroup
# 2734                 SkillGroup
# 19448  KnowledgeSkillCompetence
# 20589  KnowledgeSkillCompetence
#
#                                               broaderUri
# 4699             http://data.europa.eu/esco/isced-f/0533
# 5219             http://data.europa.eu/esco/isced-f/0613
# 2734   http://data.europa.eu/esco/skill/1d4be2e3-ac64...
# 19448  http://data.europa.eu/esco/skill/7dd94ad3-13d6...
# 20589  http://data.europa.eu/esco/skill/609a8ac1-9d29...
# conceptSchemes_en.csv
#       conceptType                                   conceptSchemeUri  \
# 15  ConceptScheme  http://data.europa.eu/esco/concept-scheme/skil...
# 10  ConceptScheme  http://data.europa.eu/esco/concept-scheme/regu...
# 13  ConceptScheme  http://data.europa.eu/esco/concept-scheme/skil...
# 2   ConceptScheme  http://data.europa.eu/esco/concept-scheme/digcomp
# 1   ConceptScheme  http://data.europa.eu/esco/concept-scheme/8ae4...
#
#                                   preferredLabel  \
# 15  ESCO Skill Pillar concept reusability levels
# 10                         Regulated Professions
# 13        ESCO Skill Pillar concept (sub-) Types
# 2                                        DigComp
# 1                           Research occupations
#
#                                            title    status description  \
# 15  ESCO Skill Pillar concept reusability levels       NaN         NaN
# 10                                           NaN       NaN         NaN
# 13        ESCO Skill Pillar concept (sub-) Types       NaN         NaN
# 2                                            NaN  released         NaN
# 1                                            NaN  released         NaN
#
#                                         hasTopConcept
# 15  http://data.europa.eu/esco/skill-reuse-level/t...
# 10  http://data.europa.eu/esco/regulated-professio...
# 13  http://data.europa.eu/esco/skill-type/skill,\n...
# 2   http://data.europa.eu/esco/skill/7e5147d1-60b1...
# 1   http://data.europa.eu/esco/occupation/a9c7a04d...
# digCompSkillsCollection_en.csv
#                  conceptType  \
# 8   KnowledgeSkillCompetence
# 9   KnowledgeSkillCompetence
# 20  KnowledgeSkillCompetence
# 11  KnowledgeSkillCompetence
# 5   KnowledgeSkillCompetence
#
#                                            conceptUri  \
# 8   http://data.europa.eu/esco/skill/40001d93-8937...
# 9   http://data.europa.eu/esco/skill/426ceaba-6867...
# 20  http://data.europa.eu/esco/skill/bc0b0b5d-f6be...
# 11  http://data.europa.eu/esco/skill/4d97e3c3-f335...
# 5   http://data.europa.eu/esco/skill/238343b1-7b51...
#
#                                   preferredLabel    status         skillType  \
# 8             share through digital technologies  released  skill/competence
# 9                                     ICT safety  released               NaN
# 20                       manage digital identity  released  skill/competence
# 11  manage data, information and digital content  released  skill/competence
# 5               identify digital competence gaps  released  skill/competence
#
#       reuseLevel                                          altLabels  \
# 8   cross-sector                 share through digital technologies
# 9            NaN  ICT protection | information and communication...
# 20  cross-sector  protecting privacy and identity on the Interne...
# 11  cross-sector       manage data, information and digital content
# 5   cross-sector                   identify digital competence gaps
#
#                                           description  \
# 8   Share data, information and digital content wi...
# 9   Personal protection, data protection, digital ...
# 20  Create and manage one or multiple digital iden...
# 11  Organise, store and retrieve data, information...
# 5   Understand where one’s own digital competence ...
#
#                                     broaderConceptUri  \
# 8   http://data.europa.eu/esco/skill/98fb499f-9155...
# 9   http://data.europa.eu/esco/skill/185c56ee-098f...
# 20  http://data.europa.eu/esco/skill/3399045f-8078...
# 11  http://data.europa.eu/esco/skill/32c017fd-28ab...
# 5   http://data.europa.eu/esco/skill/7e5147d1-60b1...
#
#                                      broaderConceptPT
# 8   using digital tools for collaboration and prod...
# 9                              protecting ict devices
# 20  working with digital devices and applications ...
# 11     managing information | digital data processing
# 5   problem-solving with digital tools | monitorin...
# digitalSkillsCollection_en.csv
#                   conceptType  \
# 435  KnowledgeSkillCompetence
# 187  KnowledgeSkillCompetence
# 755  KnowledgeSkillCompetence
# 544  KnowledgeSkillCompetence
# 134  KnowledgeSkillCompetence
#
#                                             conceptUri  \
# 435  http://data.europa.eu/esco/skill/5edaf4c4-6747...
# 187  http://data.europa.eu/esco/skill/28b7d7fb-0483...
# 755  http://data.europa.eu/esco/skill/a3ce2bf7-5562...
# 544  http://data.europa.eu/esco/skill/755a5df2-863e...
# 134  http://data.europa.eu/esco/skill/1c7fbce8-741b...
#
#                                preferredLabel    status         skillType  \
# 435          control production flow remotely  released  skill/competence
# 187             operate voice picking systems  released  skill/competence
# 755         ICT problem management techniques  released         knowledge
# 544  design brand's online communication plan  released  skill/competence
# 134     Shiva (digital game creation systems)  released         knowledge
#
#               reuseLevel                                          altLabels  \
# 435         cross-sector  controlling production flow remotely | operati...
# 187      sector-specific  perform warehouse operations using voice picki...
# 755      sector-specific                  ICT problem management techniques
# 544  occupation-specific  designing a brand's online communication plan ...
# 134      sector-specific                                              Shiva
#
#                                            description  \
# 435  Control remotely the flow of production from t...
# 187  Operate voice pick systems applying various pi...
# 755  The techniques related to identifying the solu...
# 544  Design of content and presentation of the bran...
# 134  The cross-platform game engine which is a soft...
#
#                                      broaderConceptUri  \
# 435  http://data.europa.eu/esco/skill/494b8057-daf5...
# 187  http://data.europa.eu/esco/skill/485b2e3b-f883...
# 755            http://data.europa.eu/esco/isced-f/0611
# 544  http://data.europa.eu/esco/skill/37272760-957a...
# 134  http://data.europa.eu/esco/skill/966f2fd3-3de6...
#
#                                       broaderConceptPT
# 435  using digital tools to control machinery | con...
# 187                      sorting materials or products
# 755                                       computer use
# 544  developing financial, business or marketing plans
# 134  digital game creation systems | audio-visual t...
# greenSkillsCollection_en.csv
#                   conceptType  \
# 95   KnowledgeSkillCompetence
# 351  KnowledgeSkillCompetence
# 128  KnowledgeSkillCompetence
# 32   KnowledgeSkillCompetence
# 16   KnowledgeSkillCompetence
#
#                                             conceptUri  \
# 95   http://data.europa.eu/esco/skill/2879e8f6-037a...
# 351  http://data.europa.eu/esco/skill/9263f0d8-7266...
# 128  http://data.europa.eu/esco/skill/311832d1-1167...
# 32   http://data.europa.eu/esco/skill/0d75a128-bd88...
# 16   http://data.europa.eu/esco/skill/0625e737-2b29...
#
#                           preferredLabel    status         skillType  \
# 95         food waste monitoring systems  released         knowledge
# 351  promote sustainable interior design  released  skill/competence
# 128       describe electric drive system  released  skill/competence
# 32        adopt ways to reduce pollution  released  skill/competence
# 16         test paper production samples  released  skill/competence
#
#           reuseLevel                                          altLabels  \
# 95   sector-specific                                                NaN
# 351     cross-sector  promote sustainable interior design | endorse ...
# 128  sector-specific  describe electric vehicle system components | ...
# 32       transversal  prefer public to private transport | use publi...
# 16   sector-specific  testing paper production samples | measure pap...
#
#                                            description  \
# 95   The characteristics, benefits and ways of usin...
# 351  Develop an environmental friendly interior des...
# 128  Describe the complete electric drive system wi...
# 32   Apply measures to reduce air, noise, light, wa...
# 16   Acquire test samples at various stages of the ...
#
#                                      broaderConceptUri  \
# 95             http://data.europa.eu/esco/isced-f/0612
# 351  http://data.europa.eu/esco/skill/469e19ed-a0bd...
# 128  http://data.europa.eu/esco/skill/d54970ba-d9f2...
# 32   http://data.europa.eu/esco/skill/80cf002a-6586...
# 16   http://data.europa.eu/esco/skill/cd4b9e72-a18d...
#
#                                       broaderConceptPT
# 95      database and network design and administration
# 351  promote sustainability | designing structures ...
# 128    providing information to the public and clients
# 32       applying environmental skills and competences
# 16   prepare samples for testing | testing and anal...
# ISCOGroups_en.csv
#     conceptType                             conceptUri  code  \
# 319   ISCOGroup  http://data.europa.eu/esco/isco/C4311  4311
# 20    ISCOGroup   http://data.europa.eu/esco/isco/C121   121
# 496   ISCOGroup  http://data.europa.eu/esco/isco/C7523  7523
# 520   ISCOGroup   http://data.europa.eu/esco/isco/C813   813
# 241   ISCOGroup  http://data.europa.eu/esco/isco/C3311  3311
#
#                                         preferredLabel    status  altLabels  \
# 319                  Accounting and bookkeeping clerks  released        NaN
# 20       Business services and administration managers  released        NaN
# 496     Woodworking-machine tool setters and operators  released        NaN
# 520  Chemical and photographic products plant and m...  released        NaN
# 241         Securities and finance dealers and brokers  released        NaN
#
#                                               inScheme  \
# 319  http://data.europa.eu/esco/concept-scheme/occu...
# 20   http://data.europa.eu/esco/concept-scheme/occu...
# 496  http://data.europa.eu/esco/concept-scheme/isco...
# 520  http://data.europa.eu/esco/concept-scheme/isco...
# 241  http://data.europa.eu/esco/concept-scheme/isco...
#
#                                            description
# 319  Accounting and bookkeeping clerks compute, cla...
# 20   Business services and administration managers ...
# 496  Woodworking machine tool setters and operators...
# 520  Chemical and photographic products plant and m...
# 241  Securities and finance dealers and brokers buy...
# languageSkillsCollection_en.csv
#                   conceptType  \
# 285  KnowledgeSkillCompetence
# 265  KnowledgeSkillCompetence
# 201  KnowledgeSkillCompetence
# 172  KnowledgeSkillCompetence
# 289  KnowledgeSkillCompetence
#
#                                             conceptUri         skillType  \
# 285  http://data.europa.eu/esco/skill/d54d7c00-87c4...         knowledge
# 265  http://data.europa.eu/esco/skill/c8c283af-3d77...  skill/competence
# 201  http://data.europa.eu/esco/skill/99933cd7-7868...  skill/competence
# 172  http://data.europa.eu/esco/skill/7ee20fe2-facd...  skill/competence
# 289  http://data.europa.eu/esco/skill/d6dbc6ea-9bb6...  skill/competence
#
#       reuseLevel                   preferredLabel    status  \
# 285  transversal                          Walloon  released
# 265  transversal       understand spoken Romanian  released
# 201  transversal     understand spoken Lithuanian  released
# 172  transversal       understand written English  released
# 289  transversal  interact verbally in Vietnamese  released
#
#                                              altLabels  \
# 285  ability to comprehend spoken and written Wallo...
# 265  understanding spoken Romanian | understand spo...
# 201  understanding spoken Lithuanian | understand L...
# 172  read English | understanding written English |...
# 289  be fluent in Vietnamese | interacting verbally...
#
#                                        description  \
# 285                          The Walloon language.
# 265          Comprehend orally expressed Romanian.
# 201        Comprehend orally expressed Lithuanian.
# 172  Read and comprehend written texts in English.
# 289              Communicate orally in Vietnamese.
#
#                                      broaderConceptUri  \
# 285  http://data.europa.eu/esco/skill/9adca63b-9c75...
# 265  http://data.europa.eu/esco/skill/4b9f1ae5-0ee6...
# 201  http://data.europa.eu/esco/skill/b3950b87-a980...
# 172  http://data.europa.eu/esco/skill/6d3edede-8951...
# 289  http://data.europa.eu/esco/skill/bf60009d-8afb...
#
#                     broaderConceptPT
# 285  mastering languages | languages
# 265                         Romanian
# 201                       Lithuanian
# 172                          English
# 289                       Vietnamese
# occupationSkillRelations_en.csv
#                                             occupationUri relationType  \
# 60205   http://data.europa.eu/esco/occupation/77bfd6e7...    essential
# 87282   http://data.europa.eu/esco/occupation/afbe50b0...     optional
# 86736   http://data.europa.eu/esco/occupation/ae3f1edd...     optional
# 64422   http://data.europa.eu/esco/occupation/80d880ec...    essential
# 121267  http://data.europa.eu/esco/occupation/fae51298...    essential
#
#                skillType                                           skillUri
# 60205   skill/competence  http://data.europa.eu/esco/skill/7a6b4549-cd3e...
# 87282   skill/competence  http://data.europa.eu/esco/skill/797a4416-0b8d...
# 86736   skill/competence  http://data.europa.eu/esco/skill/2879a6f9-868b...
# 64422   skill/competence  http://data.europa.eu/esco/skill/bb4f3174-8d64...
# 121267  skill/competence  http://data.europa.eu/esco/skill/c5bc42be-4970...
# occupations_en.csv
#      conceptType                                         conceptUri  \
# 192   Occupation  http://data.europa.eu/esco/occupation/0ee67d5e...
# 2789  Occupation  http://data.europa.eu/esco/occupation/eb9479c6...
# 2558  Occupation  http://data.europa.eu/esco/occupation/d4ccb6d4...
# 1815  Occupation  http://data.europa.eu/esco/occupation/95a89206...
# 860   Occupation  http://data.europa.eu/esco/occupation/46db7e2e...
#
#       iscoGroup                 preferredLabel  \
# 192        1111             secretary of state
# 2789       1321  industrial production manager
# 2558       5411            mine rescue officer
# 1815       7534                    upholsterer
# 860        2355            photography teacher
#
#                                               altLabels hiddenLabels  \
# 192   state secretary\nsenior minister\nunder secret...          NaN
# 2789  area production manager\nproduction manufactur...          NaN
# 2558  mining rescue officer\nmine emergency officer\...          NaN
# 1815  craft upholsterer\ncraftswoman upholsterer\nse...          NaN
# 860   teacher of photography\nmedia arts teacher\nph...          NaN
#
#         status              modifiedDate  \
# 192   released   2022-01-13T10:46:54.16Z
# 2789  released      2017-01-17T11:46:16Z
# 2558  released      2016-07-05T17:11:00Z
# 1815  released  2021-12-08T19:44:09.619Z
# 860   released  2020-08-10T07:43:23.685Z
#
#                                 regulatedProfessionNote scopeNote definition  \
# 192   http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 2789  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 2558  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 1815  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 860   http://data.europa.eu/esco/regulated-professio...       NaN        NaN
#
#                                                inScheme  \
# 192   http://data.europa.eu/esco/concept-scheme/memb...
# 2789  http://data.europa.eu/esco/concept-scheme/memb...
# 2558  http://data.europa.eu/esco/concept-scheme/memb...
# 1815  http://data.europa.eu/esco/concept-scheme/occu...
# 860   http://data.europa.eu/esco/concept-scheme/memb...
#
#                                             description      code
# 192   Secretaries of state assist heads of governmen...    1111.6
# 2789  Industrial production managers oversee the ope...  1321.2.1
# 2558  Mine rescue officers coordinate mine rescue op...  5411.1.3
# 1815  Upholsterers provide objects such as furniture...    7534.3
# 860   Photography teachers instruct students in the ...    2355.5
# researchOccupationsCollection_en.csv
#     conceptType                                         conceptUri  \
# 19   Occupation  http://data.europa.eu/esco/occupation/25829508...
# 118  Occupation  http://data.europa.eu/esco/occupation/f3e23761...
# 28   Occupation  http://data.europa.eu/esco/occupation/3f7b7ce5...
# 97   Occupation  http://data.europa.eu/esco/occupation/bc659adc...
# 89   Occupation  http://data.europa.eu/esco/occupation/b2cede50...
#
#            preferredLabel    status  \
# 19           physiologist  released
# 118  biochemical engineer  released
# 28           toxicologist  released
# 97            cosmologist  released
# 89        energy engineer  released
#
#                                              altLabels  \
# 19   anatomist | anatomy researcher | physiology sc...
# 118  biochemical engineering specialist | biochemic...
# 28   toxicology studies researcher | toxicology sci...
# 97   evolutionary cosmologist | cosmology research ...
# 89   energy technology engineering consultant | ene...
#
#                                            description  \
# 19   Physiologists study and exert research on the ...
# 118  Biochemical engineers research on the field of...
# 28   Toxicologists study the effects that chemical ...
# 97   Cosmologists focus on the study of the univers...
# 89   Energy engineers design new, efficient and cle...
#
#                                      broaderConceptUri  \
# 19   http://data.europa.eu/esco/occupation/eee68e13...
# 118  http://data.europa.eu/esco/occupation/ec21ce88...
# 28   http://data.europa.eu/esco/occupation/eee68e13...
# 97               http://data.europa.eu/esco/isco/C2111
# 89               http://data.europa.eu/esco/isco/C2149
#
#                                       broaderConceptPT
# 19                                           biologist
# 118                                  chemical engineer
# 28                                           biologist
# 97                          Physicists and astronomers
# 89   Engineering professionals not elsewhere classi...
# researchSkillsCollection_en.csv
#                  conceptType  \
# 8   KnowledgeSkillCompetence
# 2   KnowledgeSkillCompetence
# 17  KnowledgeSkillCompetence
# 28  KnowledgeSkillCompetence
# 23  KnowledgeSkillCompetence
#
#                                            conceptUri  \
# 8   http://data.europa.eu/esco/skill/4707da90-9cfc...
# 2   http://data.europa.eu/esco/skill/20a8fe89-d4eb...
# 17  http://data.europa.eu/esco/skill/7a147904-22b3...
# 28  http://data.europa.eu/esco/skill/b363bb5f-2c79...
# 23  http://data.europa.eu/esco/skill/9a58cd26-58eb...
#
#                                        preferredLabel    status  \
# 8                                  think analytically  released
# 2   interact professionally in research and profes...  released
# 17                                   cope with stress  released
# 28                             apply blended learning  released
# 23                                   think abstractly  released
#
#            skillType    reuseLevel  \
# 8   skill/competence   transversal
# 2   skill/competence  cross-sector
# 17  skill/competence   transversal
# 28  skill/competence  cross-sector
# 23  skill/competence  cross-sector
#
#                                             altLabels  \
# 8   think in an analytical way | develop an analyt...
# 2                                                 NaN
# 17  cope with pressure | deal with pressure | perf...
# 28                                                NaN
# 23                                                NaN
#
#                                           description  \
# 8   Produce thoughts using logic and reasoning in ...
# 2   Show consideration to others as well as colleg...
# 17  Handle challenges, disruption and change and r...
# 28  Be familiar with blended learning tools by com...
# 23  Demonstrate the ability to use concepts in ord...
#
#                                     broaderConceptUri  \
# 8   http://data.europa.eu/esco/skill/fff1d675-c36a...
# 2   http://data.europa.eu/esco/skill/91b0b918-942e...
# 17  http://data.europa.eu/esco/skill/2b2c3254-7f6c...
# 28  http://data.europa.eu/esco/skill/caede8f1-6658...
# 23  http://data.europa.eu/esco/skill/ab877a24-335d...
#
#                                broaderConceptPT
# 8    processing information, ideas and concepts
# 2                           working with others
# 17              maintaining a positive attitude
# 28                        teaching and training
# 23  communication, collaboration and creativity
# skillGroups_en.csv
#     conceptType                                         conceptUri  \
# 114  SkillGroup             http://data.europa.eu/esco/isced-f/061
# 204  SkillGroup            http://data.europa.eu/esco/isced-f/1022
# 84   SkillGroup             http://data.europa.eu/esco/isced-f/049
# 552  SkillGroup  http://data.europa.eu/esco/skill/cbe1b24e-00f3...
# 400  SkillGroup  http://data.europa.eu/esco/skill/6f89dcbe-4315...
#
#                                         preferredLabel           altLabels  \
# 114  information and communication technologies (icts)                 NaN
# 204                     occupational health and safety                 NaN
# 84   business, administration and law not elsewhere...                 NaN
# 552                          identifying opportunities                 NaN
# 400               developing objectives and strategies  strategic planning
#
#     hiddenLabels    status              modifiedDate  \
# 114          NaN  released  2021-08-30T14:53:01.939Z
# 204          NaN  released                       NaN
# 84           NaN  released  2022-06-07T12:45:17.113Z
# 552          NaN  released  2021-12-17T13:01:48.803Z
# 400          NaN  released                       NaN
#
#                                              scopeNote  \
# 114                                                NaN
# 204                                                NaN
# 84                                                 NaN
# 552  Examples:\n- identify market niches\n- identif...
# 400                                                NaN
#
#                                               inScheme  \
# 114  http://data.europa.eu/esco/concept-scheme/skil...
# 204  http://data.europa.eu/esco/concept-scheme/skil...
# 84   http://data.europa.eu/esco/concept-scheme/skil...
# 552  http://data.europa.eu/esco/concept-scheme/skil...
# 400  http://data.europa.eu/esco/concept-scheme/skil...
#
#                                            description    code
# 114                                                NaN     NaN
# 204  Occupational health and safety is the study of...     NaN
# 84                                                 NaN     NaN
# 552  Identifying business or organizational opportu...  S4.1.1
# 400  Envisioning a future state and developing stra...    S4.1
# skillsHierarchy_en.csv
#                                            Level 0 URI  \
# 527  http://data.europa.eu/esco/skill/c46fcb45-5c14...
# 258  http://data.europa.eu/esco/skill/335228d2-297d...
# 631  http://data.europa.eu/esco/skill/c46fcb45-5c14...
# 6    http://data.europa.eu/esco/skill/04a13491-b58c...
# 120  http://data.europa.eu/esco/skill/335228d2-297d...
#
#                  Level 0 preferred term  \
# 527                           knowledge
# 258                              skills
# 631                           knowledge
# 6    transversal skills and competences
# 120                              skills
#
#                                            Level 1 URI  \
# 527              http://data.europa.eu/esco/isced-f/05
# 258  http://data.europa.eu/esco/skill/9b8bb484-dcba...
# 631              http://data.europa.eu/esco/isced-f/10
# 6    http://data.europa.eu/esco/skill/021a23e1-907e...
# 120  http://data.europa.eu/esco/skill/0a2d70ee-d435...
#
#                                Level 1 preferred term  \
# 527      natural sciences, mathematics and statistics
# 258  working with machinery and specialised equipment
# 631                                          services
# 6              self-management skills and competences
# 120                                information skills
#
#                                            Level 2 URI  \
# 527             http://data.europa.eu/esco/isced-f/053
# 258  http://data.europa.eu/esco/skill/2198d7a0-6eca...
# 631             http://data.europa.eu/esco/isced-f/102
# 6    http://data.europa.eu/esco/skill/2b2c3254-7f6c...
# 120  http://data.europa.eu/esco/skill/325a3d29-a235...
#
#                                 Level 2 preferred term  \
# 527                                  physical sciences
# 258  operating machinery for the extraction and pro...
# 631           hygiene and occupational health services
# 6                      maintaining a positive attitude
# 120              documenting and recording information
#
#                                            Level 3 URI  \
# 527            http://data.europa.eu/esco/isced-f/0530
# 258  http://data.europa.eu/esco/skill/8bf9699c-f964...
# 631            http://data.europa.eu/esco/isced-f/1022
# 6                                                  NaN
# 120  http://data.europa.eu/esco/skill/06fdd94c-292d...
#
#                                 Level 3 preferred term  \
# 527              physical sciences not further defined
# 258  operating energy production or distribution eq...
# 631                     occupational health and safety
# 6                                                  NaN
# 120                    maintaining operational records
#
#                                            Description  \
# 527                                                NaN
# 258  Operating turbines, generators, boilers or pow...
# 631  Occupational health and safety is the study of...
# 6    Withstand adversity, demonstrate resilience an...
# 120  Keeping records required for operational purpo...
#
#                                             Scope note Level 0 code  \
# 527                                                NaN            K
# 258  Examples:\n- Operate gas turbines\n- Operate s...            S
# 631                                                NaN            K
# 6             Excludes coping with physical adversity             T
# 120  Examples:\n- keep personal records\n- keep sto...            S
#
#     Level 1 code Level 2 code Level 3 code
# 527          NaN          NaN          NaN
# 258           S8         S8.4       S8.4.4
# 631          NaN          NaN          NaN
# 6             T3         T3.3          NaN
# 120           S2         S2.2       S2.2.5
# skillSkillRelations_en.csv
#                                        originalSkillUri originalSkillType  \
# 2913  http://data.europa.eu/esco/skill/7b56814d-5617...  skill/competence
# 3475  http://data.europa.eu/esco/skill/934226ed-71a3...  skill/competence
# 3442  http://data.europa.eu/esco/skill/91d06ad9-245e...  skill/competence
# 1645  http://data.europa.eu/esco/skill/46257638-c7e5...  skill/competence
# 3846  http://data.europa.eu/esco/skill/a472a200-d895...  skill/competence
#
#      relationType relatedSkillType  \
# 2913     optional        knowledge
# 3475     optional        knowledge
# 3442     optional        knowledge
# 1645     optional        knowledge
# 3846     optional        knowledge
#
#                                         relatedSkillUri
# 2913  http://data.europa.eu/esco/skill/c93527bc-6668...
# 3475  http://data.europa.eu/esco/skill/9b960424-c101...
# 3442  http://data.europa.eu/esco/skill/94c41e56-2a55...
# 1645  http://data.europa.eu/esco/skill/a815de2c-cefb...
# 3846  http://data.europa.eu/esco/skill/8c1ffdbd-3581...
# skills_en.csv
#                     conceptType  \
# 4293   KnowledgeSkillCompetence
# 13886  KnowledgeSkillCompetence
# 13262  KnowledgeSkillCompetence
# 11539  KnowledgeSkillCompetence
# 4934   KnowledgeSkillCompetence
#
#                                               conceptUri         skillType  \
# 4293   http://data.europa.eu/esco/skill/4eba4667-402e...         knowledge
# 13886  http://data.europa.eu/esco/skill/ffddfc7c-a9dd...         knowledge
# 13262  http://data.europa.eu/esco/skill/f49df8e2-f451...         knowledge
# 11539  http://data.europa.eu/esco/skill/d4f7cf8d-0d14...  skill/competence
# 4934   http://data.europa.eu/esco/skill/5a234b3b-63b4...         knowledge
#
#             reuseLevel                      preferredLabel  \
# 4293   sector-specific  combined heat and power generation
# 13886  sector-specific                               Scala
# 13262     cross-sector                         biosecurity
# 11539  sector-specific       inspect construction of ships
# 4934   sector-specific                    office equipment
#
#                                                altLabels hiddenLabels  \
# 4293                                                 chp          NaN
# 13886                                              Scala          NaN
# 13262  methods of bio-security\navoiding bio-security...          NaN
# 11539  inspect construction of vessels\ncarry out shi...          NaN
# 4934   office machinery\nequipment found in offices\n...          NaN
#
#          status              modifiedDate scopeNote definition  \
# 4293   released  2020-12-08T16:11:21.267Z       NaN        NaN
# 13886  released   2022-07-05T14:34:46.63Z       NaN        NaN
# 13262  released      2016-12-20T17:24:17Z       NaN        NaN
# 11539  released      2016-12-20T21:16:27Z       NaN        NaN
# 4934   released      2016-12-20T20:52:15Z       NaN        NaN
#
#                                                 inScheme  \
# 4293   http://data.europa.eu/esco/concept-scheme/gree...
# 13886  http://data.europa.eu/esco/concept-scheme/6c93...
# 13262  http://data.europa.eu/esco/concept-scheme/memb...
# 11539  http://data.europa.eu/esco/concept-scheme/skil...
# 4934   http://data.europa.eu/esco/concept-scheme/memb...
#
#                                              description
# 4293   Technology that generates electricity and capt...
# 13886  The techniques and principles of software deve...
# 13262  Be aware of the general principles of the conc...
# 11539  Inspect ship surfaces, windows, and ventilatio...
# 4934   The offered office machinery and equipment pro...
# transversalSkillsCollection_en.csv
#                  conceptType  \
# 89  KnowledgeSkillCompetence
# 64  KnowledgeSkillCompetence
# 18  KnowledgeSkillCompetence
# 12  KnowledgeSkillCompetence
# 53  KnowledgeSkillCompetence
#
#                                            conceptUri         skillType  \
# 89  http://data.europa.eu/esco/skill/e37d64dc-0f05...  skill/competence
# 64  http://data.europa.eu/esco/skill/b40584aa-7c63...  skill/competence
# 18  http://data.europa.eu/esco/skill/409a0245-0e6c...  skill/competence
# 12  http://data.europa.eu/esco/skill/1dabb413-18e8...  skill/competence
# 53  http://data.europa.eu/esco/skill/96de2e86-e287...  skill/competence
#
#      reuseLevel                       preferredLabel    status  \
# 89  transversal  respect confidentiality obligations  released
# 64  transversal                            improvise  released
# 18  transversal             exercise self-reflection  released
# 12  transversal              calculate probabilities  released
# 53  transversal                    resolve conflicts  released
#
#                                             altLabels  \
# 89  protect privacy | keep secret information | en...
# 64  demonstrate ability to improvise | show talent...
# 18  reflect on practice | self-evaluate | perform ...
# 12  estimate the probability of an outcome or fact...
# 53  demonstrate willingness to compromise | mediat...
#
#                                           description  \
# 89  Observe the necessary discretion and restraint...
# 64  Be able to improvise and react immediately and...
# 18  Effectively, regularly and systematically refl...
# 12  Predict the probability of an outcome based on...
# 53  Mediate in conflicts and tense situations by a...
#
#                                     broaderConceptUri  \
# 89  http://data.europa.eu/esco/skill/925af2b5-2f4d...
# 64  http://data.europa.eu/esco/skill/e84d080a-ff6d...
# 18  http://data.europa.eu/esco/skill/f5c9eef3-0495...
# 12  http://data.europa.eu/esco/skill/edc72cfe-78a8...
# 53  http://data.europa.eu/esco/skill/6f142deb-03a9...
#
#                         broaderConceptPT
# 89     following ethical code of conduct
# 64  thinking creatively and innovatively
# 18    demonstrating willingness to learn
# 12     working with numbers and measures
# 53                         communicating
# tech_managment_taxonomy.csv
#       Unnamed: 0                                             Source  \
# 768         1243  http://data.europa.eu/esco/skill/48ca61e4-9b68...
# 681         1109  http://data.europa.eu/esco/skill/4216e465-7baa...
# 2288        3701  http://data.europa.eu/esco/skill/da1398ac-6955...
# 1706        2755  http://data.europa.eu/esco/skill/a2bd1707-d1b8...
# 575          946  http://data.europa.eu/esco/skill/371d57e6-cc5f...
#
#                                            Type Level 4  \
# 768                            supervise audiology team
# 681                                 perform data mining
# 2288                             collect financial data
# 1706  perform inspections required by international ...
# 575                             perform product testing
#
#                                               altLabels  \
# 768   supervise audiology teams\nsupervise audiology...
# 681      perform data mining\nmine data\nuse model data
# 2288  collect finance data\nGather financial data\no...
# 1706  perform inspections to comply with internation...
# 575   execute product testing\nundertake product tes...
#
#                                              Definition Dimension  \
# 768   Oversee the work of audiology students and hea...    skills
# 681   Explore large datasets to reveal patterns usin...    skills
# 2288  Gather, organise, and combine financial data f...    skills
# 1706  Perform inspections as required by internation...    skills
# 575   Test processed workpieces or products for basi...    skills
#
#                 Type Level 1                          Type Level 2  \
# 768        management skills                    supervising people
# 681   working with computers  accessing and analysing digital data
# 2288      information skills                processing information
# 1706      information skills    monitoring, inspecting and testing
# 575       information skills    monitoring, inspecting and testing
#
#                                            Type Level 3  unique_id  \
# 768                         supervising a team or group       1768
# 681        managing, gathering and storing digital data       1681
# 2288  gathering information from physical or electro...       3288
# 1706                 monitoring, inspecting and testing       2706
# 575                      monitoring quality of products       1575
#
#                                                    name  \
# 768                            supervise audiology team
# 681                                 perform data mining
# 2288                             collect financial data
# 1706  perform inspections required by international ...
# 575                             perform product testing
#
#                                          name+defintion
# 768   supervise audiology team : oversee the work of...
# 681   perform data mining : explore large datasets t...
# 2288  collect financial data : gather, organise, and...
# 1706  perform inspections required by international ...
# 575   perform product testing : test processed workp...
# tech_managment_taxonomy_narrow.csv
#       Unnamed: 0                                             Source  \
# 812         1276  http://data.europa.eu/esco/skill/76cf35c2-2587...
# 635         1003  http://data.europa.eu/esco/skill/5cd46e15-61ce...
# 1516        2415  http://data.europa.eu/esco/skill/d9e5349e-8791...
# 1162        1845  http://data.europa.eu/esco/skill/a87c1c42-8927...
# 1378        2196  http://data.europa.eu/esco/skill/c6f01d70-2376...
#
#                           Type Level 4  \
# 812    engage in chiropractic research
# 635   forecast distribution activities
# 1516     define technical requirements
# 1162                            Litmos
# 1378        gather reference materials
#
#                                               altLabels  \
# 812   engage in chiropractic research activities\nen...
# 635   foresee distribution activities\nanticipate di...
# 1516  define technical requirements\nwrite technical...
# 1162                                             Litmos
# 1378  assemble reference materials\ngathering refere...
#
#                                              Definition  Dimension  \
# 812   Undertake different levels of engagement in re...     skills
# 635   Interpret data in order to identify future tre...     skills
# 1516  Specify technical properties of goods, materia...     skills
# 1162  The computer program Litmos is a e-learning pl...  knowledge
# 1378  Gathering reference materials such as drawings...     skills
#
#                                            Type Level 1  \
# 812                                  information skills
# 635                                  information skills
# 1516                                  management skills
# 1162  information and communication technologies (icts)
# 1378                                 information skills
#
#                                            Type Level 2  \
# 812   conducting studies, investigations and examina...
# 635       analysing and evaluating information and data
# 1516               developing objectives and strategies
# 1162  information and communication technologies (icts)
# 1378                             processing information
#
#                                            Type Level 3  unique_id  \
# 812              conducting academic or market research       1812
# 635                       analysing business operations       1635
# 1516     developing operational policies and procedures       2516
# 1162     database and network design and administration       2162
# 1378  gathering information from physical or electro...       2378
#
#                                   name  \
# 812    engage in chiropractic research
# 635   forecast distribution activities
# 1516     define technical requirements
# 1162                            Litmos
# 1378        gather reference materials
#
#                                          name+defintion
# 812   engage in chiropractic research : undertake di...
# 635   forecast distribution activities : interpret d...
# 1516  define technical requirements : specify techni...
# 1162  Litmos : the computer program litmos is a e-le...
# 1378  gather reference materials : gathering referen...

# %% [markdown]
# ## ESCO processing

# %%
esco = pd.read_csv(ESCO_DIR + "skills_en.csv")
print(len(esco)) #13896
esco = esco[['conceptUri', 'preferredLabel',  'altLabels', 'description']]

relationskill = pd.read_csv(ESCO_DIR + "broaderRelationsSkillPillar_en.csv")
skillshierarchy = pd.read_csv(ESCO_DIR + "skillsHierarchy_en.csv")

esco.head()
# Out:
# 13896
#                                           conceptUri  \
# 0  http://data.europa.eu/esco/skill/0005c151-5b5a...
# 1  http://data.europa.eu/esco/skill/00064735-8fad...
# 2  http://data.europa.eu/esco/skill/000709ed-2be5...
# 3  http://data.europa.eu/esco/skill/0007bdc2-dd15...
# 4  http://data.europa.eu/esco/skill/00090cc1-1f27...
#
#                                       preferredLabel  \
# 0                               manage musical staff
# 1                  supervise correctional procedures
# 2                    apply anti-oppressive practices
# 3  control compliance of railway vehicles regulat...
# 4                        identify available services
#
#                                            altLabels  \
# 0  manage staff of music\ncoordinate duties of mu...
# 1  oversee prison procedures\nmanage correctional...
# 2  apply non-oppressive practices\napply an anti-...
# 3  monitoring of compliance with railway vehicles...
# 4  establish available services\nidentify availab...
#
#                                          description
# 0  Assign and manage staff tasks in areas such as...
# 1  Supervise the operations of a correctional fac...
# 2  Identify oppression in societies, economies, c...
# 3  Inspect rolling stock, components and systems ...
# 4  Identify the different services available for ...

# %%
pd.read_csv(ESCO_DIR + "digitalSkillsCollection_en.csv")
# Out:
#                    conceptType  \
# 0     KnowledgeSkillCompetence
# 1     KnowledgeSkillCompetence
# 2     KnowledgeSkillCompetence
# 3     KnowledgeSkillCompetence
# 4     KnowledgeSkillCompetence
# ...                        ...
# 1196  KnowledgeSkillCompetence
# 1197  KnowledgeSkillCompetence
# 1198  KnowledgeSkillCompetence
# 1199  KnowledgeSkillCompetence
# 1200  KnowledgeSkillCompetence
#
#                                              conceptUri  \
# 0     http://data.europa.eu/esco/skill/000f1d3d-220f...
# 1     http://data.europa.eu/esco/skill/00c04e40-35ea...
# 2     http://data.europa.eu/esco/skill/013441c1-1f13...
# 3     http://data.europa.eu/esco/skill/0189f448-179e...
# 4     http://data.europa.eu/esco/skill/020918ef-4b55...
# ...                                                 ...
# 1196  http://data.europa.eu/esco/skill/ffa1d58b-ba09...
# 1197  http://data.europa.eu/esco/skill/ffc1e455-ced2...
# 1198  http://data.europa.eu/esco/skill/ffdd5e53-7191...
# 1199  http://data.europa.eu/esco/skill/ffddfc7c-a9dd...
# 1200  http://data.europa.eu/esco/skill/fff0e2cd-d0bd...
#
#                             preferredLabel    status         skillType  \
# 0                                  Haskell  released         knowledge
# 1                  Incremental development  released         knowledge
# 2                                 KDevelop  released         knowledge
# 3     Absorb (learning management systems)  released         knowledge
# 4                    migrate existing data  released  skill/competence
# ...                                    ...       ...               ...
# 1196            perform energy simulations  released  skill/competence
# 1197                           Capture One  released         knowledge
# 1198                          model sensor  released  skill/competence
# 1199                                 Scala  released         knowledge
# 1200           natural language processing  released         knowledge
#
#            reuseLevel                                          altLabels  \
# 0     sector-specific                                            Haskell
# 1     sector-specific                            Incremental development
# 2     sector-specific  KDevelop 4.7.0 | KDevelop 4.6.0 | KDevelop 4.0...
# 3     sector-specific                                             Absorb
# 4     sector-specific                              migrate existing data
# ...               ...                                                ...
# 1196  sector-specific                       carry out energy simulations
# 1197  sector-specific                                        Capture One
# 1198  sector-specific  sensor modelling | modelling sensor | simulati...
# 1199  sector-specific                                              Scala
# 1200  sector-specific                  natural language processing | NLP
#
#                                             description  \
# 0     The techniques and principles of software deve...
# 1     The incremental development model is a methodo...
# 2     The computer program KDevelop is a suite of so...
# 3     The learning system Absorb is an e-learning pl...
# 4     Apply migration and conversion methods for exi...
# ...                                                 ...
# 1196  Replicate the building's energy performance by...
# 1197  The computer program Capture One is a graphica...
# 1198  Model and simulate sensors, products using sen...
# 1199  The techniques and principles of software deve...
# 1200  The technologies which enable ICT devices to u...
#
#                                       broaderConceptUri  \
# 0     http://data.europa.eu/esco/skill/21d2f96d-35f7...
# 1     http://data.europa.eu/esco/skill/bec4359e-cb92...
# 2     http://data.europa.eu/esco/isced-f/0612 | http...
# 3     http://data.europa.eu/esco/skill/6c80d53c-d8c9...
# 4     http://data.europa.eu/esco/skill/6a7fc30d-af16...
# ...                                                 ...
# 1196  http://data.europa.eu/esco/skill/1f2950c0-ef1e...
# 1197            http://data.europa.eu/esco/isced-f/0611
# 1198  http://data.europa.eu/esco/skill/c34b06c4-d164...
# 1199            http://data.europa.eu/esco/isced-f/0613
# 1200            http://data.europa.eu/esco/isced-f/0231
#
#                                        broaderConceptPT
# 0     computer programming | software and applicatio...
# 1     ICT project management methodologies | softwar...
# 2     database and network design and administration...
# 3     learning management systems | database and net...
# 4          managing, gathering and storing digital data
# ...                                                 ...
# 1196      analysing and evaluating information and data
# 1197                                       computer use
# 1198  designing industrial materials, systems or pro...
# 1199  software and applications development and anal...
# 1200                               language acquisition
#
# [1201 rows x 10 columns]

# %%
uriwhitelist = list(set(['http://data.europa.eu/esco/isced-f/06', ## K: Information and Communication Technologies
                # 'http://data.europa.eu/esco/skill/c1a13ee0-b00d-4cfa-a22c-20d284e398b0', ## management skills S4.0 ==> too vast
                'http://data.europa.eu/esco/skill/cb668e89-6ef5-4ff3-ab4a-506010e7e70b', ## more specific T.4.4.X
                'http://data.europa.eu/esco/skill/248894d1-42dc-474f-af6e-2da52ac0c679', ## is S.4.1.2 define technology strategy 
                'http://data.europa.eu/esco/skill/736ef286-fbd3-4e5c-a4b4-d1e2008c9898', ## Plan digital marketing
                'http://data.europa.eu/esco/skill/6f89dcbe-4315-4533-8801-3aadf9190b86', ## Developing objectives and strategies S4.1
                'http://data.europa.eu/esco/skill/ce17a874-b476-491d-a7a7-5f05d32ad542', ## Leading and motitvating S4.5 
                # 'http://data.europa.eu/esco/skill/7a00c77c-4a1c-4fd6-a83f-004bda65d81a', ## Supervising people S4.8 ==> too vast
                'http://data.europa.eu/esco/skill/7af6e9e8-1e11-4c0b-b7c6-ac96bbbbc674', ## Coordinate engineering team
                'http://data.europa.eu/esco/skill/ef64005d-75bc-4597-8ed6-717edec5e55e', ## Enhance website visibility
                'http://data.europa.eu/esco/skill/d15ba5cb-9212-4a90-85af-2c560da59925', ## perform product planning
                'http://data.europa.eu/esco/skill/bb99a123-88be-42a2-8758-f5a18e06ccc6', ## Making decision S4.9
                'http://data.europa.eu/esco/skill/243eb885-07c7-4b77-ab9c-827551d83dc4', ## Working with computer S5
                'http://data.europa.eu/esco/skill/8267ecb5-c976-4b6a-809b-4ceecb954967', ## Thinking skills and Competences T2
                'http://data.europa.eu/esco/skill/7eafec38-621a-4b6e-9298-bfe70ec0b253', ## Information skills S2.1.1 conducting academic or market research 
                'http://data.europa.eu/esco/skill/587e1cd6-a376-4c8f-8369-187c128d72a3', ## Information skills S2.4 processing information  
                'http://data.europa.eu/esco/skill/dddd229b-61e1-480d-80d6-d9d9ee9b5f54', ## Information skills S2.4 managing information
                'http://data.europa.eu/esco/skill/3753e796-121e-46a3-9c27-dee31ce92c80', ## Information skills S2.7 analysing and evaluating information and data 
                # 'http://data.europa.eu/esco/skill/1e95cef2-9c35-4f9f-b6a9-cb458c3e5379', ## Information skills S2.8 monitoring, inspecting and testing
                'http://data.europa.eu/esco/skill/85b379e7-e0b7-48b8-baa7-631f50a7cdd5', ## S1.0 communication, collaboration and creativity 
                'http://data.europa.eu/esco/skill/3f641516-9846-4a7f-a7f4-e1274eef6688', ## S1.4 presenting information
                #'http://data.europa.eu/esco/skill/548c3fbe-9eb1-4035-bc54-027fd5bc5315', ## S1.8 working with others ==> too vast
                ] + list(dfs[files.index("digitalSkillsCollection_en.csv")]["conceptUri"].unique()) ## in digitalSkillsCollection_en.csv
        )
)

relationskill1 = relationskill[relationskill['conceptUri'].isin(uriwhitelist)]
print("Number of ConceptURI dans la liste > ", len(relationskill1)) 
relationskill2 = relationskill[relationskill['broaderUri'].isin(uriwhitelist)]
print(len(relationskill2)) # 2: conceptUri = http://data.europa.eu/esco/isced-f/061, http://data.europa.eu/esco/isced-f/068
esco1 = esco[esco['conceptUri'].isin(uriwhitelist)]
print("Number of matches in ESCO > ", len(esco1)) # 0
skillshierarchy1 = skillshierarchy[skillshierarchy['Level 0 URI'].isin(uriwhitelist)]
print("Number of matches in Level0 hierarchy = (S, K, T, L) > ", len(skillshierarchy1)) # 0
skillshierarchy2 = skillshierarchy[skillshierarchy['Level 1 URI'].isin(uriwhitelist)]
print("Number of matches in Level1 hierarchy = (Sn, Kn, Tn, Ln) > ", len(skillshierarchy2)) 
#
#  Level 0 URI = 'http://data.europa.eu/esco/skill/c46fcb45-5c14-4ffa-abed-5a43f104bb22'
# Level 2 URI = http://data.europa.eu/esco/isced-f/061, http://data.europa.eu/esco/isced-f/068
skillshierarchy3 = skillshierarchy[skillshierarchy['Level 2 URI'].isin(uriwhitelist)]
print("Number of matches in Level2 hierarchy = (Si.j, Ki.j, Ti.j, Li.j) > ", len(skillshierarchy3)) 
skillshierarchy4 = skillshierarchy[skillshierarchy['Level 3 URI'].isin(uriwhitelist)]
print("Number of matches in Level3 hierarchy = (Si.j.k, Ki.j.k, Ti.j.k, Li.j.k) > ", len(skillshierarchy3))
# Out:
# Number of ConceptURI dans la liste >  1879
# 812
# Number of matches in ESCO >  1205
# Number of matches in Level0 hierarchy = (S, K, T, L) >  0
# Number of matches in Level1 hierarchy = (Sn, Kn, Tn, Ln) >  36
# Number of matches in Level2 hierarchy = (Si.j, Ki.j, Ti.j, Li.j) >  34
# Number of matches in Level3 hierarchy = (Si.j.k, Ki.j.k, Ti.j.k, Li.j.k) >  34

# %%
print(len(esco[esco['conceptUri'].isin(list(relationskill['broaderUri']))]))
print(len(esco[esco['conceptUri'].isin(list(relationskill['conceptUri']))]))
for level in ['Level 0 URI', 'Level 1 URI', 'Level 2 URI', 'Level 3 URI']:
    print(f"Matching is ESCO conceptUri at level : {level.split(' ')[1]} > {len(esco[esco['conceptUri'].isin(list(skillshierarchy[level]))])}")
    print(f"Matching is ESCO broaderUri at level : {level.split(' ')[1]} > {len(esco[esco['conceptUri'].isin(list(skillshierarchy[level]))])}")
# esco['conceptUri'] looks like this: http://data.europa.eu/esco/skill/000f1d3d-220f...

# conclusion: esco['conceptUri'] are all in relationskill['conceptUri'] --> can deduce broaderURi

for level in ['Level 0 URI', 'Level 1 URI', 'Level 2 URI', 'Level 3 URI']:
    print(f"Matching in relation skill broaderUri at Level {level.split(' ')[1]} > {len(relationskill[relationskill['broaderUri'].isin(list(skillshierarchy[level]))])}")

# conclusion: the broaderUri mostly corresponds to skillshierarchy['Level 3 URI']

# the uritoexclude = 'http://data.europa.eu/esco/isced-f/06' is in skillshierarchy['Level 1 URI']
# The associated skillshierarchy['Level 3 URI'] are:
broaderskill_toexclude = []
for level in ['Level 0 URI', 'Level 1 URI', 'Level 2 URI', 'Level 3 URI']:
    broaderskill_toexclude += list(skillshierarchy[skillshierarchy[level].isin(uriwhitelist)]['Level 3 URI'])
print(broaderskill_toexclude)
skillshierarchy['Level 3 URI'] = skillshierarchy['Level 3 URI'].fillna('')
# these two lists are the same, so the pattern is right

# get conceptUri of broader skills to exclude:
conceptUri_toexclude = list(relationskill[relationskill['broaderUri'].isin(broaderskill_toexclude)]['conceptUri'])
print(len(conceptUri_toexclude))
esco_filtered = esco[esco['conceptUri'].isin(conceptUri_toexclude)]
print(len(esco_filtered)) # 2741
# Out:
# 2313
# 13896
# Matching is ESCO conceptUri at level : 0 > 0
# Matching is ESCO broaderUri at level : 0 > 0
# Matching is ESCO conceptUri at level : 1 > 0
# Matching is ESCO broaderUri at level : 1 > 0
# Matching is ESCO conceptUri at level : 2 > 0
# Matching is ESCO broaderUri at level : 2 > 0
# Matching is ESCO conceptUri at level : 3 > 0
# Matching is ESCO broaderUri at level : 3 > 0
# Matching in relation skill broaderUri at Level 0 > 28
# Matching in relation skill broaderUri at Level 1 > 229
# Matching in relation skill broaderUri at Level 2 > 633
# Matching in relation skill broaderUri at Level 3 > 13201
# [nan, nan, nan, nan, nan, nan, nan, 'http://data.europa.eu/esco/skill/258fea29-09db-4918-8235-0d7d529cd31c', 'http://data.europa.eu/esco/skill/4d6a48ae-352e-4823-bc3a-3f3e9e2cae86', 'http://data.europa.eu/esco/skill/6a7fc30d-af16-4cc5-a957-29d174bdb61c', nan, 'http://data.europa.eu/esco/skill/0b9968af-72de-470a-98e1-2d19577443fb', 'http://data.europa.eu/esco/skill/185c56ee-098f-46a1-af87-56337085da6f', 'http://data.europa.eu/esco/skill/24aa32e7-5b7c-42fd-b045-11f0c3d9b6e3', 'http://data.europa.eu/esco/skill/f839b1da-78b6-4466-86f4-a5798821ea20', nan, 'http://data.europa.eu/esco/skill/494b8057-daf5-46a0-b33b-416e0115c30a', nan, 'http://data.europa.eu/esco/skill/446a36a5-2376-439f-b46b-4a214ba0acdf', 'http://data.europa.eu/esco/skill/98fb499f-9155-412d-a8a0-95ba97126fec', 'http://data.europa.eu/esco/skill/b1115b14-fa16-4c1e-be6c-91fd49a1808b', 'http://data.europa.eu/esco/skill/c53a55a1-8b2b-4d2c-b12d-626742a3833a', 'http://data.europa.eu/esco/skill/f774131e-8f2d-43b6-8c20-7fe35fa0f0bd', nan, 'http://data.europa.eu/esco/skill/a8c3186b-c791-4d57-8f4f-4d12c7a5c6a7', nan, 'http://data.europa.eu/esco/skill/39499028-35bf-4d69-9275-fb98902ed88b', nan, nan, 'http://data.europa.eu/esco/isced-f/0610', 'http://data.europa.eu/esco/isced-f/0611', 'http://data.europa.eu/esco/isced-f/0612', 'http://data.europa.eu/esco/isced-f/0613', 'http://data.europa.eu/esco/isced-f/0619', nan, 'http://data.europa.eu/esco/isced-f/0688', nan, 'http://data.europa.eu/esco/skill/1f2950c0-ef1e-44b4-9a55-125ccd7b78af', 'http://data.europa.eu/esco/skill/3eef7ff2-3ade-41d4-b084-2bd2a3949e1c', 'http://data.europa.eu/esco/skill/7e153e1d-2b12-43ad-89f3-0cf82ebc4a30', 'http://data.europa.eu/esco/skill/ba1f6201-b206-4459-b178-706db34a851d', 'http://data.europa.eu/esco/skill/d94e1143-3a3a-4f6a-a881-df93bf56cf23', 'http://data.europa.eu/esco/skill/ec528c47-65f4-4187-9dc1-5a8889f84a06', 'http://data.europa.eu/esco/skill/f2cf57fe-d4cb-4b4a-831d-73171cc73909', nan, 'http://data.europa.eu/esco/skill/29dcc31e-a8d6-4a62-b3c1-2de81e966e39', 'http://data.europa.eu/esco/skill/70ac2c90-656a-4fa3-886c-5b9305db2087', 'http://data.europa.eu/esco/skill/9bdf8a77-8524-43da-bac6-d15d22e1b7ed', nan, 'http://data.europa.eu/esco/skill/32c017fd-28ab-4051-bf68-74de952c2f77', nan, 'http://data.europa.eu/esco/skill/164510d1-1216-4dc0-b9d1-a7f6af19e469', 'http://data.europa.eu/esco/skill/37272760-957a-4c34-b4f3-780ee285334d', 'http://data.europa.eu/esco/skill/6ee936b0-4e0c-4e04-97c7-1f4ee9230d67', 'http://data.europa.eu/esco/skill/7e0b93e0-0de7-4607-b07f-27a6828d3ff0', 'http://data.europa.eu/esco/skill/8ed41305-4abf-4b54-9f8f-0e043d26feba', 'http://data.europa.eu/esco/skill/c23e0a2f-f04b-45bc-b0dd-20571f6b502c', 'http://data.europa.eu/esco/skill/cbe1b24e-00f3-4b17-94e9-1fcd34a11c3e', 'http://data.europa.eu/esco/skill/db54693e-bcb0-4dae-8885-a43d510fb71f', nan, 'http://data.europa.eu/esco/skill/c7f96545-46c4-451a-b284-014f4baed5ed', nan, 'http://data.europa.eu/esco/skill/b7e752ec-7b2e-46e6-ac24-8b1233609c31', nan, 'http://data.europa.eu/esco/skill/8f9f8b20-ff26-4392-b04f-695dcde5b90a', 'http://data.europa.eu/esco/skill/ad326fa7-f2e9-4421-8426-bc0c2e167143', 'http://data.europa.eu/esco/skill/cdb2aecd-9dca-48fd-8d56-f0aace3ab5a9', 'http://data.europa.eu/esco/skill/de884168-32e7-4500-a227-3f0966f962b6', nan, 'http://data.europa.eu/esco/skill/ab877a24-335d-4676-b366-c5c06651481a', 'http://data.europa.eu/esco/skill/7eafec38-621a-4b6e-9298-bfe70ec0b253']
# 1793
# 1793

# %%
# merge skillshierarchy with esco
# 1/ get broader URi
esco_filtered_augmented = pd.merge(esco_filtered, relationskill, left_on='conceptUri', right_on='conceptUri', how='left')
print(len(esco_filtered_augmented)) # 3281
esco_filtered_augmented = esco_filtered_augmented[['conceptUri', 'preferredLabel', 'altLabels', 'description', 'broaderUri']]
# After merging we get duplicated conceptURi
# 2/ get skill levels
esco_filtered_augmented2 = pd.merge(esco_filtered_augmented, skillshierarchy, left_on='broaderUri', right_on='Level 3 URI', how='left')
# remove NAs
esco_filtered_augmented2.isnull().sum()
len(esco_filtered_augmented2['conceptUri'].unique())
esco_filtered_augmented2.dropna(subset=['Level 0 URI'], inplace=True)
len(esco_filtered_augmented2['conceptUri'].unique())
print(esco_filtered_augmented2.isnull().sum())

print(len(esco_filtered_augmented2)) 
esco_filtered_augmented2 = esco_filtered_augmented2[['conceptUri', 'preferredLabel', 'altLabels', 'description', 'Level 0 preferred term', 'Level 1 preferred term', 'Level 2 preferred term', 'Level 3 preferred term']]
# Out:
# 2883
# conceptUri                  0
# preferredLabel              0
# altLabels                  47
# description                 0
# broaderUri                  0
# Level 0 URI                 0
# Level 0 preferred term      0
# Level 1 URI                 0
# Level 1 preferred term      0
# Level 2 URI                 0
# Level 2 preferred term      0
# Level 3 URI                 0
# Level 3 preferred term      0
# Description                 0
# Scope note                364
# Level 0 code                0
# Level 1 code              318
# Level 2 code              318
# Level 3 code              318
# dtype: int64
# 1794

# %%
esco_filtered_augmented2.rename(columns={'preferredLabel': 'Type Level 4', 'description': 'Definition', 'Level 1 preferred term': 'Type Level 1', 'Level 2 preferred term': 'Type Level 2', 'Level 3 preferred term': 'Type Level 3', 'conceptUri': 'Source', 'Level 0 preferred term': 'Dimension'}, inplace=True)

esco_filtered_augmented2["unique_id"] = [1000+ i for i in range(len(esco_filtered_augmented2))]

# %%
esco_filtered_augmented2["name"] = esco_filtered_augmented2["Type Level 4"]

# %%
print("Number of skills : ", len(esco_filtered_augmented2.index))
esco_filtered_augmented2.head()
# Out:
# Number of skills :  1794
#                                               Source  \
# 0  http://data.europa.eu/esco/skill/000f1d3d-220f...
# 2  http://data.europa.eu/esco/skill/0037c821-2898...
# 4  http://data.europa.eu/esco/skill/0058526a-11e9...
# 5  http://data.europa.eu/esco/skill/00c04e40-35ea...
# 7  http://data.europa.eu/esco/skill/0121ac3b-775b...
#
#                      Type Level 4  \
# 0                         Haskell
# 2  develop energy saving concepts
# 4       conduct research on flora
# 5         Incremental development
# 7   develop terminology databases
#
#                                            altLabels  \
# 0                                            Haskell
# 2  developing concepts for energy saving\ndevelop...
# 4  carry out research on flora\nflora research\nc...
# 5                            Incremental development
# 7  define terminology databases prepare terminolo...
#
#                                           Definition  Dimension  \
# 0  The techniques and principles of software deve...  knowledge
# 2  Use current research results and collaborate w...     skills
# 4  Collect and analyse data about plants in order...     skills
# 5  The incremental development model is a methodo...  knowledge
# 7  Collect and submit terms after verifying their...     skills
#
#                                         Type Level 1  \
# 0  information and communication technologies (icts)
# 2                                  management skills
# 4                                 information skills
# 5  information and communication technologies (icts)
# 7                                 information skills
#
#                                         Type Level 2  \
# 0  information and communication technologies (icts)
# 2               developing objectives and strategies
# 4      analysing and evaluating information and data
# 5  information and communication technologies (icts)
# 7                               managing information
#
#                                         Type Level 3  unique_id  \
# 0  software and applications development and anal...       1000
# 2     developing operational policies and procedures       1001
# 4              analysing scientific and medical data       1002
# 5  software and applications development and anal...       1003
# 7                               managing information       1004
#
#                              name
# 0                         Haskell
# 2  develop energy saving concepts
# 4       conduct research on flora
# 5         Incremental development
# 7   develop terminology databases

# %%
esco_filtered_augmented2["name+definition"] = esco_filtered_augmented2["name"] + " : " + esco_filtered_augmented2["Definition"].apply(lambda x : x.lower())

# %%
esco_filtered_augmented2.to_csv(ESCO_DIR + "tech_managment_taxonomy_narrow.csv")

# %%
esco_filtered_augmented2
# Out:
#                                                  Source  \
# 0     http://data.europa.eu/esco/skill/0005c151-5b5a...
# 3     http://data.europa.eu/esco/skill/000bb1e4-89f0...
# 4     http://data.europa.eu/esco/skill/000f1d3d-220f...
# 6     http://data.europa.eu/esco/skill/0037c821-2898...
# 8     http://data.europa.eu/esco/skill/004f1e68-9ca2...
# ...                                                 ...
# 4398  http://data.europa.eu/esco/skill/ff82aa43-aef7...
# 4399  http://data.europa.eu/esco/skill/ff862044-d49e...
# 4401  http://data.europa.eu/esco/skill/ffa1d58b-ba09...
# 4402  http://data.europa.eu/esco/skill/ffc1e455-ced2...
# 4403  http://data.europa.eu/esco/skill/ffddfc7c-a9dd...
#
#                               Type Level 4  \
# 0                     manage musical staff
# 3            perform toxicological studies
# 4                                  Haskell
# 6           develop energy saving concepts
# 8                       work with soloists
# ...                                    ...
# 4398            perform nutrition analysis
# 4399  analyse work-related written reports
# 4401            perform energy simulations
# 4402                           Capture One
# 4403                                 Scala
#
#                                               altLabels  \
# 0     manage staff of music\ncoordinate duties of mu...
# 3     perform toxicological studies\napply toxicolog...
# 4                                               Haskell
# 6     developing concepts for energy saving\ndevelop...
# 8     collaborate with soloists\nworking with solois...
# ...                                                 ...
# 4398  determine nutrients of food products\nperform ...
# 4399  analyze  work-related written reports\nconduct...
# 4401                       carry out energy simulations
# 4402                                        Capture One
# 4403                                              Scala
#
#                                              Definition  Dimension  \
# 0     Assign and manage staff tasks in areas such as...     skills
# 3     Perform tests to detect poisons or drug misuse...     skills
# 4     The techniques and principles of software deve...  knowledge
# 6     Use current research results and collaborate w...     skills
# 8     Communicate with solo artists and concert mast...     skills
# ...                                                 ...        ...
# 4398  Determine and calculate the nutrients of food ...     skills
# 4399  Read and comprehend job-related reports, analy...     skills
# 4401  Replicate the building's energy performance by...     skills
# 4402  The computer program Capture One is a graphica...  knowledge
# 4403  The techniques and principles of software deve...  knowledge
#
#                                            Type Level 1  \
# 0                                     management skills
# 3                                    information skills
# 4     information and communication technologies (icts)
# 6                                     management skills
# 8           communication, collaboration and creativity
# ...                                                 ...
# 4398                                 information skills
# 4399                                 information skills
# 4401                                 information skills
# 4402  information and communication technologies (icts)
# 4403  information and communication technologies (icts)
#
#                                            Type Level 2  \
# 0                                    supervising people
# 3                    monitoring, inspecting and testing
# 4     information and communication technologies (icts)
# 6                  developing objectives and strategies
# 8                                   working with others
# ...                                                 ...
# 4398      analysing and evaluating information and data
# 4399      analysing and evaluating information and data
# 4401      analysing and evaluating information and data
# 4402  information and communication technologies (icts)
# 4403  information and communication technologies (icts)
#
#                                            Type Level 3  unique_id  \
# 0                           supervising a team or group       1000
# 3     monitoring health conditions of humans and ani...       1001
# 4     software and applications development and anal...       1002
# 6        developing operational policies and procedures       1003
# 8                                      working in teams       1004
# ...                                                 ...        ...
# 4398              analysing scientific and medical data       3700
# 4399                      analysing business operations       3701
# 4401      analysing and evaluating information and data       3702
# 4402                                       computer use       3703
# 4403  software and applications development and anal...       3704
#
#                                       name  \
# 0                     manage musical staff
# 3            perform toxicological studies
# 4                                  Haskell
# 6           develop energy saving concepts
# 8                       work with soloists
# ...                                    ...
# 4398            perform nutrition analysis
# 4399  analyse work-related written reports
# 4401            perform energy simulations
# 4402                           Capture One
# 4403                                 Scala
#
#                                          name+defintion
# 0     manage musical staff : assign and manage staff...
# 3     perform toxicological studies : perform tests ...
# 4     Haskell : the techniques and principles of sof...
# 6     develop energy saving concepts : use current r...
# 8     work with soloists : communicate with solo art...
# ...                                                 ...
# 4398  perform nutrition analysis : determine and cal...
# 4399  analyse work-related written reports : read an...
# 4401  perform energy simulations : replicate the bui...
# 4402  Capture One : the computer program capture one...
# 4403  Scala : the techniques and principles of softw...
#
# [2705 rows x 11 columns]

# %% [markdown]
# #### Negative sample taxonomy

# %%
assert(
    (len(esco[~esco['conceptUri'].isin(conceptUri_toexclude)].index) + len(esco_filtered.index) == len(esco.index))
)


excluded_taxonomy = esco[~esco['conceptUri'].isin(conceptUri_toexclude)]
ex_esco_filtered_augmented = pd.merge(excluded_taxonomy, relationskill, left_on='conceptUri', right_on='conceptUri', how='left')
print(len(esco_filtered_augmented)) # 3281
ex_esco_filtered_augmented = ex_esco_filtered_augmented[['conceptUri', 'preferredLabel', 'altLabels', 'description', 'broaderUri']]
# After merging we get duplicated conceptURi
# 2/ get skill levels
ex_esco_filtered_augmented2 = pd.merge(ex_esco_filtered_augmented, skillshierarchy, left_on='broaderUri', right_on='Level 3 URI', how='left')
# remove NAs
ex_esco_filtered_augmented2.isnull().sum()
len(ex_esco_filtered_augmented2['conceptUri'].unique())
ex_esco_filtered_augmented2.dropna(subset=['Level 0 URI'], inplace=True)
len(ex_esco_filtered_augmented2['conceptUri'].unique())
print(ex_esco_filtered_augmented2.isnull().sum())

print(len(ex_esco_filtered_augmented2)) 
ex_esco_filtered_augmented2 = ex_esco_filtered_augmented2[['conceptUri', 'preferredLabel', 'altLabels', 'description', 'Level 0 preferred term', 'Level 1 preferred term', 'Level 2 preferred term', 'Level 3 preferred term']]

ex_esco_filtered_augmented2.rename(columns={'preferredLabel': 'Type Level 4', 'description': 'Definition', 'Level 1 preferred term': 'Type Level 1', 'Level 2 preferred term': 'Type Level 2', 'Level 3 preferred term': 'Type Level 3', 'conceptUri': 'Source', 'Level 0 preferred term': 'Dimension'}, inplace=True)

ex_esco_filtered_augmented2["unique_id"] = [5000+ i for i in range(len(ex_esco_filtered_augmented2))]

ex_esco_filtered_augmented2["name"] = ex_esco_filtered_augmented2["Type Level 4"]


print(len(ex_esco_filtered_augmented2.index))
print(len(esco_filtered.index))
print(len(esco.index))
print(set(ex_esco_filtered_augmented2["name"]).intersection(set(esco_filtered_augmented2["name"])))
# Out:
# 2883
# conceptUri                   0
# preferredLabel               0
# altLabels                  140
# description                  0
# broaderUri                   0
# Level 0 URI                  0
# Level 0 preferred term       0
# Level 1 URI                  0
# Level 1 preferred term       0
# Level 2 URI                  0
# Level 2 preferred term       0
# Level 3 URI                  0
# Level 3 preferred term       0
# Description                186
# Scope note                3174
# Level 0 code                 0
# Level 1 code              2661
# Level 2 code              2661
# Level 3 code              2661
# dtype: int64
# 11407
# 11407
# 1793
# 13896
# set()

# %%
ex_esco_filtered_augmented2.to_csv(ESCO_DIR + "excluded_skills_taxonomy.csv")

# %%
import pandas as pd
ESCO_DIR = "../../../esco/"
ex_esco_filtered_augmented2 = pd.read_csv(ESCO_DIR + "excluded_skills_taxonomy.csv")

# %%
from transformers import AutoTokenizer, AutoModel
from tqdm.notebook import tqdm
import pickle

tqdm.pandas()


word_emb = "jjzha/jobbert-base-cased"
word_emb_tokenizer = AutoTokenizer.from_pretrained(word_emb)
word_emb_model = AutoModel.from_pretrained(word_emb)

excluded_taxonomy = ex_esco_filtered_augmented2
excluded_taxonomy["name+definition"] = excluded_taxonomy["name"] + " : " + excluded_taxonomy["Definition"]


## it fails after 11180 !!
for i in range(1, 11):
    vals = []
    for nd in tqdm(excluded_taxonomy["name+definition"].values[1_000*i:1_000*(i+1)]):
        vals.append(
            word_emb_model(**word_emb_tokenizer(nd, return_tensors="pt", max_length=768, padding=True, truncation=True))\
                            .last_hidden_state[:, 0, :]
        )
    sub_ex_emb_tax = excluded_taxonomy.iloc[1_000*i:1_000*(i+1)]
    sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]
    with open(ESCO_DIR + f"excluded_emb_tax_slice{i + 1}.pkl", "wb") as f:
        pickle.dump(sub_ex_emb_tax[["unique_id", "name", "name+definition", "embeddings"]], f)
    del vals
# excluded_taxonomy["embeddings"] = excluded_taxonomy["name+definition"]\
#                         .progress_apply(lambda st : \
#                         word_emb_model(**word_emb_tokenizer(st, return_tensors="pt", max_length=768, padding=True, truncation=True))\
#                         .last_hidden_state[:, 0, :]\
#                         )
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at jjzha/jobbert-base-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipykernel_18033/2528358407.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipykernel_18033/2528358407.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipykernel_18033/2528358407.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipykernel_18033/2528358407.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipykernel_18033/2528358407.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipykernel_18033/2528358407.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipykernel_18033/2528358407.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipykernel_18033/2528358407.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipykernel_18033/2528358407.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipykernel_18033/2528358407.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]

# %%
sub_ex_emb_tax = excluded_taxonomy.iloc[:1000]
sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]
# Out:
# /tmp/ipykernel_18033/1998132013.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_ex_emb_tax["embeddings"] = [x.detach() for x in vals]

# %%
slices = [ESCO_DIR + f"excluded_emb_tax_slice{i}.pkl" for i in range(1, 11)]

emb_slices = []
for slice in slices:
    with open(slice, "rb") as f:
        emb_slices.append(pickle.load(f))

# %%
with open(ESCO_DIR + "excluded_emb_tax.pkl", "wb") as f:
    pickle.dump(pd.concat(emb_slices), f)
