# %% [markdown]
# # Translate the taxonomy
#
#
# The taxonomy is currently in german and we would like to use the same one for the pipeline.

# %%
import pandas as pd
import os
import sys

# %%
taxonomy_de = pd.read_csv("../../data/taxonomy/taxonomy_V4.csv")
taxonomy_de.sample(5)
# Out:
#      unique_id ElementID Dimension FE       Type Level 1  \
# 49          45   2.3.2.2   Deskriptor  Kompetenzelemente
# 88          71       NaN    Kompetenz      Fachkompetenz
# 10          83     2.1.2   Deskriptor  Kompetenzelemente
# 323         40       NaN    Kompetenz      Fachkompetenz
# 193         51       NaN    Kompetenz      Fachkompetenz
#
#                   Type Level 1 E              Type Level 1 F  \
# 49   General Skills & Attitudes       Éléments de Compétence
# 88       Professional Competency  Compétence Professionnelle
# 10   General Skills & Attitudes       Éléments de Compétence
# 323      Professional Competency  Compétence Professionnelle
# 193      Professional Competency  Compétence Professionnelle
#
#                     Type Level 2       Type Level 2 E  \
# 49   Psychomotorische Fertigkeit    Psychomotor Skill
# 88            Management der ICT       ICT Management
# 10          Kognitive Fertigkeit      Cognitive Skill
# 323            Gebäudeautomation  Building Automation
# 193       Informationssicherheit        Data Security
#
#                   Type Level 2 F            Type Level 3  ... Unnamed: 34  \
# 49        Aptitude Psychomotrice      Bewegungskontrolle  ...         NaN
# 88               Gestion des TIC                     NaN  ...         NaN
# 10            Aptitude Cognitive  Organisationsfähigkeit  ...         NaN
# 323  Automatisation de Bâtiments                     NaN  ...         NaN
# 193    Sécurité de l'information                     NaN  ...         NaN
#
#     Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40  \
# 49          NaN         NaN         NaN         NaN         NaN         NaN
# 88          NaN         NaN         NaN         NaN         NaN         NaN
# 10          NaN         NaN         NaN         NaN         NaN         NaN
# 323         NaN         NaN         NaN         NaN         NaN         NaN
# 193         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 41 Unnamed: 42 Unnamed: 43
# 49          NaN         NaN         NaN
# 88          NaN         NaN         NaN
# 10          NaN         NaN         NaN
# 323         NaN         NaN         NaN
# 193         NaN         NaN         NaN
#
# [5 rows x 45 columns]

# %%
taxonomy_de.columns
# Out:
# Index(['unique_id', 'ElementID', 'Dimension FE', 'Type Level 1',
#        'Type Level 1 E', 'Type Level 1 F', 'Type Level 2', 'Type Level 2 E',
#        'Type Level 2 F', 'Type Level 3', 'Type Level 4', 'Example',
#        'Definition', 'Industry', 'Bildungsweg 1', 'Bildungsweg 2',
#        'Bildungsweg 3', 'Bildungsweg 4', 'Bildungsweg 5', 'Bildungsweg 6',
#        'Bildungsweg 7', 'Bildungsweg 8', 'Bildungsweg 9', 'Bildungsweg 10',
#        'Frontend', 'Source', 'Connection SwissICT Model', 'Internal Reference',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42',
#        'Unnamed: 43'],
#       dtype='object')

# %%
ESCO_DIR = "../../../esco/"
files = os.listdir(ESCO_DIR)
display(files)
# Out:
# ['broaderRelationsOccPillar_en.csv',
#  'broaderRelationsSkillPillar_en.csv',
#  'conceptSchemes_en.csv',
#  'digCompSkillsCollection_en.csv',
#  'digitalSkillsCollection_en.csv',
#  'greenSkillsCollection_en.csv',
#  'ISCOGroups_en.csv',
#  'languageSkillsCollection_en.csv',
#  'occupationSkillRelations_en.csv',
#  'occupations_en.csv',
#  'researchOccupationsCollection_en.csv',
#  'researchSkillsCollection_en.csv',
#  'skillGroups_en.csv',
#  'skillsHierarchy_en.csv',
#  'skillSkillRelations_en.csv',
#  'skills_en.csv',
#  'transversalSkillsCollection_en.csv']

# %%
len(taxonomy_de.index)
# Out:
# 373

# %%
[print(f"{f} > {len(df.index)}") for f, df in zip(files, dfs)];
# Out:
# broaderRelationsOccPillar_en.csv > 3617
# broaderRelationsSkillPillar_en.csv > 20656
# conceptSchemes_en.csv > 19
# digCompSkillsCollection_en.csv > 26
# digitalSkillsCollection_en.csv > 1201
# greenSkillsCollection_en.csv > 570
# ISCOGroups_en.csv > 619
# languageSkillsCollection_en.csv > 346
# occupationSkillRelations_en.csv > 123855
# occupations_en.csv > 3007
# researchOccupationsCollection_en.csv > 122
# researchSkillsCollection_en.csv > 40
# skillGroups_en.csv > 640
# skillsHierarchy_en.csv > 647
# skillSkillRelations_en.csv > 5899
# skills_en.csv > 13896
# transversalSkillsCollection_en.csv > 96

# %%
dfs = []
for file in files:
    df = pd.read_csv(ESCO_DIR + file)
    dfs.append(df)
    print(file)
    display(df.sample(5))
# Out:
# broaderRelationsOccPillar_en.csv
#      conceptType                                         conceptUri  \
# 2483  Occupation  http://data.europa.eu/esco/occupation/1663e9d9...
# 163    ISCOGroup              http://data.europa.eu/esco/isco/C2632
# 719   Occupation  http://data.europa.eu/esco/occupation/0ec62c2e...
# 10     ISCOGroup               http://data.europa.eu/esco/isco/C111
# 504    ISCOGroup              http://data.europa.eu/esco/isco/C8111
#
#      broaderType                                         broaderUri
# 2483  Occupation  http://data.europa.eu/esco/occupation/a7594892...
# 163    ISCOGroup               http://data.europa.eu/esco/isco/C263
# 719    ISCOGroup              http://data.europa.eu/esco/isco/C7231
# 10     ISCOGroup                http://data.europa.eu/esco/isco/C11
# 504    ISCOGroup               http://data.europa.eu/esco/isco/C811
# broaderRelationsSkillPillar_en.csv
#                     conceptType  \
# 18935  KnowledgeSkillCompetence
# 16946  KnowledgeSkillCompetence
# 12518  KnowledgeSkillCompetence
# 3047   KnowledgeSkillCompetence
# 19205  KnowledgeSkillCompetence
#
#                                               conceptUri  \
# 18935  http://data.europa.eu/esco/skill/bd3df39b-3693...
# 16946  http://data.europa.eu/esco/skill/6e34b68e-0d61...
# 12518  http://data.europa.eu/esco/skill/e2d44a9b-f28c...
# 3047   http://data.europa.eu/esco/skill/2d3552aa-08da...
# 19205  http://data.europa.eu/esco/skill/c74eb35b-f9ed...
#
#                     broaderType  \
# 18935  KnowledgeSkillCompetence
# 16946  KnowledgeSkillCompetence
# 12518                SkillGroup
# 3047                 SkillGroup
# 19205  KnowledgeSkillCompetence
#
#                                               broaderUri
# 18935  http://data.europa.eu/esco/skill/05cddb12-85c8...
# 16946  http://data.europa.eu/esco/skill/7dd94ad3-13d6...
# 12518  http://data.europa.eu/esco/skill/fe5eabaa-63f6...
# 3047   http://data.europa.eu/esco/skill/e4da156d-a6c4...
# 19205  http://data.europa.eu/esco/skill/329d7233-7231...
# conceptSchemes_en.csv
#       conceptType                                   conceptSchemeUri  \
# 14  ConceptScheme  http://data.europa.eu/esco/concept-scheme/skil...
# 6   ConceptScheme  http://data.europa.eu/esco/concept-scheme/labe...
# 2   ConceptScheme  http://data.europa.eu/esco/concept-scheme/digcomp
# 17  ConceptScheme   http://data.europa.eu/esco/concept-scheme/skills
# 5   ConceptScheme     http://data.europa.eu/esco/concept-scheme/isco
#
#       preferredLabel title    status  \
# 14          Language   NaN  released
# 6   ESCO label roles   NaN       NaN
# 2            DigComp   NaN  released
# 17       ESCO skills   NaN  released
# 5          ISCO 2008   NaN  released
#
#                                          description  \
# 14                                               NaN
# 6    A taxonomy of the different label roles in ESCO
# 2                                                NaN
# 17  A taxonomy of the skills and competences in ESCO
# 5                                                NaN
#
#                                         hasTopConcept
# 14  http://data.europa.eu/esco/skill/8ee2b6f2-7017...
# 6   http://data.europa.eu/esco/label-role/male,\nh...
# 2   http://data.europa.eu/esco/skill/7e5147d1-60b1...
# 17  http://data.europa.eu/esco/skill/e35a5936-091d...
# 5   http://data.europa.eu/esco/isco/C7,\nhttp://da...
# digCompSkillsCollection_en.csv
#                  conceptType  \
# 21  KnowledgeSkillCompetence
# 6   KnowledgeSkillCompetence
# 11  KnowledgeSkillCompetence
# 24  KnowledgeSkillCompetence
# 3   KnowledgeSkillCompetence
#
#                                            conceptUri  \
# 21  http://data.europa.eu/esco/skill/c4ba12d1-4698...
# 6   http://data.europa.eu/esco/skill/2b34a99f-9813...
# 11  http://data.europa.eu/esco/skill/4d97e3c3-f335...
# 24  http://data.europa.eu/esco/skill/e439742d-558d...
# 3   http://data.europa.eu/esco/skill/1d6c7de4-350e...
#
#                                        preferredLabel    status  \
# 21  protect the environment from the impact of the...  released
# 6            collaborate through digital technologies  released
# 11       manage data, information and digital content  released
# 24  browse, search and filter data, information an...  released
# 3      evaluate data, information and digital content  released
#
#            skillType    reuseLevel  \
# 21  skill/competence  cross-sector
# 6   skill/competence  cross-sector
# 11  skill/competence  cross-sector
# 24  skill/competence  cross-sector
# 3   skill/competence  cross-sector
#
#                                             altLabels  \
# 21  protect the environment from the impact of the...
# 6   able to use online tools to collaborate | util...
# 11       manage data, information and digital content
# 24  browse, search and filter data, information an...
# 3      evaluate data, information and digital content
#
#                                           description  \
# 21  Be aware of the environmental impact of digita...
# 6   Use digital tools and technologies for collabo...
# 11  Organise, store and retrieve data, information...
# 24  Articulate information needs, search for data,...
# 3   Analyse, compare and critically evaluate the c...
#
#                                     broaderConceptUri  \
# 21  http://data.europa.eu/esco/skill/8064ae65-5d1b...
# 6   http://data.europa.eu/esco/skill/98fb499f-9155...
# 11  http://data.europa.eu/esco/skill/32c017fd-28ab...
# 24  http://data.europa.eu/esco/skill/629685b8-5f9e...
# 3   http://data.europa.eu/esco/skill/629685b8-5f9e...
#
#                                      broaderConceptPT
# 21  complying with environmental protection laws a...
# 6   using digital tools for collaboration and prod...
# 11     managing information | digital data processing
# 24  digital data processing | browsing, searching ...
# 3   digital data processing | analysing and evalua...
# digitalSkillsCollection_en.csv
#                    conceptType  \
# 430   KnowledgeSkillCompetence
# 999   KnowledgeSkillCompetence
# 786   KnowledgeSkillCompetence
# 1019  KnowledgeSkillCompetence
# 818   KnowledgeSkillCompetence
#
#                                              conceptUri  \
# 430   http://data.europa.eu/esco/skill/5da42cfd-1da8...
# 999   http://data.europa.eu/esco/skill/d70cab7b-ad8c...
# 786   http://data.europa.eu/esco/skill/a8d07b5a-c1a1...
# 1019  http://data.europa.eu/esco/skill/db36f7f1-5900...
# 818   http://data.europa.eu/esco/skill/b080a008-a35d...
#
#                                     preferredLabel    status  \
# 430                                virtual reality  released
# 999          maintain media integration equipment   released
# 786                                     PostgreSQL  released
# 1019                      support ICT system users  released
# 818   use communication and collaboration software  released
#
#              skillType           reuseLevel  \
# 430          knowledge         cross-sector
# 999   skill/competence  occupation-specific
# 786          knowledge      sector-specific
# 1019  skill/competence      sector-specific
# 818   skill/competence          transversal
#
#                                               altLabels  \
# 430                                                 NaN
# 999                                                 NaN
# 786                               Postgres | PostgreSQL
# 1019  staff support | support ICT system users | use...
# 818   communicate in digital environments | communic...
#
#                                             description  \
# 430   The process of simulating real-life experience...
# 999   Check and repair media integration equipment a...
# 786   The computer program PostgreSQL is a free and ...
# 1019  Communicate with end users, instruct them on h...
# 818   Use simple digital tools and technologies for ...
#
#                                       broaderConceptUri  \
# 430             http://data.europa.eu/esco/isced-f/0619
# 999   http://data.europa.eu/esco/skill/ec0401f1-f690...
# 786   http://data.europa.eu/esco/isced-f/0612 | http...
# 1019  http://data.europa.eu/esco/skill/6c4fa8c8-e9e1...
# 818   http://data.europa.eu/esco/skill/3399045f-8078...
#
#                                        broaderConceptPT
# 430   information and communication technologies not...
# 999   maintaining electrical, electronic and precisi...
# 786   database and network design and administration...
# 1019  training on operational procedures | instruct ...
# 818       working with digital devices and applications
# greenSkillsCollection_en.csv
#                   conceptType  \
# 302  KnowledgeSkillCompetence
# 421  KnowledgeSkillCompetence
# 209  KnowledgeSkillCompetence
# 445  KnowledgeSkillCompetence
# 79   KnowledgeSkillCompetence
#
#                                             conceptUri  \
# 302  http://data.europa.eu/esco/skill/7afd29d7-9c9f...
# 421  http://data.europa.eu/esco/skill/b7a26b32-c457...
# 209  http://data.europa.eu/esco/skill/50e6eba0-4440...
# 445  http://data.europa.eu/esco/skill/c3bb5700-a94d...
# 79   http://data.europa.eu/esco/skill/215d64d0-a698...
#
#                                preferredLabel    status         skillType  \
# 302  apply transportation management concepts  released  skill/competence
# 421                    maintain wind turbines  released  skill/competence
# 209                          hydroelectricity  released         knowledge
# 445              urban pollution implications  released         knowledge
# 79                develop forestry strategies  released  skill/competence
#
#           reuseLevel                                          altLabels  \
# 302  sector-specific  apply transportation management concepts | imp...
# 421  sector-specific                               repair wind turbines
# 209     cross-sector  hydropower electricity | hydro-power electrici...
# 445  sector-specific  science of urban pollution implications | impa...
# 79   sector-specific  forestry plans developing | develop forestry p...
#
#                                            description  \
# 302  Apply transport industry management concepts i...
# 421  Perform all required activities to maintain th...
# 209  The generation of electrical power through the...
# 445  Collection of pollutants created by cities and...
# 79   Build up forestry policies in order to enhance...
#
#                                      broaderConceptUri  \
# 302  http://data.europa.eu/esco/skill/58bd927f-e4cc...
# 421  http://data.europa.eu/esco/skill/ec0401f1-f690...
# 209            http://data.europa.eu/esco/isced-f/0713
# 445            http://data.europa.eu/esco/isced-f/0712
# 79   http://data.europa.eu/esco/skill/7a8fb784-67fa...
#
#                                       broaderConceptPT
# 302  following instructions and procedures | manage...
# 421  maintaining electrical, electronic and precisi...
# 209                             electricity and energy
# 445                environmental protection technology
# 79   develop strategy to solve problems | developin...
# ISCOGroups_en.csv
#     conceptType                             conceptUri  code  \
# 429   ISCOGroup  http://data.europa.eu/esco/isco/C7113  7113
# 319   ISCOGroup  http://data.europa.eu/esco/isco/C4311  4311
# 325   ISCOGroup  http://data.europa.eu/esco/isco/C4323  4323
# 211   ISCOGroup  http://data.europa.eu/esco/isco/C3151  3151
# 152   ISCOGroup  http://data.europa.eu/esco/isco/C2521  2521
#
#                                         preferredLabel    status  altLabels  \
# 429  Stonemasons, stone cutters, splitters and carvers  released        NaN
# 319                  Accounting and bookkeeping clerks  released        NaN
# 325                                   Transport clerks  released        NaN
# 211                                   Ships’ engineers  released        NaN
# 152              Database designers and administrators  released        NaN
#
#                                               inScheme  \
# 429  http://data.europa.eu/esco/concept-scheme/occu...
# 319  http://data.europa.eu/esco/concept-scheme/occu...
# 325  http://data.europa.eu/esco/concept-scheme/isco...
# 211  http://data.europa.eu/esco/concept-scheme/occu...
# 152  http://data.europa.eu/esco/concept-scheme/occu...
#
#                                            description
# 429  Stonemasons, stone cutters, splitters and carv...
# 319  Accounting and bookkeeping clerks compute, cla...
# 325  Transport clerks keep records of operational a...
# 211  Ships’ engineers control and participate in th...
# 152  Database designers and administrators design, ...
# languageSkillsCollection_en.csv
#                   conceptType  \
# 104  KnowledgeSkillCompetence
# 220  KnowledgeSkillCompetence
# 56   KnowledgeSkillCompetence
# 93   KnowledgeSkillCompetence
# 54   KnowledgeSkillCompetence
#
#                                             conceptUri         skillType  \
# 104  http://data.europa.eu/esco/skill/4c5a2793-c18d...  skill/competence
# 220  http://data.europa.eu/esco/skill/a88e4c9e-5a40...  skill/competence
# 56   http://data.europa.eu/esco/skill/237420c1-1882...  skill/competence
# 93   http://data.europa.eu/esco/skill/42b7c03a-3ed5...  skill/competence
# 54   http://data.europa.eu/esco/skill/227accd5-5e70...  skill/competence
#
#       reuseLevel                preferredLabel    status  \
# 104  transversal               write Icelandic  released
# 220  transversal  understand written Hungarian  released
# 56   transversal  understand spoken Vietnamese  released
# 93   transversal                  write Danish  released
# 54   transversal   interact verbally in Arabic  released
#
#                                              altLabels  \
# 104  show competency in written Icelandic | writing...
# 220  read Hungarian | interpret written Hungarian |...
# 56   listen to Vietnamese | understanding spoken Vi...
# 93   correspond in written Danish | write Danish | ...
# 54   interact verbally in Arabic | interacting verb...
#
#                                          description  \
# 104              Compose written texts in Icelandic.
# 220  Read and comprehend written texts in Hungarian.
# 56           Comprehend orally expressed Vietnamese.
# 93                  Compose written texts in Danish.
# 54                     Communicate orally in Arabic.
#
#                                      broaderConceptUri broaderConceptPT
# 104  http://data.europa.eu/esco/skill/a18e3090-6afb...        Icelandic
# 220  http://data.europa.eu/esco/skill/ddd3596a-43f3...        Hungarian
# 56   http://data.europa.eu/esco/skill/bf60009d-8afb...       Vietnamese
# 93   http://data.europa.eu/esco/skill/273a28d6-1bd3...           Danish
# 54   http://data.europa.eu/esco/skill/33859d93-987c...           Arabic
# occupationSkillRelations_en.csv
#                                             occupationUri relationType  \
# 10626   http://data.europa.eu/esco/occupation/15419750...    essential
# 93520   http://data.europa.eu/esco/occupation/bc1c82a5...    essential
# 50380   http://data.europa.eu/esco/occupation/6474e4d4...    essential
# 105234  http://data.europa.eu/esco/occupation/d3570716...     optional
# 95074   http://data.europa.eu/esco/occupation/be235deb...    essential
#
#                skillType                                           skillUri
# 10626          knowledge  http://data.europa.eu/esco/skill/ec7fd241-e68f...
# 93520   skill/competence  http://data.europa.eu/esco/skill/a98c21d7-c106...
# 50380   skill/competence  http://data.europa.eu/esco/skill/49026711-0f2d...
# 105234  skill/competence  http://data.europa.eu/esco/skill/e1f09038-b493...
# 95074   skill/competence  http://data.europa.eu/esco/skill/14d88fae-ead0...
# occupations_en.csv
#      conceptType                                         conceptUri  \
# 158   Occupation  http://data.europa.eu/esco/occupation/0c7c9606...
# 550   Occupation  http://data.europa.eu/esco/occupation/2c027db0...
# 1378  Occupation  http://data.europa.eu/esco/occupation/70b5896f...
# 923   Occupation  http://data.europa.eu/esco/occupation/4b72d306...
# 1030  Occupation  http://data.europa.eu/esco/occupation/53d55c80...
#
#       iscoGroup                            preferredLabel  \
# 158        2152                   medical device engineer
# 550        5165                vessel steering instructor
# 1378       2642                         sports journalist
# 923        3324       non-vessel operating common carrier
# 1030       8153  leather goods stitching machine operator
#
#                                               altLabels hiddenLabels  \
# 158   engineer in biomedical systems\nengineer of me...          NaN
# 550   vessel steering teacher\nmarine vessel captain...          NaN
# 1378  sports journalist\nradio sports journalist\nsp...          NaN
# 923   shipment consolidator\nfreight forwarder\nnon-...          NaN
# 1030           leather goods stitching machine operator          NaN
#
#         status              modifiedDate  \
# 158   released  2022-07-05T14:40:09.218Z
# 550   released  2021-06-09T08:28:22.525Z
# 1378  released      2016-07-05T13:47:34Z
# 923   released      2016-12-20T14:06:34Z
# 1030  released  2020-08-03T10:35:53.529Z
#
#                                 regulatedProfessionNote  \
# 158   http://data.europa.eu/esco/regulated-professio...
# 550   http://data.europa.eu/esco/regulated-professio...
# 1378  http://data.europa.eu/esco/regulated-professio...
# 923   http://data.europa.eu/esco/regulated-professio...
# 1030  http://data.europa.eu/esco/regulated-professio...
#
#                                               scopeNote definition  \
# 158   Includes people working in hospitals. \n Inclu...        NaN
# 550                                                 NaN        NaN
# 1378      Includes people working in live sport events.        NaN
# 923                                                 NaN        NaN
# 1030  Includes joining, decorating and reinforcing p...        NaN
#
#                                                inScheme  \
# 158   http://data.europa.eu/esco/concept-scheme/memb...
# 550   http://data.europa.eu/esco/concept-scheme/occu...
# 1378  http://data.europa.eu/esco/concept-scheme/memb...
# 923   http://data.europa.eu/esco/concept-scheme/occu...
# 1030  http://data.europa.eu/esco/concept-scheme/occu...
#
#                                             description       code
# 158   Medical device engineers design and develop me...   2152.1.5
# 550   Vessel steering instructors teach people the t...     5165.2
# 1378  Sports journalists research and write articles...  2642.1.16
# 923   Non-vessel operating common carriers (NVOCC) a...     3324.3
# 1030  Leather goods stitching machine operators join...   8153.1.4
# researchOccupationsCollection_en.csv
#     conceptType                                         conceptUri  \
# 31   Occupation  http://data.europa.eu/esco/occupation/49023c69...
# 47   Occupation  http://data.europa.eu/esco/occupation/6140be85...
# 117  Occupation  http://data.europa.eu/esco/occupation/f3d8bc61...
# 52   Occupation  http://data.europa.eu/esco/occupation/6cd08cbe...
# 107  Occupation  http://data.europa.eu/esco/occupation/c8fa93eb...
#
#               preferredLabel    status  \
# 31   communications lecturer  released
# 47                geneticist  released
# 117         literary scholar  released
# 52   communication scientist  released
# 107            test engineer  released
#
#                                              altLabels  \
# 31   lecturer in communication and media | communic...
# 47   genetics engineer | genetics research scientis...
# 117  literary studies scholar | literary researcher...
# 52   communication studies research analyst | commu...
# 107  agricultural equipment test engineer | test en...
#
#                                            description  \
# 31   Communications lecturers are subject professor...
# 47   Geneticists study and focus their research on ...
# 117  Literary scholars research works of literature...
# 52   Communication scientists research the differen...
# 107  Test engineers plan and perform detailed quali...
#
#                                      broaderConceptUri  \
# 31   http://data.europa.eu/esco/occupation/684fd8d5...
# 47   http://data.europa.eu/esco/occupation/eee68e13...
# 117              http://data.europa.eu/esco/isco/C2641
# 52   http://data.europa.eu/esco/occupation/acf69cab...
# 107              http://data.europa.eu/esco/isco/C2149
#
#                                       broaderConceptPT
# 31                           higher education lecturer
# 47                                           biologist
# 117                        Authors and related writers
# 52                                      anthropologist
# 107  Engineering professionals not elsewhere classi...
# researchSkillsCollection_en.csv
#                  conceptType  \
# 18  KnowledgeSkillCompetence
# 20  KnowledgeSkillCompetence
# 6   KnowledgeSkillCompetence
# 26  KnowledgeSkillCompetence
# 1   KnowledgeSkillCompetence
#
#                                            conceptUri  \
# 18  http://data.europa.eu/esco/skill/7dd94ad3-13d6...
# 20  http://data.europa.eu/esco/skill/872a1632-f1db...
# 6   http://data.europa.eu/esco/skill/39f67488-cfd3...
# 26  http://data.europa.eu/esco/skill/a8d24a95-47b3...
# 1   http://data.europa.eu/esco/skill/08b04e53-ed25...
#
#                               preferredLabel    status         skillType  \
# 18                          think critically  released  skill/competence
# 20       promote open innovation in research  released  skill/competence
# 6               evaluate research activities  released  skill/competence
# 26  manage personal professional development  released  skill/competence
# 1                       manage research data  released  skill/competence
#
#       reuseLevel                                          altLabels  \
# 18   transversal  weigh information | assess information | check...
# 20  cross-sector       promote integrated collaboration in research
# 6   cross-sector  assess research results | assess research meth...
# 26  cross-sector  develop own practice continuously | research o...
# 1   cross-sector                                                NaN
#
#                                           description  \
# 18  Make and defend judgements based on internal e...
# 20  Apply techniques, models, methods and strategi...
# 6   Review proposals, progress, impact and outcome...
# 26  Take responsibility for lifelong learning and ...
# 1   Produce and analyse scientific data originatin...
#
#                                     broaderConceptUri  \
# 18  http://data.europa.eu/esco/skill/fff1d675-c36a...
# 20  http://data.europa.eu/esco/skill/7eafec38-621a...
# 6   http://data.europa.eu/esco/skill/23cfb269-eec1...
# 26  http://data.europa.eu/esco/skill/7e0b93e0-0de7...
# 1   http://data.europa.eu/esco/skill/32c017fd-28ab...
#
#                                      broaderConceptPT
# 18         processing information, ideas and concepts
# 20             conducting academic or market research
# 6                                     giving feedback
# 26  developing educational programmes | manage per...
# 1                                managing information
# skillGroups_en.csv
#     conceptType                                         conceptUri  \
# 39   SkillGroup             http://data.europa.eu/esco/isced-f/023
# 344  SkillGroup  http://data.europa.eu/esco/skill/47aa582a-3edb...
# 379  SkillGroup  http://data.europa.eu/esco/skill/5f92ff3e-288b...
# 156  SkillGroup            http://data.europa.eu/esco/isced-f/0819
# 19   SkillGroup             http://data.europa.eu/esco/isced-f/018
#
#                                         preferredLabel altLabels hiddenLabels  \
# 39                                           languages       NaN          NaN
# 344                                   testing vehicles       NaN          NaN
# 379       styling hair and providing beauty treatments       NaN          NaN
# 156               agriculture not elsewhere classified       NaN          NaN
# 19   inter-disciplinary programmes and qualificatio...       NaN          NaN
#
#        status              modifiedDate  \
# 39   released                       NaN
# 344  released  2022-06-19T15:45:14.266Z
# 379  released                       NaN
# 156  released                       NaN
# 19   released  2022-01-13T14:49:36.928Z
#
#                                              scopeNote  \
# 39                                                 NaN
# 344                                                NaN
# 379  Examples:\n- apply nail polish\n- use hair rem...
# 156                                                NaN
# 19                                                 NaN
#
#                                               inScheme  \
# 39   http://data.europa.eu/esco/concept-scheme/isce...
# 344  http://data.europa.eu/esco/concept-scheme/skil...
# 379  http://data.europa.eu/esco/concept-scheme/skil...
# 156  http://data.europa.eu/esco/concept-scheme/skil...
# 19   http://data.europa.eu/esco/concept-scheme/isce...
#
#                                            description     code
# 39                                                 NaN      NaN
# 344  Inspecting vehicles and other heavy machinery ...  S2.8.11
# 379  Grooming, styling or removing hair, applying m...   S3.6.4
# 156                                                NaN      NaN
# 19                                                 NaN      NaN
# skillsHierarchy_en.csv
#                                            Level 0 URI  \
# 12   http://data.europa.eu/esco/skill/04a13491-b58c...
# 246  http://data.europa.eu/esco/skill/335228d2-297d...
# 253  http://data.europa.eu/esco/skill/335228d2-297d...
# 483  http://data.europa.eu/esco/skill/c46fcb45-5c14...
# 153  http://data.europa.eu/esco/skill/335228d2-297d...
#
#                  Level 0 preferred term  \
# 12   transversal skills and competences
# 246                              skills
# 253                              skills
# 483                           knowledge
# 153                              skills
#
#                                            Level 1 URI  \
# 12   http://data.europa.eu/esco/skill/4ef78abc-e983...
# 246  http://data.europa.eu/esco/skill/869fc2ce-478f...
# 253  http://data.europa.eu/esco/skill/9b8bb484-dcba...
# 483              http://data.europa.eu/esco/isced-f/03
# 153  http://data.europa.eu/esco/skill/0a2d70ee-d435...
#
#                                Level 1 preferred term  \
# 12                        life skills and competences
# 246                                 management skills
# 253  working with machinery and specialised equipment
# 483       social sciences, journalism and information
# 153                                information skills
#
#                                            Level 2 URI  \
# 12                                                 NaN
# 246  http://data.europa.eu/esco/skill/f306bf2a-271d...
# 253  http://data.europa.eu/esco/skill/2198d7a0-6eca...
# 483             http://data.europa.eu/esco/isced-f/031
# 153  http://data.europa.eu/esco/skill/dddd229b-61e1...
#
#                                 Level 2 preferred term  \
# 12                                                 NaN
# 246               performing administrative activities
# 253  operating machinery for the extraction and pro...
# 483                    social and behavioural sciences
# 153                               managing information
#
#                                            Level 3 URI  \
# 12                                                 NaN
# 246  http://data.europa.eu/esco/skill/c20ac175-3aab...
# 253                                                NaN
# 483            http://data.europa.eu/esco/isced-f/0314
# 153  http://data.europa.eu/esco/skill/32c017fd-28ab...
#
#                Level 3 preferred term  \
# 12                                NaN
# 246  executing financial transactions
# 253                               NaN
# 483    sociology and cultural studies
# 153              managing information
#
#                                            Description  \
# 12   Skills and competences relating to the ability...
# 246  Executing financial or commercial transactions...
# 253  Operating and monitoring various types of mech...
# 483  Sociology and cultural studies is the study of...
# 153  Setting up and managing manual or electronic s...
#
#                                             Scope note Level 0 code  \
# 12                                                 NaN            T
# 246  Examples:\n- issue sales invoices\n- operate c...            S
# 253  Excludes:\n- Operating centralized process con...            S
# 483                                                NaN            K
# 153  Examples:\n- Manage digital archives\n- Overse...            S
#
#     Level 1 code Level 2 code Level 3 code
# 12            T6          NaN          NaN
# 246           S4         S4.4       S4.4.2
# 253           S8         S8.4          NaN
# 483          NaN          NaN          NaN
# 153           S2         S2.3       S2.3.0
# skillSkillRelations_en.csv
#                                        originalSkillUri originalSkillType  \
# 2514  http://data.europa.eu/esco/skill/6b4bff9e-11e7...  skill/competence
# 1753  http://data.europa.eu/esco/skill/4ae00a8e-9f47...  skill/competence
# 4093  http://data.europa.eu/esco/skill/af76c813-5c7f...  skill/competence
# 3492  http://data.europa.eu/esco/skill/93b7c809-f6a2...  skill/competence
# 3176  http://data.europa.eu/esco/skill/87454307-a3ad...  skill/competence
#
#      relationType  relatedSkillType  \
# 2514    essential  skill/competence
# 1753     optional         knowledge
# 4093     optional         knowledge
# 3492     optional         knowledge
# 3176     optional         knowledge
#
#                                         relatedSkillUri
# 2514  http://data.europa.eu/esco/skill/c624c6a3-b0ba...
# 1753  http://data.europa.eu/esco/skill/a88c4bdc-73f8...
# 4093  http://data.europa.eu/esco/skill/324f0243-1a21...
# 3492  http://data.europa.eu/esco/skill/b4195435-179b...
# 3176  http://data.europa.eu/esco/skill/267a2f67-f526...
# skills_en.csv
#                     conceptType  \
# 1994   KnowledgeSkillCompetence
# 5132   KnowledgeSkillCompetence
# 13298  KnowledgeSkillCompetence
# 8487   KnowledgeSkillCompetence
# 645    KnowledgeSkillCompetence
#
#                                               conceptUri         skillType  \
# 1994   http://data.europa.eu/esco/skill/24ec34dc-62e9...         knowledge
# 5132   http://data.europa.eu/esco/skill/5d805ae9-0d48...  skill/competence
# 13298  http://data.europa.eu/esco/skill/f5750c05-7b15...  skill/competence
# 8487   http://data.europa.eu/esco/skill/9ae3d44d-38c5...  skill/competence
# 645    http://data.europa.eu/esco/skill/0c452783-8873...  skill/competence
#
#                 reuseLevel                                     preferredLabel  \
# 1994       sector-specific                              young horses training
# 5132   occupation-specific  make recommendation on nutrition to public pol...
# 13298  occupation-specific                              operate machine tools
# 8487   occupation-specific                                   operate nail gun
# 645        sector-specific                                 draw prop sketches
#
#                                                altLabels hiddenLabels  \
# 1994   training young horse\ntraining young horses\ny...          NaN
# 5132   make suggestions on nutrition to public policy...          NaN
# 13298  operating machine tools\noperate machine tools...          NaN
# 8487   operate nail guns\nuse nail gun\nhandle nail g...          NaN
# 645    draw and sketch props\ndraw sketches of props\...          NaN
#
#          status              modifiedDate scopeNote definition  \
# 1994   released  2021-12-08T21:58:24.732Z       NaN        NaN
# 5132   released      2016-12-20T19:32:33Z       NaN        NaN
# 13298  released  2022-07-05T14:38:14.433Z       NaN        NaN
# 8487   released      2016-12-20T21:24:38Z       NaN        NaN
# 645    released      2016-12-20T17:49:55Z       NaN        NaN
#
#                                                 inScheme  \
# 1994   http://data.europa.eu/esco/concept-scheme/memb...
# 5132   http://data.europa.eu/esco/concept-scheme/memb...
# 13298  http://data.europa.eu/esco/concept-scheme/memb...
# 8487   http://data.europa.eu/esco/concept-scheme/memb...
# 645    http://data.europa.eu/esco/concept-scheme/skil...
#
#                                              description
# 1994   Principles and techiques of educating young ho...
# 5132   Advise public policy makers on nutrition-relat...
# 13298  Program and operate numerically controlled mac...
# 8487   Use a mechanical tool to fasten parts together...
# 645    Make sketches of envisioned props to help deve...
# transversalSkillsCollection_en.csv
#                  conceptType  \
# 36  KnowledgeSkillCompetence
# 48  KnowledgeSkillCompetence
# 9   KnowledgeSkillCompetence
# 66  KnowledgeSkillCompetence
# 74  KnowledgeSkillCompetence
#
#                                            conceptUri         skillType  \
# 36  http://data.europa.eu/esco/skill/699e7c26-6502...  skill/competence
# 48  http://data.europa.eu/esco/skill/7f321b88-3d16...  skill/competence
# 9   http://data.europa.eu/esco/skill/19a64e91-bfe3...  skill/competence
# 66  http://data.europa.eu/esco/skill/b6bdf202-524f...  skill/competence
# 74  http://data.europa.eu/esco/skill/c10d5d87-36cf...  skill/competence
#
#      reuseLevel                                    preferredLabel    status  \
# 36  transversal                                   instruct others  released
# 48  transversal  engage others in environment friendly behaviours  released
# 9   transversal                                show determination  released
# 66  transversal                                      move objects  released
# 74  transversal              demonstrate intercultural competence  released
#
#                                             altLabels  \
# 36  train others | instruct others | instruct coll...
# 48  inform about sustainability | promote sustaina...
# 9   strive for success | make an effort | demonstr...
# 66  store goods | climb | lift things | move and l...
# 74  display intercultural competence | show interc...
#
#                                           description  \
# 36  Guide or teach others by providing relevant kn...
# 48  Inform about and promote environmental friendl...
# 9   Show commitment to do something that is diffic...
# 66  Perform physical activities to move, load, unl...
# 74  Understand and respect people who are perceive...
#
#                                     broaderConceptUri  \
# 36  http://data.europa.eu/esco/skill/82463bb1-85d1...
# 48  http://data.europa.eu/esco/skill/80cf002a-6586...
# 9   http://data.europa.eu/esco/skill/91860993-1a8b...
# 66  http://data.europa.eu/esco/skill/ccb6db6a-8538...
# 74  http://data.europa.eu/esco/skill/036afa6e-cdde...
#
#                                      broaderConceptPT
# 36                                  supporting others
# 48      applying environmental skills and competences
# 9                         taking a proactive approach
# 66  manipulating and controlling objects and equip...
# 74                collaborating in teams and networks

# %%
dfs[files.index("skillGroups_en.csv")]
# Out:
#     conceptType                                         conceptUri  \
# 0    SkillGroup              http://data.europa.eu/esco/isced-f/00
# 1    SkillGroup             http://data.europa.eu/esco/isced-f/000
# 2    SkillGroup            http://data.europa.eu/esco/isced-f/0000
# 3    SkillGroup             http://data.europa.eu/esco/isced-f/001
# 4    SkillGroup            http://data.europa.eu/esco/isced-f/0011
# ..          ...                                                ...
# 635  SkillGroup  http://data.europa.eu/esco/skill/fbb861f7-2386...
# 636  SkillGroup  http://data.europa.eu/esco/skill/fe317a4c-e4e0...
# 637  SkillGroup  http://data.europa.eu/esco/skill/fe5eabaa-63f6...
# 638  SkillGroup  http://data.europa.eu/esco/skill/ff565308-8f29...
# 639  SkillGroup  http://data.europa.eu/esco/skill/fff1d675-c36a...
#
#                                         preferredLabel  \
# 0                generic programmes and qualifications
# 1    generic programmes and qualifications not furt...
# 2    generic programmes and qualifications not furt...
# 3                  basic programmes and qualifications
# 4                  basic programmes and qualifications
# ..                                                 ...
# 635                            providing personal care
# 636                           protecting and enforcing
# 637                                     leading others
# 638                                handling and moving
# 639         processing information, ideas and concepts
#
#                                              altLabels  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 635                                      personal care
# 636                                                NaN
# 637                           demonstrating leadership
# 638                          handling goods or animals
# 639  processing of information\nprocessing quantita...
#
#                         hiddenLabels    status              modifiedDate  \
# 0                                NaN  released                       NaN
# 1                                NaN  released                       NaN
# 2                                NaN  released                       NaN
# 3                                NaN  released                       NaN
# 4                                NaN  released                       NaN
# ..                               ...       ...                       ...
# 635                              NaN  released                       NaN
# 636                              NaN  released                       NaN
# 637                       leadership  released  2021-08-30T16:33:15.592Z
# 638                              NaN  released                       NaN
# 639  using knowledge and information  released  2021-08-30T13:39:50.945Z
#
#                                              scopeNote  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 635  Excludes:\n- Administration of medical treatme...
# 636                                                NaN
# 637                                                NaN
# 638  Excludes:\n- Specific skills involving interac...
# 639                                                NaN
#
#                                               inScheme  \
# 0    http://data.europa.eu/esco/concept-scheme/isce...
# 1    http://data.europa.eu/esco/concept-scheme/skil...
# 2    http://data.europa.eu/esco/concept-scheme/skil...
# 3    http://data.europa.eu/esco/concept-scheme/skil...
# 4    http://data.europa.eu/esco/concept-scheme/isce...
# ..                                                 ...
# 635  http://data.europa.eu/esco/concept-scheme/skil...
# 636  http://data.europa.eu/esco/concept-scheme/skil...
# 637  http://data.europa.eu/esco/concept-scheme/skil...
# 638  http://data.europa.eu/esco/concept-scheme/skil...
# 639  http://data.europa.eu/esco/concept-scheme/skil...
#
#                                            description    code
# 0    Generic programmes and qualifications are thos...     NaN
# 1                                                  NaN     NaN
# 2                                                  NaN     NaN
# 3                                                  NaN     NaN
# 4    Basic programmes and qualifications are design...     NaN
# ..                                                 ...     ...
# 635  Responding to the daily and occasional persona...  S3.6.0
# 636  Responding to public and personal safety and s...  S3.3.0
# 637                 Guide, direct and motivate others.    T4.4
# 638  Sorting, arranging, moving, transforming, fabr...    S6.0
# 639  Evaluate, input, record, transcribe and update...    T2.1
#
# [640 rows x 11 columns]

# %% [markdown]
# ## ESCO processing

# %%
esco = pd.read_csv(ESCO_DIR + "skills_en.csv")
print(len(esco)) #13896
esco = esco[['conceptUri', 'preferredLabel',  'altLabels', 'description']]

relationskill = pd.read_csv(ESCO_DIR + "broaderRelationsSkillPillar_en.csv")
skillshierarchy = pd.read_csv(ESCO_DIR + "skillsHierarchy_en.csv")

esco.head()
# Out:
# 13896
#                                           conceptUri  \
# 0  http://data.europa.eu/esco/skill/0005c151-5b5a...
# 1  http://data.europa.eu/esco/skill/00064735-8fad...
# 2  http://data.europa.eu/esco/skill/000709ed-2be5...
# 3  http://data.europa.eu/esco/skill/0007bdc2-dd15...
# 4  http://data.europa.eu/esco/skill/00090cc1-1f27...
#
#                                       preferredLabel  \
# 0                               manage musical staff
# 1                  supervise correctional procedures
# 2                    apply anti-oppressive practices
# 3  control compliance of railway vehicles regulat...
# 4                        identify available services
#
#                                            altLabels  \
# 0  manage staff of music\ncoordinate duties of mu...
# 1  oversee prison procedures\nmanage correctional...
# 2  apply non-oppressive practices\napply an anti-...
# 3  monitoring of compliance with railway vehicles...
# 4  establish available services\nidentify availab...
#
#                                          description
# 0  Assign and manage staff tasks in areas such as...
# 1  Supervise the operations of a correctional fac...
# 2  Identify oppression in societies, economies, c...
# 3  Inspect rolling stock, components and systems ...
# 4  Identify the different services available for ...

# %%
uriwhitelist = ['http://data.europa.eu/esco/isced-f/06', ## K: Information and Communication Technologies
                'http://data.europa.eu/esco/skill/c1a13ee0-b00d-4cfa-a22c-20d284e398b0', ## management skills S4.0
                'http://data.europa.eu/esco/skill/6f89dcbe-4315-4533-8801-3aadf9190b86', ## Developing objectives and strategies S4.1
                'http://data.europa.eu/esco/skill/ce17a874-b476-491d-a7a7-5f05d32ad542', ## Leading and motitvating S4.5 
                'http://data.europa.eu/esco/skill/7a00c77c-4a1c-4fd6-a83f-004bda65d81a', ## Supervising people S4.8
                'http://data.europa.eu/esco/skill/bb99a123-88be-42a2-8758-f5a18e06ccc6', ## Making decision S4.9
                'http://data.europa.eu/esco/skill/243eb885-07c7-4b77-ab9c-827551d83dc4', ## Working with computer S5
                'http://data.europa.eu/esco/skill/8267ecb5-c976-4b6a-809b-4ceecb954967', ## Thinking skills and Competences T2
                'http://data.europa.eu/esco/skill/7eafec38-621a-4b6e-9298-bfe70ec0b253', ## Information skills S2.1.1 conducting academic or market research 
                'http://data.europa.eu/esco/skill/587e1cd6-a376-4c8f-8369-187c128d72a3', ## Information skills S2.4 processing information  
                'http://data.europa.eu/esco/skill/dddd229b-61e1-480d-80d6-d9d9ee9b5f54', ## Information skills S2.4 managing information
                'http://data.europa.eu/esco/skill/3753e796-121e-46a3-9c27-dee31ce92c80', ## Information skills S2.7 analysing and evaluating information and data 
                'http://data.europa.eu/esco/skill/1e95cef2-9c35-4f9f-b6a9-cb458c3e5379', ## Information skills S2.8 monitoring, inspecting and testing
                'http://data.europa.eu/esco/skill/85b379e7-e0b7-48b8-baa7-631f50a7cdd5', ## S1.0 communication, collaboration and creativity 
                'http://data.europa.eu/esco/skill/3f641516-9846-4a7f-a7f4-e1274eef6688', ## S1.4 presenting information
                'http://data.europa.eu/esco/skill/548c3fbe-9eb1-4035-bc54-027fd5bc5315', ## S1.8 working with others
        ] #+ list(dfs[files.index("digitalSkillsCollection_en.csv")]["broaderConceptUri"].apply(lambda x : x.split(" | ")).explode().unique()) ## in digitalSkillsCollection_en.csv

relationskill1 = relationskill[relationskill['conceptUri'].isin(uriwhitelist)]
print("Number of ConceptURI dans la liste > ", len(relationskill1)) 
relationskill2 = relationskill[relationskill['broaderUri'].isin(uriwhitelist)]
print(len(relationskill2)) # 2: conceptUri = http://data.europa.eu/esco/isced-f/061, http://data.europa.eu/esco/isced-f/068
esco1 = esco[esco['conceptUri'].isin(uriwhitelist)]
print("Number of matches in ESCO > ", len(esco1)) # 0
skillshierarchy1 = skillshierarchy[skillshierarchy['Level 0 URI'].isin(uriwhitelist)]
print("Number of matches in Level0 hierarchy = (S, K, T, L) > ", len(skillshierarchy1)) # 0
skillshierarchy2 = skillshierarchy[skillshierarchy['Level 1 URI'].isin(uriwhitelist)]
print("Number of matches in Level1 hierarchy = (Sn, Kn, Tn, Ln) > ", len(skillshierarchy2)) 
#
#  Level 0 URI = 'http://data.europa.eu/esco/skill/c46fcb45-5c14-4ffa-abed-5a43f104bb22'
# Level 2 URI = http://data.europa.eu/esco/isced-f/061, http://data.europa.eu/esco/isced-f/068
skillshierarchy3 = skillshierarchy[skillshierarchy['Level 2 URI'].isin(uriwhitelist)]
print("Number of matches in Level2 hierarchy = (Si.j, Ki.j, Ti.j, Li.j) > ", len(skillshierarchy3)) 
skillshierarchy4 = skillshierarchy[skillshierarchy['Level 3 URI'].isin(uriwhitelist)]
print("Number of matches in Level3 hierarchy = (Si.j.k, Ki.j.k, Ti.j.k, Li.j.k) > ", len(skillshierarchy3))
# Out:
# Number of ConceptURI dans la liste >  16
# 194
# Number of matches in ESCO >  0
# Number of matches in Level0 hierarchy = (S, K, T, L) >  0
# Number of matches in Level1 hierarchy = (Sn, Kn, Tn, Ln) >  36
# Number of matches in Level2 hierarchy = (Si.j, Ki.j, Ti.j, Li.j) >  61
# Number of matches in Level3 hierarchy = (Si.j.k, Ki.j.k, Ti.j.k, Li.j.k) >  61

# %%
print(len(esco[esco['conceptUri'].isin(list(relationskill['broaderUri']))]))
print(len(esco[esco['conceptUri'].isin(list(relationskill['conceptUri']))]))
for level in ['Level 0 URI', 'Level 1 URI', 'Level 2 URI', 'Level 3 URI']:
    print(f"Matching is ESCO conceptUri at level : {level.split(' ')[1]} > {len(esco[esco['conceptUri'].isin(list(skillshierarchy[level]))])}")
    print(f"Matching is ESCO broaderUri at level : {level.split(' ')[1]} > {len(esco[esco['conceptUri'].isin(list(skillshierarchy[level]))])}")
# esco['conceptUri'] looks like this: http://data.europa.eu/esco/skill/000f1d3d-220f...

# conclusion: esco['conceptUri'] are all in relationskill['conceptUri'] --> can deduce broaderURi

for level in ['Level 0 URI', 'Level 1 URI', 'Level 2 URI', 'Level 3 URI']:
    print(f"Matching in relation skill broaderUri at Level {level.split(' ')[1]} > {len(relationskill[relationskill['broaderUri'].isin(list(skillshierarchy[level]))])}")

# conclusion: the broaderUri mostly corresponds to skillshierarchy['Level 3 URI']

# the uritoexclude = 'http://data.europa.eu/esco/isced-f/06' is in skillshierarchy['Level 1 URI']
# The associated skillshierarchy['Level 3 URI'] are:
broaderskill_toexclude = []
for level in ['Level 0 URI', 'Level 1 URI', 'Level 2 URI', 'Level 3 URI']:
    broaderskill_toexclude += list(skillshierarchy[skillshierarchy[level].isin(uriwhitelist)]['Level 3 URI'])
print(broaderskill_toexclude)
skillshierarchy['Level 3 URI'] = skillshierarchy['Level 3 URI'].fillna('')
# these two lists are the same, so the pattern is right

# get conceptUri of broader skills to exclude:
conceptUri_toexclude = list(relationskill[relationskill['broaderUri'].isin(broaderskill_toexclude)]['conceptUri'])
print(len(conceptUri_toexclude))
esco_filtered = esco[esco['conceptUri'].isin(conceptUri_toexclude)]
print(len(esco_filtered)) # 2741
# Out:
# 2313
# 13896
# Matching is ESCO conceptUri at level : 0 > 0
# Matching is ESCO broaderUri at level : 0 > 0
# Matching is ESCO conceptUri at level : 1 > 0
# Matching is ESCO broaderUri at level : 1 > 0
# Matching is ESCO conceptUri at level : 2 > 0
# Matching is ESCO broaderUri at level : 2 > 0
# Matching is ESCO conceptUri at level : 3 > 0
# Matching is ESCO broaderUri at level : 3 > 0
# Matching in relation skill broaderUri at Level 0 > 28
# Matching in relation skill broaderUri at Level 1 > 229
# Matching in relation skill broaderUri at Level 2 > 633
# Matching in relation skill broaderUri at Level 3 > 13201
# ['', '', '', '', '', '', '', 'http://data.europa.eu/esco/skill/258fea29-09db-4918-8235-0d7d529cd31c', 'http://data.europa.eu/esco/skill/4d6a48ae-352e-4823-bc3a-3f3e9e2cae86', 'http://data.europa.eu/esco/skill/6a7fc30d-af16-4cc5-a957-29d174bdb61c', '', 'http://data.europa.eu/esco/skill/0b9968af-72de-470a-98e1-2d19577443fb', 'http://data.europa.eu/esco/skill/185c56ee-098f-46a1-af87-56337085da6f', 'http://data.europa.eu/esco/skill/24aa32e7-5b7c-42fd-b045-11f0c3d9b6e3', 'http://data.europa.eu/esco/skill/f839b1da-78b6-4466-86f4-a5798821ea20', '', 'http://data.europa.eu/esco/skill/494b8057-daf5-46a0-b33b-416e0115c30a', '', 'http://data.europa.eu/esco/skill/446a36a5-2376-439f-b46b-4a214ba0acdf', 'http://data.europa.eu/esco/skill/98fb499f-9155-412d-a8a0-95ba97126fec', 'http://data.europa.eu/esco/skill/b1115b14-fa16-4c1e-be6c-91fd49a1808b', 'http://data.europa.eu/esco/skill/c53a55a1-8b2b-4d2c-b12d-626742a3833a', 'http://data.europa.eu/esco/skill/f774131e-8f2d-43b6-8c20-7fe35fa0f0bd', '', 'http://data.europa.eu/esco/skill/a8c3186b-c791-4d57-8f4f-4d12c7a5c6a7', '', 'http://data.europa.eu/esco/skill/39499028-35bf-4d69-9275-fb98902ed88b', '', '', 'http://data.europa.eu/esco/isced-f/0610', 'http://data.europa.eu/esco/isced-f/0611', 'http://data.europa.eu/esco/isced-f/0612', 'http://data.europa.eu/esco/isced-f/0613', 'http://data.europa.eu/esco/isced-f/0619', '', 'http://data.europa.eu/esco/isced-f/0688', '', 'http://data.europa.eu/esco/skill/0b3930a2-8a13-4932-8a09-4c72ec8af464', 'http://data.europa.eu/esco/skill/0e0a44a8-654c-4e85-986a-fb4386114838', 'http://data.europa.eu/esco/skill/15fa3879-ac0e-46e6-ae36-609bae9c19c3', 'http://data.europa.eu/esco/skill/1893b4bc-0eb2-41de-96e3-9c8f1f1eac41', 'http://data.europa.eu/esco/skill/47aa582a-3edb-45b5-9ef4-e87813ea327c', 'http://data.europa.eu/esco/skill/54f7432d-a8b6-4ed4-a50e-9ec882320595', 'http://data.europa.eu/esco/skill/5c2d5780-23ed-4372-bb8d-c1846ee404ae', 'http://data.europa.eu/esco/skill/c5ff50d7-97d3-401e-90ac-e5ae756a52de', 'http://data.europa.eu/esco/skill/d2e8f452-ac19-4eed-b984-8f55d2a5b763', 'http://data.europa.eu/esco/skill/d519fadd-85bf-475f-bf14-c53a0290687d', 'http://data.europa.eu/esco/skill/f7fc7bf8-f41d-44af-81e3-09b88e9779e6', '', 'http://data.europa.eu/esco/skill/1f2950c0-ef1e-44b4-9a55-125ccd7b78af', 'http://data.europa.eu/esco/skill/3eef7ff2-3ade-41d4-b084-2bd2a3949e1c', 'http://data.europa.eu/esco/skill/7e153e1d-2b12-43ad-89f3-0cf82ebc4a30', 'http://data.europa.eu/esco/skill/ba1f6201-b206-4459-b178-706db34a851d', 'http://data.europa.eu/esco/skill/d94e1143-3a3a-4f6a-a881-df93bf56cf23', 'http://data.europa.eu/esco/skill/ec528c47-65f4-4187-9dc1-5a8889f84a06', 'http://data.europa.eu/esco/skill/f2cf57fe-d4cb-4b4a-831d-73171cc73909', '', 'http://data.europa.eu/esco/skill/29dcc31e-a8d6-4a62-b3c1-2de81e966e39', 'http://data.europa.eu/esco/skill/70ac2c90-656a-4fa3-886c-5b9305db2087', 'http://data.europa.eu/esco/skill/9bdf8a77-8524-43da-bac6-d15d22e1b7ed', '', 'http://data.europa.eu/esco/skill/32c017fd-28ab-4051-bf68-74de952c2f77', '', 'http://data.europa.eu/esco/skill/164510d1-1216-4dc0-b9d1-a7f6af19e469', 'http://data.europa.eu/esco/skill/37272760-957a-4c34-b4f3-780ee285334d', 'http://data.europa.eu/esco/skill/6ee936b0-4e0c-4e04-97c7-1f4ee9230d67', 'http://data.europa.eu/esco/skill/7e0b93e0-0de7-4607-b07f-27a6828d3ff0', 'http://data.europa.eu/esco/skill/8ed41305-4abf-4b54-9f8f-0e043d26feba', 'http://data.europa.eu/esco/skill/c23e0a2f-f04b-45bc-b0dd-20571f6b502c', 'http://data.europa.eu/esco/skill/cbe1b24e-00f3-4b17-94e9-1fcd34a11c3e', 'http://data.europa.eu/esco/skill/db54693e-bcb0-4dae-8885-a43d510fb71f', '', 'http://data.europa.eu/esco/skill/aab9f44d-fe0e-46d8-a470-11ce82a64846', 'http://data.europa.eu/esco/skill/bffa732b-12ab-4214-a4b3-498598820b1c', 'http://data.europa.eu/esco/skill/c206d301-14b0-4bea-8028-a3749303a512', 'http://data.europa.eu/esco/skill/c57c0294-9940-4626-8954-08055bc242ba', '', 'http://data.europa.eu/esco/skill/c7f96545-46c4-451a-b284-014f4baed5ed', '', ...
# 2704
# 2703

# %%
esco
# Out:
#                                               conceptUri  \
# 0      http://data.europa.eu/esco/skill/0005c151-5b5a...
# 1      http://data.europa.eu/esco/skill/00064735-8fad...
# 2      http://data.europa.eu/esco/skill/000709ed-2be5...
# 3      http://data.europa.eu/esco/skill/0007bdc2-dd15...
# 4      http://data.europa.eu/esco/skill/00090cc1-1f27...
# ...                                                  ...
# 13891  http://data.europa.eu/esco/skill/ffef5eb3-a15e...
# 13892  http://data.europa.eu/esco/skill/fff0b074-5a76...
# 13893  http://data.europa.eu/esco/skill/fff0e2cd-d0bd...
# 13894  http://data.europa.eu/esco/skill/fff5bc45-b506...
# 13895  http://data.europa.eu/esco/skill/fff74a70-4f82...
#
#                                           preferredLabel  \
# 0                                   manage musical staff
# 1                      supervise correctional procedures
# 2                        apply anti-oppressive practices
# 3      control compliance of railway vehicles regulat...
# 4                            identify available services
# ...                                                  ...
# 13891  remediate healthcare user's occupational perfo...
# 13892               install transport equipment lighting
# 13893                        natural language processing
# 13894                 coordinate construction activities
# 13895                  position guardrails and toeboards
#
#                                                altLabels  \
# 0      manage staff of music\ncoordinate duties of mu...
# 1      oversee prison procedures\nmanage correctional...
# 2      apply non-oppressive practices\napply an anti-...
# 3      monitoring of compliance with railway vehicles...
# 4      establish available services\nidentify availab...
# ...                                                  ...
# 13891  restore healthcare user's occupational perform...
# 13892  install transport equipment illumination\nfix ...
# 13893                   natural language processing\nNLP
# 13894  reviewing construction progress\nconstruction ...
# 13895  positioning guardrails and toeboards\nattachme...
#
#                                              description
# 0      Assign and manage staff tasks in areas such as...
# 1      Supervise the operations of a correctional fac...
# 2      Identify oppression in societies, economies, c...
# 3      Inspect rolling stock, components and systems ...
# 4      Identify the different services available for ...
# ...                                                  ...
# 13891  Remediate or restore the cognitive, sensorimot...
# 13892  Install lighting elements in transport equipme...
# 13893  The technologies which enable ICT devices to u...
# 13894  Coordinate the activities of several construct...
# 13895  Attach guardrails and toeboards to the scaffol...
#
# [13896 rows x 4 columns]

# %%
# merge skillshierarchy with esco
# 1/ get broader URi
esco_filtered_augmented = pd.merge(esco_filtered, relationskill, left_on='conceptUri', right_on='conceptUri', how='left')
print(len(esco_filtered_augmented)) # 3281
esco_filtered_augmented = esco_filtered_augmented[['conceptUri', 'preferredLabel', 'altLabels', 'description', 'broaderUri']]
# After merging we get duplicated conceptURi
# 2/ get skill levels
esco_filtered_augmented2 = pd.merge(esco_filtered_augmented, skillshierarchy, left_on='broaderUri', right_on='Level 3 URI', how='left')
# remove NAs
esco_filtered_augmented2.isnull().sum()
len(esco_filtered_augmented2['conceptUri'].unique())
esco_filtered_augmented2.dropna(subset=['Level 0 URI'], inplace=True)
len(esco_filtered_augmented2['conceptUri'].unique())
print(esco_filtered_augmented2.isnull().sum())

print(len(esco_filtered_augmented2)) 
esco_filtered_augmented2 = esco_filtered_augmented2[['conceptUri', 'preferredLabel', 'altLabels', 'description', 'Level 0 preferred term', 'Level 1 preferred term', 'Level 2 preferred term', 'Level 3 preferred term']]
# Out:
# 4404
# conceptUri                  0
# preferredLabel              0
# altLabels                  58
# description                 0
# broaderUri                  0
# Level 0 URI                 0
# Level 0 preferred term      0
# Level 1 URI                 0
# Level 1 preferred term      0
# Level 2 URI                 0
# Level 2 preferred term      0
# Level 3 URI                 0
# Level 3 preferred term      0
# Description                 0
# Scope note                482
# Level 0 code                0
# Level 1 code              318
# Level 2 code              318
# Level 3 code              318
# dtype: int64
# 2705

# %%
def concatenate_cols(row):
    output = row["preferredLabel"] if not pd.isna(row["preferredLabel"]) else ""
    output += f" {row['altLabels']}" if not pd.isna(row["altLabels"]) else ""
    #output += f" {row['hiddenLabels']}" if not pd.isna(row["hiddenLabels"]) else ""
    return output

#esco_filtered_augmented2["preferredLabel"] = esco_filtered_augmented2.apply(lambda row: concatenate_cols(row), axis=1)

esco_filtered_augmented2.rename(columns={'preferredLabel': 'Type Level 4', 'description': 'Definition', 'Level 1 preferred term': 'Type Level 1', 'Level 2 preferred term': 'Type Level 2', 'Level 3 preferred term': 'Type Level 3', 'conceptUri': 'Source', 'Level 0 preferred term': 'Dimension'}, inplace=True)

esco_filtered_augmented2["unique_id"] = [1000+ i for i in range(len(esco_filtered_augmented2))]

# %%
esco_filtered_augmented2["name"] = esco_filtered_augmented2["Type Level 4"]

# %%
print("Number of skills : ", len(esco_filtered_augmented2.index))
esco_filtered_augmented2.head()
# Out:
# Number of skills :  2705
#                                               Source  \
# 0  http://data.europa.eu/esco/skill/0005c151-5b5a...
# 3  http://data.europa.eu/esco/skill/000bb1e4-89f0...
# 4  http://data.europa.eu/esco/skill/000f1d3d-220f...
# 6  http://data.europa.eu/esco/skill/0037c821-2898...
# 8  http://data.europa.eu/esco/skill/004f1e68-9ca2...
#
#                      Type Level 4  \
# 0            manage musical staff
# 3   perform toxicological studies
# 4                         Haskell
# 6  develop energy saving concepts
# 8              work with soloists
#
#                                            altLabels  \
# 0  manage staff of music\ncoordinate duties of mu...
# 3  perform toxicological studies\napply toxicolog...
# 4                                            Haskell
# 6  developing concepts for energy saving\ndevelop...
# 8  collaborate with soloists\nworking with solois...
#
#                                           Definition  Dimension  \
# 0  Assign and manage staff tasks in areas such as...     skills
# 3  Perform tests to detect poisons or drug misuse...     skills
# 4  The techniques and principles of software deve...  knowledge
# 6  Use current research results and collaborate w...     skills
# 8  Communicate with solo artists and concert mast...     skills
#
#                                         Type Level 1  \
# 0                                  management skills
# 3                                 information skills
# 4  information and communication technologies (icts)
# 6                                  management skills
# 8        communication, collaboration and creativity
#
#                                         Type Level 2  \
# 0                                 supervising people
# 3                 monitoring, inspecting and testing
# 4  information and communication technologies (icts)
# 6               developing objectives and strategies
# 8                                working with others
#
#                                         Type Level 3  unique_id  \
# 0                        supervising a team or group       1000
# 3  monitoring health conditions of humans and ani...       1001
# 4  software and applications development and anal...       1002
# 6     developing operational policies and procedures       1003
# 8                                   working in teams       1004
#
#                              name
# 0            manage musical staff
# 3   perform toxicological studies
# 4                         Haskell
# 6  develop energy saving concepts
# 8              work with soloists

# %%
esco_filtered_augmented2["name+defintion"] = esco_filtered_augmented2["name"] + " : " + esco_filtered_augmented2["Definition"].apply(lambda x : x.lower())

# %%
esco_filtered_augmented2.to_csv(ESCO_DIR + "tech_managment_taxonomy.csv")

# %%
esco_filtered_augmented2
# Out:
#                                                  Source  \
# 0     http://data.europa.eu/esco/skill/0005c151-5b5a...
# 3     http://data.europa.eu/esco/skill/000bb1e4-89f0...
# 4     http://data.europa.eu/esco/skill/000f1d3d-220f...
# 6     http://data.europa.eu/esco/skill/0037c821-2898...
# 8     http://data.europa.eu/esco/skill/004f1e68-9ca2...
# ...                                                 ...
# 4398  http://data.europa.eu/esco/skill/ff82aa43-aef7...
# 4399  http://data.europa.eu/esco/skill/ff862044-d49e...
# 4401  http://data.europa.eu/esco/skill/ffa1d58b-ba09...
# 4402  http://data.europa.eu/esco/skill/ffc1e455-ced2...
# 4403  http://data.europa.eu/esco/skill/ffddfc7c-a9dd...
#
#                               Type Level 4  \
# 0                     manage musical staff
# 3            perform toxicological studies
# 4                                  Haskell
# 6           develop energy saving concepts
# 8                       work with soloists
# ...                                    ...
# 4398            perform nutrition analysis
# 4399  analyse work-related written reports
# 4401            perform energy simulations
# 4402                           Capture One
# 4403                                 Scala
#
#                                               altLabels  \
# 0     manage staff of music\ncoordinate duties of mu...
# 3     perform toxicological studies\napply toxicolog...
# 4                                               Haskell
# 6     developing concepts for energy saving\ndevelop...
# 8     collaborate with soloists\nworking with solois...
# ...                                                 ...
# 4398  determine nutrients of food products\nperform ...
# 4399  analyze  work-related written reports\nconduct...
# 4401                       carry out energy simulations
# 4402                                        Capture One
# 4403                                              Scala
#
#                                              Definition  Dimension  \
# 0     Assign and manage staff tasks in areas such as...     skills
# 3     Perform tests to detect poisons or drug misuse...     skills
# 4     The techniques and principles of software deve...  knowledge
# 6     Use current research results and collaborate w...     skills
# 8     Communicate with solo artists and concert mast...     skills
# ...                                                 ...        ...
# 4398  Determine and calculate the nutrients of food ...     skills
# 4399  Read and comprehend job-related reports, analy...     skills
# 4401  Replicate the building's energy performance by...     skills
# 4402  The computer program Capture One is a graphica...  knowledge
# 4403  The techniques and principles of software deve...  knowledge
#
#                                            Type Level 1  \
# 0                                     management skills
# 3                                    information skills
# 4     information and communication technologies (icts)
# 6                                     management skills
# 8           communication, collaboration and creativity
# ...                                                 ...
# 4398                                 information skills
# 4399                                 information skills
# 4401                                 information skills
# 4402  information and communication technologies (icts)
# 4403  information and communication technologies (icts)
#
#                                            Type Level 2  \
# 0                                    supervising people
# 3                    monitoring, inspecting and testing
# 4     information and communication technologies (icts)
# 6                  developing objectives and strategies
# 8                                   working with others
# ...                                                 ...
# 4398      analysing and evaluating information and data
# 4399      analysing and evaluating information and data
# 4401      analysing and evaluating information and data
# 4402  information and communication technologies (icts)
# 4403  information and communication technologies (icts)
#
#                                            Type Level 3  unique_id  \
# 0                           supervising a team or group       1000
# 3     monitoring health conditions of humans and ani...       1001
# 4     software and applications development and anal...       1002
# 6        developing operational policies and procedures       1003
# 8                                      working in teams       1004
# ...                                                 ...        ...
# 4398              analysing scientific and medical data       3700
# 4399                      analysing business operations       3701
# 4401      analysing and evaluating information and data       3702
# 4402                                       computer use       3703
# 4403  software and applications development and anal...       3704
#
#                                       name  \
# 0                     manage musical staff
# 3            perform toxicological studies
# 4                                  Haskell
# 6           develop energy saving concepts
# 8                       work with soloists
# ...                                    ...
# 4398            perform nutrition analysis
# 4399  analyse work-related written reports
# 4401            perform energy simulations
# 4402                           Capture One
# 4403                                 Scala
#
#                                          name+defintion
# 0     manage musical staff : assign and manage staff...
# 3     perform toxicological studies : perform tests ...
# 4     Haskell : the techniques and principles of sof...
# 6     develop energy saving concepts : use current r...
# 8     work with soloists : communicate with solo art...
# ...                                                 ...
# 4398  perform nutrition analysis : determine and cal...
# 4399  analyse work-related written reports : read an...
# 4401  perform energy simulations : replicate the bui...
# 4402  Capture One : the computer program capture one...
# 4403  Scala : the techniques and principles of softw...
#
# [2705 rows x 11 columns]
