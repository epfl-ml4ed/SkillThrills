# %%
import pickle
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import json
from generator import SkillsGenerator, DatasetGenerator
from tqdm.notebook import tqdm
from transformers import AutoModel, AutoTokenizer
import gen_prompt_template
from importlib import reload
import pickle
from api_key import API_KEY
import seaborn as sns
tqdm.pandas()


# %load_ext autoreload
# %autoreload 2

# %%
## Loading the embedded taxonomy
ESCO_DIR = "../../../../esco/"

with open(ESCO_DIR + "dev_skillspan_emb.pkl", "rb") as f:
    dev_emb_tax = pickle.load(f)
    dev_emb_tax["embeddings"] = dev_emb_tax["embeddings"].apply(lambda x : x.detach())

with open(ESCO_DIR + "test_skillspan_emb.pkl", "rb") as f:
    test_emb_tax = pickle.load(f)
    test_emb_tax["embeddings"] = test_emb_tax["embeddings"].apply(lambda x : x.detach())

## create train emb tax
train_emb_tax = pd.concat([test_emb_tax, dev_emb_tax]).drop_duplicates("name")


## get taxonomy without embeddings
dev_tax = dev_emb_tax.drop("embeddings", axis=1)
test_tax = test_emb_tax.drop("embeddings", axis=1)
train_tax = train_emb_tax.drop("embeddings", axis=1)


## popularity distribution
F = pd.read_csv("../ppl_3_sentences_all_skills.csv").drop("Unnamed: 0", axis=1)[["name", "mean_std_ppl"]].set_index("name").to_dict()["mean_std_ppl"]

## skill nb distribution
MAX_NB_SKILL = 5
combination_dist = np.ones(MAX_NB_SKILL) / MAX_NB_SKILL

## Models
word_emb = "jjzha/jobbert-base-cased"
word_emb_model = AutoModel.from_pretrained(word_emb)
word_emb_tokenizer = AutoTokenizer.from_pretrained(word_emb)

## Not used in this version
additional_info = None
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at jjzha/jobbert-base-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def save_generation(text_file, res):
    tres = ""
    for (skills, job_posting) in res:
        tres += "skills : "+str(skills) + "\n"
        tres += (job_posting if job_posting is not None else "[NULL]") + "\n"
        tres += "-"*100 + "\n"

    with open(text_file, "w") as f:
        f.write(tres)

    print("Result saved in : ./" + text_file)


def save_json(text_file, res):
    tres = []
    for (skills, job_posting) in res:
        tres.append({'skills': skills, 'description': job_posting})

    with open(text_file, "w") as f:
        json.dump(tres, f)

    print("Result saved in : ./" + text_file)

# %% [markdown]
# Generation for a certain split:

# %%
def combinations_generation(emb_tax, split_size):
    gen = SkillsGenerator(taxonomy=emb_tax, 
                taxonomy_is_embedded=True,
                combination_dist=combination_dist,
                popularity=F)
    
    gen_args = {
        "nb_generation" : split_size, # number of samples
        "threshold" : 0.83, # not considering skills that are less than .8 similar
        "beam_size" : 20, # considering 20 skills
        "temperature_pairing": 1, # popularity to be skewed toward popular skills
        "temperature_sample_size": 1,
        "frequency_select": True, # wether we select within the NN acording to frequency
    }


    combinations = list(gen.balanced_nbred_iter(**gen_args))
    return combinations

f, a = plt.subplots(1, 3, figsize=(15, 5))

split_sizes = {
    "train": 0.75,
    "test": 0.15,
    "dev": 0.15,
}
split_emb_taxs = {
    "train": train_emb_tax,
    "test": test_emb_tax,
    "dev": dev_emb_tax,
}
TOTAL_SAMPLES = 8_000

combinations = {}
for ax, split in zip(a.flatten(), split_sizes):
    combinations[split] = combinations_generation(split_emb_taxs[split], int(TOTAL_SAMPLES * split_sizes[split]))
    ax.hist([len(x) for x in combinations[split]], bins=np.arange(1,6))
    ax.set_title(f"Disttribution of combinations length for {split}")
    ax.set_ylabel("Number of combinations")
    ax.set_xlabel("Number of skills in combination")
    ax.set_xticks(np.arange(1,6))
    print(f"Number of combinations in {split} split : {len(combinations[split])}")

plt.tight_layout()
# Out:
# Number of combinations in train split : 6000
# Number of combinations in test split : 1200
# Number of combinations in dev split : 1200

# %%
from collections import Counter
def occurences_lookup(combinations):
    flatten_dist = sum(combinations, [])
    counts = Counter(flatten_dist).values()
    return counts


f, a = plt.subplots(1, 3, figsize=(15, 5))
for ax, split in zip(a.flatten(), split_sizes):
    split_dist = occurences_lookup(combinations[split])
    ax.hist(split_dist)
    ax.set_title(f"Disttribution of occurences of skills in {split}")
    ax.set_ylabel("Number of skills")
    ax.set_xlabel("Number of occurences of the skills")
    

plt.tight_layout()

# %%
flatten_tests = set(sum(combinations["test"], []) + sum(combinations["dev"], []))
flatten_train = set(sum(combinations["train"], []))

print(flatten_tests.difference(flatten_train)) ## = set (), so all the test sample are represented at least once in the train
# Out:
# set()

# %%
def generate_split(split, n_samples=None):
    combs = combinations[split]

    if(n_samples is None):
        n_samples = len(combs)
    
    emb_tax = split_emb_taxs[split]
    datagen = DatasetGenerator(emb_tax,
                           None, ## no references, we work in Zero-Shot
                           word_emb_model,
                           word_emb_tokenizer,
                           additional_info)

    generation_args = {
        "skill_generator": combs[:n_samples], 
        "specific_few_shots": False,
        "model": "gpt-3.5",
        "gen_mode": "PROTOTYPE",
        "autosave": True,
        "autosave_file": f"generated/SKILLSPAN/{split}.json",
        "checkpoints_freq":10
    }
    res = datagen.generate_ds(**generation_args)
    return res

# %%
res = generate_split("train", n_samples=10)
# Out:
# 0it [00:00, ?it/s]

# %%
for r in res:
    print("-"*100)
    print("labels :", r[0])
    print("Desc : ")
    [print(r[1][n:n+75]) for n in range(0, len(r[1]), 75)]
# Out:
# ----------------------------------------------------------------------------------------------------
# labels : ['develop creative ideas']
# Desc :
# Are you a visionary thinker with a knack for crafting unique and innovative
#  solutions that captivate audiences? Join our team and be part of an enviro
# nment that fosters the development of creative concepts to drive growth and
#  impact.
# ----------------------------------------------------------------------------------------------------
# labels : ['perform ICT troubleshooting']
# Desc :
# The ideal candidate will possess a deep understanding of troubleshooting IC
# T systems, applying their expertise to swiftly identify and resolve technic
# al issues, ensuring seamless operational continuity.
# ----------------------------------------------------------------------------------------------------
# labels : ['Open source model', 'Agile development']
# Desc :
# Are you an adaptable and collaborative software engineer experienced in lev
# eraging community-driven development methodologies for efficient and innova
# tive software solutions? We're in need of a forward-thinking professional w
# ho excels in harnessing the power of open source models and embraces the pr
# inciples of agile development to drive our organization's digital transform
# ation.
# ----------------------------------------------------------------------------------------------------
# labels : ['perform software unit testing', 'develop ICT test suite', 'execute software tests', 'conduct ICT code review']
# Desc :
# Looking for a detail-oriented individual with expertise in ensuring quality
#  software through comprehensive testing, including developing and implement
# ing test suites, executing software tests, and conducting code reviews for
# an efficient ICT infrastructure.
# ----------------------------------------------------------------------------------------------------
# labels : ['Jenkins (tools for software configuration management)', 'tools for software configuration management', 'Ansible', 'solution deployment']
# Desc :
# Experience in automating software configuration management processes using
# industry-leading tools, such as Jenkins and Ansible, is required for effici
# ent solution deployment.
# ----------------------------------------------------------------------------------------------------
# labels : ['systems thinking', 'SaaS (service-oriented modelling)']
# Desc :
# Join our dynamic team and bring your expertise in holistic problem-solving
# and cutting-edge software solutions to drive innovative approaches to compl
# ex business challenges.
# ----------------------------------------------------------------------------------------------------
# labels : ['service-oriented modelling', 'SaaS (service-oriented modelling)', 'computer science']
# Desc :
# Are you passionate about leveraging cutting-edge technology and applying se
# rvice-oriented approaches to drive innovation in the field of computer scie
# nce? Join our dynamic team as we revolutionize the industry with our SaaS-b
# ased solutions and service-oriented modelling techniques.
# ----------------------------------------------------------------------------------------------------
# labels : ['Unity (digital game creation systems)', 'authoring software']
# Desc :
# Proficiency in utilizing industry-standard game development tools, includin
# g robust digital game creation systems, and authoring software, is essentia
# l for this role.
# ----------------------------------------------------------------------------------------------------
# labels : ['manage administrative systems']
# Desc :
# Proven expertise in optimizing and streamlining operational processes, ensu
# ring the seamless management and integration of diverse administrative syst
# ems.
# ----------------------------------------------------------------------------------------------------
# labels : ['communicate with target community', 'develop campaigns']
# Desc :
# Our ideal candidate will be adept at establishing effective lines of commun
# ication with the target community, leveraging their expertise to strategica
# lly develop innovative campaigns that resonate with our audience.

# %%
train_ds = generate_split("train")
# Out:
# 0it [00:00, ?it/s]
# > saved checkpoint at 10
# > saved checkpoint at 20
# > saved checkpoint at 30
# > saved checkpoint at 40
# > saved checkpoint at 50
# > saved checkpoint at 60
# > saved checkpoint at 70
# > saved checkpoint at 80
# > saved checkpoint at 90
# > saved checkpoint at 100
# > saved checkpoint at 110
# > saved checkpoint at 120
# > saved checkpoint at 130
# > saved checkpoint at 140
# > saved checkpoint at 150
# > saved checkpoint at 160
# > saved checkpoint at 170
# > saved checkpoint at 180
# > saved checkpoint at 190
# > saved checkpoint at 200
# > saved checkpoint at 210
# > saved checkpoint at 220
# > saved checkpoint at 230
# > saved checkpoint at 240
# > saved checkpoint at 250
# > saved checkpoint at 260
# > saved checkpoint at 270
# > saved checkpoint at 280
# > saved checkpoint at 290
# > saved checkpoint at 300
# > saved checkpoint at 310
# > saved checkpoint at 320
# > saved checkpoint at 330
# > saved checkpoint at 340
# > saved checkpoint at 350
# > saved checkpoint at 360
# > saved checkpoint at 370
# > saved checkpoint at 380
# > saved checkpoint at 390
# > saved checkpoint at 400
# > saved checkpoint at 410
# > saved checkpoint at 420
# > saved checkpoint at 430
# > saved checkpoint at 440
# > saved checkpoint at 450
# > saved checkpoint at 460
# > saved checkpoint at 470
# > saved checkpoint at 480
# > saved checkpoint at 490
# > saved checkpoint at 500
# > saved checkpoint at 510
# > saved checkpoint at 520
# > saved checkpoint at 530
# > saved checkpoint at 540
# > saved checkpoint at 550
# > saved checkpoint at 560
# > saved checkpoint at 570
# > saved checkpoint at 580
# > saved checkpoint at 590
# > saved checkpoint at 600
# > saved checkpoint at 610
# > saved checkpoint at 620
# > saved checkpoint at 630
# > saved checkpoint at 640
# > saved checkpoint at 650
# > saved checkpoint at 660
# > saved checkpoint at 670
# > saved checkpoint at 680
# > saved checkpoint at 690
# > saved checkpoint at 700
# > saved checkpoint at 710
# > saved checkpoint at 720
# > saved checkpoint at 730
# > saved checkpoint at 740
# > saved checkpoint at 750
# > saved checkpoint at 760
# > saved checkpoint at 770
# > saved checkpoint at 780
# > saved checkpoint at 790
# > saved checkpoint at 800
# > saved checkpoint at 810
# > saved checkpoint at 820
# > saved checkpoint at 830
# > saved checkpoint at 840
# > saved checkpoint at 850
# > saved checkpoint at 860
# > saved checkpoint at 870
# > saved checkpoint at 880
# > saved checkpoint at 890
# > saved checkpoint at 900
# > saved checkpoint at 910
# > saved checkpoint at 920
# > saved checkpoint at 930
# > saved checkpoint at 940
# > saved checkpoint at 950
# > saved checkpoint at 960
# > saved checkpoint at 970
# > saved checkpoint at 980
# > saved checkpoint at 990
# > saved checkpoint at 1000
# > saved checkpoint at 1010
# > saved checkpoint at 1020
# > saved checkpoint at 1030
# > saved checkpoint at 1040
# > saved checkpoint at 1050
# > saved checkpoint at 1060
# > saved checkpoint at 1070
# > saved checkpoint at 1080
# > saved checkpoint at 1090
# > saved checkpoint at 1100
# > saved checkpoint at 1110
# > saved checkpoint at 1120
# > saved checkpoint at 1130
# > saved checkpoint at 1140
# > saved checkpoint at 1150
# > saved checkpoint at 1160
# > saved checkpoint at 1170
# > saved checkpoint at 1180
# > saved checkpoint at 1190
# > saved checkpoint at 1200
# > saved checkpoint at 1210
# > saved checkpoint at 1220
# > saved checkpoint at 1230
# > saved checkpoint at 1240
# > saved checkpoint at 1250
# > saved checkpoint at 1260
# > saved checkpoint at 1270
# > saved checkpoint at 1280
# > saved checkpoint at 1290
# > saved checkpoint at 1300
# > saved checkpoint at 1310
# > saved checkpoint at 1320
# > saved checkpoint at 1330
# > saved checkpoint at 1340
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 1350
# > saved checkpoint at 1360
# > saved checkpoint at 1370
# > saved checkpoint at 1380
# > saved checkpoint at 1390
# > saved checkpoint at 1400
# > saved checkpoint at 1410
# > saved checkpoint at 1420
# > saved checkpoint at 1430
# > saved checkpoint at 1440
# > saved checkpoint at 1450
# > saved checkpoint at 1460
# > saved checkpoint at 1470
# > saved checkpoint at 1480
# > saved checkpoint at 1490
# > saved checkpoint at 1500
# > saved checkpoint at 1510
# > saved checkpoint at 1520
# > saved checkpoint at 1530
# > saved checkpoint at 1540
# > saved checkpoint at 1550
# > saved checkpoint at 1560
# > saved checkpoint at 1570
# > saved checkpoint at 1580
# > saved checkpoint at 1590
# > saved checkpoint at 1600
# > saved checkpoint at 1610
# > saved checkpoint at 1620
# > saved checkpoint at 1630
# > saved checkpoint at 1640
# > saved checkpoint at 1650
# > saved checkpoint at 1660
# > saved checkpoint at 1670
# > saved checkpoint at 1680
# > saved checkpoint at 1690
# > saved checkpoint at 1700
# > saved checkpoint at 1710
# > saved checkpoint at 1720
# > saved checkpoint at 1730
# > saved checkpoint at 1740
# > saved checkpoint at 1750
# > saved checkpoint at 1760
# > saved checkpoint at 1770
# > saved checkpoint at 1780
# > saved checkpoint at 1790
# > saved checkpoint at 1800
# > saved checkpoint at 1810
# > saved checkpoint at 1820
# > saved checkpoint at 1830
# > saved checkpoint at 1840
# > saved checkpoint at 1850
# > saved checkpoint at 1860
# > saved checkpoint at 1870
# > saved checkpoint at 1880
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 1890
# > saved checkpoint at 1900
# > saved checkpoint at 1910
# > saved checkpoint at 1920
# > saved checkpoint at 1930
# > saved checkpoint at 1940
# > saved checkpoint at 1950
# > saved checkpoint at 1960
# > saved checkpoint at 1970
# > saved checkpoint at 1980
# > saved checkpoint at 1990
# > saved checkpoint at 2000
# > saved checkpoint at 2010
# > saved checkpoint at 2020
# > saved checkpoint at 2030
# > saved checkpoint at 2040
# > saved checkpoint at 2050
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 2060
# > saved checkpoint at 2070
# > saved checkpoint at 2080
# > saved checkpoint at 2090
# > saved checkpoint at 2100
# > saved checkpoint at 2110
# > saved checkpoint at 2120
# > saved checkpoint at 2130
# > saved checkpoint at 2140
# > saved checkpoint at 2150
# > saved checkpoint at 2160
# > saved checkpoint at 2170
# > saved checkpoint at 2180
# > saved checkpoint at 2190
# > saved checkpoint at 2200
# > saved checkpoint at 2210
# > saved checkpoint at 2220
# > saved checkpoint at 2230
# > saved checkpoint at 2240
# > saved checkpoint at 2250
# > saved checkpoint at 2260
# > saved checkpoint at 2270
# > saved checkpoint at 2280
# > saved checkpoint at 2290
# > saved checkpoint at 2300
# > saved checkpoint at 2310
# > saved checkpoint at 2320
# > saved checkpoint at 2330
# > saved checkpoint at 2340
# > saved checkpoint at 2350
# > saved checkpoint at 2360
# > saved checkpoint at 2370
# > saved checkpoint at 2380
# > saved checkpoint at 2390
# > saved checkpoint at 2400
# > saved checkpoint at 2410
# > saved checkpoint at 2420
# > saved checkpoint at 2430
# > saved checkpoint at 2440
# > saved checkpoint at 2450
# > saved checkpoint at 2460
# > saved checkpoint at 2470
# > saved checkpoint at 2480
# > saved checkpoint at 2490
# > saved checkpoint at 2500
# > saved checkpoint at 2510
# > saved checkpoint at 2520
# > saved checkpoint at 2530
# > saved checkpoint at 2540
# > saved checkpoint at 2550
# > saved checkpoint at 2560
# > saved checkpoint at 2570
# > saved checkpoint at 2580
# > saved checkpoint at 2590
# > saved checkpoint at 2600
# > saved checkpoint at 2610
# > saved checkpoint at 2620
# > saved checkpoint at 2630
# > saved checkpoint at 2640
# > saved checkpoint at 2650
# > saved checkpoint at 2660
# > saved checkpoint at 2670
# > saved checkpoint at 2680
# > saved checkpoint at 2690
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 2700
# > saved checkpoint at 2710
# > saved checkpoint at 2720
# > saved checkpoint at 2730
# > saved checkpoint at 2740
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 2750
# > saved checkpoint at 2760
# > saved checkpoint at 2770
# > saved checkpoint at 2780
# > saved checkpoint at 2790
# > saved checkpoint at 2800
# > saved checkpoint at 2810
# > saved checkpoint at 2820
# > saved checkpoint at 2830
# > saved checkpoint at 2840
# > saved checkpoint at 2850
# > saved checkpoint at 2860
# > saved checkpoint at 2870
# > saved checkpoint at 2880
# > saved checkpoint at 2890
# > saved checkpoint at 2900
# > saved checkpoint at 2910
# > saved checkpoint at 2920
# > saved checkpoint at 2930
# > saved checkpoint at 2940
# > saved checkpoint at 2950
# > saved checkpoint at 2960
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 2970
# > saved checkpoint at 2980
# > saved checkpoint at 2990
# > saved checkpoint at 3000
# > saved checkpoint at 3010
# > saved checkpoint at 3020
# > saved checkpoint at 3030
# > saved checkpoint at 3040
# > saved checkpoint at 3050
# > saved checkpoint at 3060
# > saved checkpoint at 3070
# > saved checkpoint at 3080
# > saved checkpoint at 3090
# > saved checkpoint at 3100
# > saved checkpoint at 3110
# > saved checkpoint at 3120
# > saved checkpoint at 3130
# > saved checkpoint at 3140
# > saved checkpoint at 3150
# > saved checkpoint at 3160
# > saved checkpoint at 3170
# > saved checkpoint at 3180
# > saved checkpoint at 3190
# > saved checkpoint at 3200
# > saved checkpoint at 3210
# > saved checkpoint at 3220
# > saved checkpoint at 3230
# > saved checkpoint at 3240
# > saved checkpoint at 3250
# > saved checkpoint at 3260
# > saved checkpoint at 3270
# > saved checkpoint at 3280
# > saved checkpoint at 3290
# > saved checkpoint at 3300
# > saved checkpoint at 3310
# > saved checkpoint at 3320
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 3330
# > saved checkpoint at 3340
# > saved checkpoint at 3350
# > saved checkpoint at 3360
# > saved checkpoint at 3370
# > saved checkpoint at 3380
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 3390
# > saved checkpoint at 3400
# > saved checkpoint at 3410
# > saved checkpoint at 3420
# > saved checkpoint at 3430
# > saved checkpoint at 3440
# > saved checkpoint at 3450
# > saved checkpoint at 3460
# > saved checkpoint at 3470
# > saved checkpoint at 3480
# > saved checkpoint at 3490
# > saved checkpoint at 3500
# > saved checkpoint at 3510
# > saved checkpoint at 3520
# > saved checkpoint at 3530
# > saved checkpoint at 3540
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 3550
# > saved checkpoint at 3560
# > saved checkpoint at 3570
# > saved checkpoint at 3580
# > saved checkpoint at 3590
# > saved checkpoint at 3600
# > saved checkpoint at 3610
# > saved checkpoint at 3620
# > saved checkpoint at 3630
# > saved checkpoint at 3640
# > saved checkpoint at 3650
# > saved checkpoint at 3660
# > saved checkpoint at 3670
# > saved checkpoint at 3680
# > saved checkpoint at 3690
# > saved checkpoint at 3700
# > saved checkpoint at 3710
# > saved checkpoint at 3720
# > saved checkpoint at 3730
# > saved checkpoint at 3740
# > saved checkpoint at 3750
# > saved checkpoint at 3760
# > saved checkpoint at 3770
# > saved checkpoint at 3780
# > saved checkpoint at 3790
# > saved checkpoint at 3800
# > saved checkpoint at 3810
# > saved checkpoint at 3820
# > saved checkpoint at 3830
# > saved checkpoint at 3840
# > saved checkpoint at 3850
# > saved checkpoint at 3860
# > saved checkpoint at 3870
# > saved checkpoint at 3880
# > saved checkpoint at 3890
# > saved checkpoint at 3900
# > saved checkpoint at 3910
# > saved checkpoint at 3920
# > saved checkpoint at 3930
# > saved checkpoint at 3940
# > saved checkpoint at 3950
# > saved checkpoint at 3960
# > saved checkpoint at 3970
# > saved checkpoint at 3980
# > saved checkpoint at 3990
# > saved checkpoint at 4000
# > saved checkpoint at 4010
# > saved checkpoint at 4020
# > saved checkpoint at 4030
# > saved checkpoint at 4040
# > saved checkpoint at 4050
# > saved checkpoint at 4060
# > saved checkpoint at 4070
# > saved checkpoint at 4080
# > saved checkpoint at 4090
# > saved checkpoint at 4100
# > saved checkpoint at 4110
# > saved checkpoint at 4120
# > saved checkpoint at 4130
# > saved checkpoint at 4140
# > saved checkpoint at 4150
# > saved checkpoint at 4160
# > saved checkpoint at 4170
# > saved checkpoint at 4180
# > saved checkpoint at 4190
# > saved checkpoint at 4200
# > saved checkpoint at 4210
# > saved checkpoint at 4220
# > saved checkpoint at 4230
# > saved checkpoint at 4240
# > saved checkpoint at 4250
# > saved checkpoint at 4260
# > saved checkpoint at 4270
# > saved checkpoint at 4280
# > saved checkpoint at 4290
# > saved checkpoint at 4300
# > saved checkpoint at 4310
# > saved checkpoint at 4320
# > saved checkpoint at 4330
# > saved checkpoint at 4340
# > saved checkpoint at 4350
# > saved checkpoint at 4360
# > saved checkpoint at 4370
# > saved checkpoint at 4380
# > saved checkpoint at 4390
# > saved checkpoint at 4400
# > saved checkpoint at 4410
# > saved checkpoint at 4420
# > saved checkpoint at 4430
# > saved checkpoint at 4440
# > saved checkpoint at 4450
# > saved checkpoint at 4460
# > saved checkpoint at 4470
# > saved checkpoint at 4480
# > saved checkpoint at 4490
# > saved checkpoint at 4500
# > saved checkpoint at 4510
# > saved checkpoint at 4520
# > saved checkpoint at 4530
# > saved checkpoint at 4540
# > saved checkpoint at 4550
# > saved checkpoint at 4560
# > saved checkpoint at 4570
# > saved checkpoint at 4580
# > saved checkpoint at 4590
# > saved checkpoint at 4600
# > saved checkpoint at 4610
# > saved checkpoint at 4620
# > saved checkpoint at 4630
# > saved checkpoint at 4640
# > saved checkpoint at 4650
# > saved checkpoint at 4660
# > saved checkpoint at 4670
# > saved checkpoint at 4680
# > saved checkpoint at 4690
# > saved checkpoint at 4700
# > saved checkpoint at 4710
# > saved checkpoint at 4720
# > saved checkpoint at 4730
# > saved checkpoint at 4740
# > saved checkpoint at 4750
# > saved checkpoint at 4760
# > saved checkpoint at 4770
# > saved checkpoint at 4780
# > saved checkpoint at 4790
# > saved checkpoint at 4800
# > saved checkpoint at 4810
# > saved checkpoint at 4820
# > saved checkpoint at 4830
# > saved checkpoint at 4840
# > saved checkpoint at 4850
# > saved checkpoint at 4860
# > saved checkpoint at 4870
# > saved checkpoint at 4880
# > saved checkpoint at 4890
# > saved checkpoint at 4900
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 4910
# > saved checkpoint at 4920
# > saved checkpoint at 4930
# > saved checkpoint at 4940
# > saved checkpoint at 4950
# > saved checkpoint at 4960
# > saved checkpoint at 4970
# > saved checkpoint at 4980
# > saved checkpoint at 4990
# > saved checkpoint at 5000
# > saved checkpoint at 5010
# > saved checkpoint at 5020
# > saved checkpoint at 5030
# > saved checkpoint at 5040
# > saved checkpoint at 5050
# > saved checkpoint at 5060
# > saved checkpoint at 5070
# > saved checkpoint at 5080
# > saved checkpoint at 5090
# > saved checkpoint at 5100
# > saved checkpoint at 5110
# > saved checkpoint at 5120
# > saved checkpoint at 5130
# > saved checkpoint at 5140
# > saved checkpoint at 5150
# > saved checkpoint at 5160
# > saved checkpoint at 5170
# > saved checkpoint at 5180
# > saved checkpoint at 5190
# > saved checkpoint at 5200
# > saved checkpoint at 5210
# > saved checkpoint at 5220
# > saved checkpoint at 5230
# > saved checkpoint at 5240
# > saved checkpoint at 5250
# > saved checkpoint at 5260
# > saved checkpoint at 5270
# > saved checkpoint at 5280
# > saved checkpoint at 5290
# > saved checkpoint at 5300
# > saved checkpoint at 5310
# > saved checkpoint at 5320
# > saved checkpoint at 5330
# > saved checkpoint at 5340
# > saved checkpoint at 5350
# > saved checkpoint at 5360
# > saved checkpoint at 5370
# > saved checkpoint at 5380
# > saved checkpoint at 5390
# > saved checkpoint at 5400
# > saved checkpoint at 5410
# > saved checkpoint at 5420
# > saved checkpoint at 5430
# > saved checkpoint at 5440
# > saved checkpoint at 5450
# > saved checkpoint at 5460
# > saved checkpoint at 5470
# > saved checkpoint at 5480
# > saved checkpoint at 5490
# > saved checkpoint at 5500
# > saved checkpoint at 5510
# > saved checkpoint at 5520
# > saved checkpoint at 5530
# > saved checkpoint at 5540
# > saved checkpoint at 5550
# > saved checkpoint at 5560
# > saved checkpoint at 5570
# > saved checkpoint at 5580
# > saved checkpoint at 5590
# > saved checkpoint at 5600
# > saved checkpoint at 5610
# > saved checkpoint at 5620
# > saved checkpoint at 5630
# > saved checkpoint at 5640
# > saved checkpoint at 5650
# > saved checkpoint at 5660
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 5670
# > saved checkpoint at 5680
# > saved checkpoint at 5690
# > saved checkpoint at 5700
# > saved checkpoint at 5710
# > saved checkpoint at 5720
# > saved checkpoint at 5730
# > saved checkpoint at 5740
# > saved checkpoint at 5750
# > saved checkpoint at 5760
# > saved checkpoint at 5770
# > saved checkpoint at 5780
# > saved checkpoint at 5790
# > saved checkpoint at 5800
# > saved checkpoint at 5810
# > saved checkpoint at 5820
# > saved checkpoint at 5830
# > saved checkpoint at 5840
# > saved checkpoint at 5850
# > saved checkpoint at 5860
# > saved checkpoint at 5870
# > saved checkpoint at 5880
# > saved checkpoint at 5890
# > saved checkpoint at 5900
# > saved checkpoint at 5910
# > saved checkpoint at 5920
# > saved checkpoint at 5930
# > saved checkpoint at 5940
# > saved checkpoint at 5950
# > saved checkpoint at 5960
# > saved checkpoint at 5970
# > saved checkpoint at 5980
# > saved checkpoint at 5990

# %%
test_ds = generate_split("test")
# Out:
# 0it [00:00, ?it/s]
# > saved checkpoint at 10
# > saved checkpoint at 20
# > saved checkpoint at 30
# > saved checkpoint at 40
# > saved checkpoint at 50
# > saved checkpoint at 60
# > saved checkpoint at 70
# > saved checkpoint at 80
# > saved checkpoint at 90
# > saved checkpoint at 100
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 110
# > saved checkpoint at 120
# > saved checkpoint at 130
# > saved checkpoint at 140
# > saved checkpoint at 150
# > saved checkpoint at 160
# > saved checkpoint at 170
# > saved checkpoint at 180
# > saved checkpoint at 190
# > saved checkpoint at 200
# > saved checkpoint at 210
# > saved checkpoint at 220
# > saved checkpoint at 230
# > saved checkpoint at 240
# > saved checkpoint at 250
# > saved checkpoint at 260
# > saved checkpoint at 270
# > saved checkpoint at 280
# > saved checkpoint at 290
# > saved checkpoint at 300
# > saved checkpoint at 310
# > saved checkpoint at 320
# > saved checkpoint at 330
# > saved checkpoint at 340
# > saved checkpoint at 350
# > saved checkpoint at 360
# > saved checkpoint at 370
# > saved checkpoint at 380
# > saved checkpoint at 390
# > saved checkpoint at 400
# > saved checkpoint at 410
# > saved checkpoint at 420
# > saved checkpoint at 430
# > saved checkpoint at 440
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 450
# > saved checkpoint at 460
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 470
# > saved checkpoint at 480
# > saved checkpoint at 490
# > saved checkpoint at 500
# > saved checkpoint at 510
# > saved checkpoint at 520
# > saved checkpoint at 530
# > saved checkpoint at 540
# > saved checkpoint at 550
# > saved checkpoint at 560
# > saved checkpoint at 570
# > saved checkpoint at 580
# > saved checkpoint at 590
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 600
# > saved checkpoint at 610
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 620
# > saved checkpoint at 630
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 640
# > saved checkpoint at 650
# > saved checkpoint at 660
# > saved checkpoint at 670
# > saved checkpoint at 680
# > saved checkpoint at 690
# > saved checkpoint at 700
# > saved checkpoint at 710
# > saved checkpoint at 720
# > saved checkpoint at 730
# > saved checkpoint at 740
# > saved checkpoint at 750
# > saved checkpoint at 760
# > saved checkpoint at 770
# > saved checkpoint at 780
# > saved checkpoint at 790
# > saved checkpoint at 800
# > saved checkpoint at 810
# > saved checkpoint at 820
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 830
# > saved checkpoint at 840
# > saved checkpoint at 850
# > saved checkpoint at 860
# > saved checkpoint at 870
# > saved checkpoint at 880
# > saved checkpoint at 890
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 900
# > saved checkpoint at 910
# > saved checkpoint at 920
# > saved checkpoint at 930
# > saved checkpoint at 940
# > saved checkpoint at 950
# > saved checkpoint at 960
# > saved checkpoint at 970
# > saved checkpoint at 980
# > saved checkpoint at 990
# > saved checkpoint at 1000
# > saved checkpoint at 1010
# > saved checkpoint at 1020
# > saved checkpoint at 1030
# > saved checkpoint at 1040
# > saved checkpoint at 1050
# > saved checkpoint at 1060
# > saved checkpoint at 1070
# > saved checkpoint at 1080
# > saved checkpoint at 1090
# > saved checkpoint at 1100
# > saved checkpoint at 1110
# > saved checkpoint at 1120
# > saved checkpoint at 1130
# > saved checkpoint at 1140
# > saved checkpoint at 1150
# > saved checkpoint at 1160
# > saved checkpoint at 1170
# > saved checkpoint at 1180
# > saved checkpoint at 1190

# %%
dev_ds = generate_split("dev")
# Out:
# 0it [00:00, ?it/s]
# > saved checkpoint at 10
# > saved checkpoint at 20
# > saved checkpoint at 30
# > saved checkpoint at 40
# > saved checkpoint at 50
# > saved checkpoint at 60
# > saved checkpoint at 70
# > saved checkpoint at 80
# > saved checkpoint at 90
# > saved checkpoint at 100
# > saved checkpoint at 110
# > saved checkpoint at 120
# > saved checkpoint at 130
# > saved checkpoint at 140
# > saved checkpoint at 150
# > saved checkpoint at 160
# > saved checkpoint at 170
# > saved checkpoint at 180
# > saved checkpoint at 190
# > saved checkpoint at 200
# > saved checkpoint at 210
# > saved checkpoint at 220
# > saved checkpoint at 230
# > saved checkpoint at 240
# Timed out Rate limit reached for gpt-3.5-turbo in organization org-tUY6bwaZRR8IwltlIGVE2rVA on tokens per min (TPM): Limit 1000000, Used 999737, Requested 447. Please try again in 11ms. Visit https://platform.openai.com/account/rate-limits to learn more.. Waiting for 10 seconds.
# > saved checkpoint at 250
# > saved checkpoint at 260
# > saved checkpoint at 270
# > saved checkpoint at 280
# > saved checkpoint at 290
# > saved checkpoint at 300
# > saved checkpoint at 310
# > saved checkpoint at 320
# > saved checkpoint at 330
# > saved checkpoint at 340
# > saved checkpoint at 350
# > saved checkpoint at 360
# > saved checkpoint at 370
# > saved checkpoint at 380
# > saved checkpoint at 390
# > saved checkpoint at 400
# > saved checkpoint at 410
# > saved checkpoint at 420
# > saved checkpoint at 430
# > saved checkpoint at 440
# > saved checkpoint at 450
# > saved checkpoint at 460
# > saved checkpoint at 470
# > saved checkpoint at 480
# > saved checkpoint at 490
# > saved checkpoint at 500
# > saved checkpoint at 510
# > saved checkpoint at 520
# > saved checkpoint at 530
# > saved checkpoint at 540
# > saved checkpoint at 550
# > saved checkpoint at 560
# > saved checkpoint at 570
# > saved checkpoint at 580
# > saved checkpoint at 590
# > saved checkpoint at 600
# > saved checkpoint at 610
# > saved checkpoint at 620
# > saved checkpoint at 630
# > saved checkpoint at 640
# > saved checkpoint at 650
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 10 seconds.
# > saved checkpoint at 660
# > saved checkpoint at 670
# > saved checkpoint at 680
# > saved checkpoint at 690
# > saved checkpoint at 700
# > saved checkpoint at 710
# > saved checkpoint at 720
# > saved checkpoint at 730
# > saved checkpoint at 740
# > saved checkpoint at 750
# Timed out Rate limit reached for gpt-3.5-turbo in organization org-tUY6bwaZRR8IwltlIGVE2rVA on tokens per min (TPM): Limit 1000000, Used 999762, Requested 457. Please try again in 13ms. Visit https://platform.openai.com/account/rate-limits to learn more.. Waiting for 10 seconds.
# > saved checkpoint at 760
# > saved checkpoint at 770
# > saved checkpoint at 780
# > saved checkpoint at 790
# > saved checkpoint at 800
# > saved checkpoint at 810
# > saved checkpoint at 820
# > saved checkpoint at 830
# > saved checkpoint at 840
# > saved checkpoint at 850
# > saved checkpoint at 860
# > saved checkpoint at 870
# > saved checkpoint at 880
# > saved checkpoint at 890
# > saved checkpoint at 900
# > saved checkpoint at 910
# > saved checkpoint at 920
# > saved checkpoint at 930
# > saved checkpoint at 940
# > saved checkpoint at 950
# > saved checkpoint at 960
# > saved checkpoint at 970
# > saved checkpoint at 980
# > saved checkpoint at 990
# > saved checkpoint at 1000
# > saved checkpoint at 1010
# > saved checkpoint at 1020
# > saved checkpoint at 1030
# > saved checkpoint at 1040
# > saved checkpoint at 1050
# > saved checkpoint at 1060
# > saved checkpoint at 1070
# > saved checkpoint at 1080
# > saved checkpoint at 1090
# > saved checkpoint at 1100
# > saved checkpoint at 1110
# > saved checkpoint at 1120
# > saved checkpoint at 1130
# > saved checkpoint at 1140
# > saved checkpoint at 1150
# > saved checkpoint at 1160
# > saved checkpoint at 1170
# > saved checkpoint at 1180
# > saved checkpoint at 1190

# %% [markdown]
# ### Negative samples

# %%
no_label_gen = pd.read_csv("generated/PROTOTYPE/no_label_gen.csv").drop("Unnamed: 0", axis=1)
no_label_gen["skills"] = no_label_gen["skills"].apply(lambda x : [x])
no_label_gen.head(3)
# Out:
#                                             sentence      skills
# 0  Join our innovative tech company headquartered...  [NO LABEL]
# 1  Kick-start your career with a leading financia...  [NO LABEL]
# 2  Be part of a dynamic e-commerce giant headquar...  [NO LABEL]

# %%
from sklearn.model_selection import train_test_split

no_label_train, no_label_rest = train_test_split(no_label_gen, test_size=int(.3 * len(no_label_gen.index)))
no_label_test, no_label_dev = train_test_split(no_label_rest, test_size=int(.5 * len(no_label_rest.index)))

print("NO LABEL TRAIN : ", len(no_label_train.index))
print("NO LABEL TEST : ", len(no_label_test.index))
print("NO LABEL DEV : ", len(no_label_dev.index))

assert(set(no_label_train["sentence"].values).intersection(no_label_test["sentence"].values) == set())
assert(set(no_label_dev["sentence"].values).intersection(no_label_test["sentence"].values) == set())
assert(set(no_label_train["sentence"].values).intersection(no_label_dev["sentence"].values) == set())
# Out:
# NO LABEL TRAIN :  341
# NO LABEL TEST :  73
# NO LABEL DEV :  72

# %%
no_label_split = {
    'train': no_label_train,
    'dev': no_label_dev,
    'test': no_label_test,

}
def merge(split):
    print("> SPLIT : ", split)
    no_label = no_label_split[split][["sentence", "skills"]]
    with open(f"generated/SKILLSPAN/{split}.pkl", 'rb') as f:
        complete_split = pickle.load(f)
    df_split = pd.DataFrame(complete_split)
    df_split.columns = ["skills", "sentence"]
    print("Number of sample before : ", len(df_split.index))
    df_split_complete = pd.concat([df_split, no_label])
    df_split_complete = df_split_complete.sample(len(df_split_complete.index))
    print("Number of sample after : ", len(df_split_complete.index))
    df_split_complete.to_csv(f"generated/SKILLSPAN/{split}_complete.csv")
    
merge("train")
merge("test")
merge("dev")
# Out:
# > SPLIT :  train
# Number of sample before :  5724
# Number of sample after :  6065
# > SPLIT :  test
# Number of sample before :  1144
# Number of sample after :  1217
# > SPLIT :  dev
# Number of sample before :  1183
# Number of sample after :  1255

# %% [markdown]
# ### Adding excluded samples

# %%
with open(ESCO_DIR + "excluded_skill_span_tax_emb.pkl", "rb") as f:
    excluded_tax_sp = pickle.load(f).drop("Unnamed: 0", axis=1)
excluded_tax_sp.head(3)
# Out:
#                                               Source  \
# 0  http://data.europa.eu/esco/skill/0005c151-5b5a...
# 1  http://data.europa.eu/esco/skill/00064735-8fad...
# 2  http://data.europa.eu/esco/skill/000709ed-2be5...
#
#                         Type Level 4  \
# 0               manage musical staff
# 1  supervise correctional procedures
# 2    apply anti-oppressive practices
#
#                                            altLabels  \
# 0  manage staff of music\ncoordinate duties of mu...
# 1  oversee prison procedures\nmanage correctional...
# 2  apply non-oppressive practices\napply an anti-...
#
#                                           Definition Dimension  \
# 0  Assign and manage staff tasks in areas such as...    skills
# 1  Supervise the operations of a correctional fac...    skills
# 2  Identify oppression in societies, economies, c...    skills
#
#            Type Level 1                                       Type Level 2  \
# 0     management skills                                 supervising people
# 1     management skills  organising, planning and scheduling work and a...
# 2  assisting and caring                           protecting and enforcing
#
#                        Type Level 3  unique_id  \
# 0       supervising a team or group       1000
# 1  directing operational activities       1001
# 2          protecting and enforcing       1002
#
#                                 name  \
# 0               manage musical staff
# 1  supervise correctional procedures
# 2    apply anti-oppressive practices
#
#                                      name+definition  \
# 0  manage musical staff : assign and manage staff...
# 1  supervise correctional procedures : supervise ...
# 2  apply anti-oppressive practices : identify opp...
#
#                                           embeddings
# 0  [[tensor(0.3457), tensor(-0.5795), tensor(-0.0...
# 1  [[tensor(0.0875), tensor(-0.5299), tensor(-0.1...
# 2  [[tensor(0.9495), tensor(-0.7187), tensor(-0.5...

# %%
gen = SkillsGenerator(taxonomy=excluded_tax_sp, 
                taxonomy_is_embedded=True,
                combination_dist=combination_dist,
                popularity=F)
    
gen_args = {
        "nb_generation" : 500, # number of samples
        "threshold" : 0.83, # not considering skills that are less than .8 similar
        "beam_size" : 20, # considering 20 skills
        "temperature_pairing": 1, # popularity to be skewed toward popular skills
        "temperature_sample_size": 1,
        "frequency_select": True, # wether we select within the NN acording to frequency
    }


combinations = list(gen.balanced_nbred_iter(**gen_args))


datagen = DatasetGenerator(excluded_tax_sp,
                           None, ## no references, we work in Zero-Shot
                           word_emb_model,
                           word_emb_tokenizer,
                           additional_info)

generation_args = {
        "skill_generator": combinations, 
        "specific_few_shots": False,
        "model": "gpt-3.5",
        "gen_mode": "PROTOTYPE",
        "autosave": True,
        "autosave_file": f"generated/SKILLSPAN/excluded_tax_samples.json",
        "checkpoints_freq":10
    }
res = datagen.generate_ds(**generation_args)
# Out:
# 0it [00:00, ?it/s]
# > saved checkpoint at 10
# > saved checkpoint at 20
# > saved checkpoint at 30
# > saved checkpoint at 40
# > saved checkpoint at 50
# > saved checkpoint at 60
# > saved checkpoint at 70
# > saved checkpoint at 80
# > saved checkpoint at 90
# > saved checkpoint at 100
# > saved checkpoint at 110
# > saved checkpoint at 120
# > saved checkpoint at 130
# > saved checkpoint at 140
# > saved checkpoint at 150
# > saved checkpoint at 160
# > saved checkpoint at 170
# > saved checkpoint at 180
# > saved checkpoint at 190
# > saved checkpoint at 200
# > saved checkpoint at 210
# > saved checkpoint at 220
# > saved checkpoint at 230
# > saved checkpoint at 240
# > saved checkpoint at 250
# > saved checkpoint at 260
# > saved checkpoint at 270
# > saved checkpoint at 280
# > saved checkpoint at 290
# > saved checkpoint at 300
# > saved checkpoint at 310
# > saved checkpoint at 320
# > saved checkpoint at 330
# > saved checkpoint at 340
# > saved checkpoint at 350
# > saved checkpoint at 360
# > saved checkpoint at 370
# > saved checkpoint at 380
# > saved checkpoint at 390
# > saved checkpoint at 400
# > saved checkpoint at 410
# > saved checkpoint at 420
# > saved checkpoint at 430
# > saved checkpoint at 440
# > saved checkpoint at 450
# > saved checkpoint at 460
# > saved checkpoint at 470
# > saved checkpoint at 480
# > saved checkpoint at 490

# %%
ex_label = pd.DataFrame(res)
ex_label.columns = ["skills", "sentence"]
ex_label["skills"] = [["NO LABEL"]] * len(ex_label.index)
ex_label_train, ex_label_rest = train_test_split(ex_label, test_size=int(.3 * len(ex_label.index)))
ex_label_test, ex_label_dev = train_test_split(ex_label_rest, test_size=int(.5 * len(ex_label_rest.index)))

print("NO LABEL TRAIN : ", len(ex_label_train.index))
print("NO LABEL TEST : ", len(ex_label_test.index))
print("NO LABEL DEV : ", len(ex_label_dev.index))

assert(set(ex_label_train["sentence"].values).intersection(ex_label_test["sentence"].values) == set())
assert(set(ex_label_dev["sentence"].values).intersection(ex_label_test["sentence"].values) == set())
assert(set(ex_label_train["sentence"].values).intersection(ex_label_dev["sentence"].values) == set())


ex_label_split = {
    'train': ex_label_train,
    'dev': ex_label_dev,
    'test': ex_label_test,

}

def merge(split):
    print("> SPLIT : ", split)
    no_label = ex_label_split[split][["sentence", "skills"]]
    complete_split = pd.read_csv(f"generated/SKILLSPAN/{split}_complete.csv").drop("Unnamed: 0", axis=1)
    complete_split["skills"] = complete_split["skills"].apply(eval)
    df_split = pd.DataFrame(complete_split)
    df_split.columns = ["skills", "sentence"]
    print("Number of sample before : ", len(df_split.index))
    df_split_complete = pd.concat([df_split, no_label])
    df_split_complete = df_split_complete.sample(len(df_split_complete.index))
    print("Number of sample after : ", len(df_split_complete.index))
    df_split_complete.to_csv(f"generated/SKILLSPAN/{split}_final.csv", index=False)
    
merge("train")
merge("test")
merge("dev")
# Out:
# NO LABEL TRAIN :  299
# NO LABEL TEST :  64
# NO LABEL DEV :  64
# > SPLIT :  train
# Number of sample before :  6065
# Number of sample after :  6364
# > SPLIT :  test
# Number of sample before :  1217
# Number of sample after :  1281
# > SPLIT :  dev
# Number of sample before :  1255
# Number of sample after :  1319
