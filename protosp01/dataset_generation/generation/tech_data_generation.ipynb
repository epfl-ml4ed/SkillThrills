# %% [markdown]
# ### Tech Data Generation

# %%
import pickle
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import json
from generator import SkillsGenerator, DatasetGenerator
from tqdm.notebook import tqdm

from transformers import AutoModel, AutoTokenizer


# %load_ext autoreload
# %autoreload 2

# %%
## Loading the embedded taxonomy
emb_sh = "_jbEn"
with open(f"../../../data/taxonomy/taxonomy_embeddings{emb_sh}.pkl", "rb") as f:
    emb_tax = pickle.load(f)
    emb_tax["name"] = emb_tax["name+definition"].apply(
        lambda x : x.split(" : ")[0]
    )


## popularity measures
with open("frequency_vals.json", "r") as f:
    F = json.load(f)

## Loading the combination dist
combination_dist = np.loadtxt("assoc_skilled_dist.npy")

# %%
def save_generation(text_file, res):
    tres = ""
    for (skills, job_posting) in res:
        tres += "skills : "+str(skills) + "\n"
        tres += (job_posting if job_posting is not None else "[NULL]") + "\n"
        tres += "-"*100 + "\n"

    with open(text_file, "w") as f:
        f.write(tres)

    print("Result saved in : ./" + text_file)

# %%
emb_tax.head(5)
# Out:
#    unique_id                                    name+definition  \
# 0          0  manage musical staff : Assign and manage staff...
# 1          1  supervise correctional procedures : Supervise ...
# 2          2  apply anti-oppressive practices : Identify opp...
# 3          3  control compliance of railway vehicles regulat...
# 4          4  identify available services : Identify the dif...
#
#                                           embeddings  \
# 0  [[tensor(0.5317), tensor(-0.4808), tensor(-0.0...
# 1  [[tensor(0.1043), tensor(-0.5770), tensor(-0.1...
# 2  [[tensor(0.9992), tensor(-0.7967), tensor(-0.6...
# 3  [[tensor(0.6206), tensor(-0.4386), tensor(0.66...
# 4  [[tensor(1.0326), tensor(0.0204), tensor(-0.98...
#
#                                                 name
# 0                               manage musical staff
# 1                  supervise correctional procedures
# 2                    apply anti-oppressive practices
# 3  control compliance of railway vehicles regulat...
# 4                        identify available services

# %%
## laoding the tech skills to reduce the skills we're assessing
tech_skills = pd.read_csv("../../../../esco/digitalSkillsCollection_en.csv")
tech_skills_names = set(tech_skills.preferredLabel.values).union(set(tech_skills.altLabels.values))
print("Complete number of skills : ", len(emb_tax.index))
print("Number of tech skills : ", len(emb_tax[emb_tax.name.isin(tech_skills_names)].index))

tech_emb_tax = emb_tax[emb_tax.name.isin(tech_skills_names)]
# Out:
# Complete number of skills :  13896
# Number of tech skills :  1201

# %%
## loading the reference dataset
test = pd.read_csv("https://raw.githubusercontent.com/jensjorisdecorte/Skill-Extraction-benchmark/main/tech_test_annotations.csv")
test = test[~test.label.isin(["LABEL NOT PRESENT", "UNDERSPECIFIED"])]
multilabel = test.groupby("sentence").agg({"label": lambda x : x.tolist() , "span": lambda x : x.tolist()}).reset_index()
multilabel["skill+sentence"] = multilabel[["label", "sentence"]].apply(lambda x : str(x["label"]) + " : " + x["sentence"], axis=1)
multilabel.head(5)
# Out:
#                                             sentence  \
# 0  ( Cypress for frontend is a must have pytest f...
# 1  * Ability to analyse requirements and interact...
# 2  * Ability to support the developers in your te...
# 3  * Ability to work in large collaborative teams...
# 4  * Ability to work in large collaborative teams...
#
#                                                label  \
# 0                                         [Solidity]
# 1  [analyse business requirements, communicate wi...
# 2  [manage a team, lead others, mentor individual...
# 3  [work in teams, meet commitments, work in team...
# 4  [work in teams, meet commitments, think innova...
#
#                                                 span  \
# 0                                         [Solidity]
# 1  [analyse requirements, interact directly with ...
# 2  [support the developers in your team, leading,...
# 3  [work in large collaborative teams, achieve or...
# 4  [work in large collaborative teams, achieve or...
#
#                                       skill+sentence
# 0  ['Solidity'] : ( Cypress for frontend is a mus...
# 1  ['analyse business requirements', 'communicate...
# 2  ['manage a team', 'lead others', 'mentor indiv...
# 3  ['work in teams', 'meet commitments', 'work in...
# 4  ['work in teams', 'meet commitments', 'think i...

# %%
word_emb = "jjzha/jobbert-base-cased"
word_emb_model = AutoModel.from_pretrained(word_emb)
word_emb_tokenizer = AutoTokenizer.from_pretrained(word_emb)
additional_info = tech_skills[["preferredLabel", "status", "skillType", "reuseLevel", "altLabels", "description"]].set_index("preferredLabel").to_dict("index")


gen = SkillsGenerator(taxonomy=tech_emb_tax, 
                taxonomy_is_embedded=True,
                combination_dist=combination_dist,
                popularity=F)



datagen = DatasetGenerator(emb_tax,
                           multilabel,
                           word_emb_model,
                           word_emb_tokenizer,
                           additional_info)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at jjzha/jobbert-base-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Zero shot GPT-4 with single skills

# %%
stochastic_gen_args = {
"total_generations" : 50, # number of samples
"threshold" : 0.6, # not considering skills that are less than .8 similar
"beam_size" : 50, # considering 20 skills
"temperature_skill" : 1, # we want to see diversity in generated words
"temperature_pairing": 2, # popularity to be skewed toward popular skills
"temperature_sample_size": 0.1,
"frequency_select": True, # wether we select within the NN acording to frequency
"upper_bound_skill_matching": 0
}

generations = gen.stochastic_inf_iter(**stochastic_gen_args)

# %%
res = datagen.generate_ds(generations, specific_few_shots=True, nb_few_shots=0)
# Out:
# 0it [00:00, ?it/s]
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['e-agriculture']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['SAS language']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['file documents']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['use modern electronic navigational aids']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['style sheet languages']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['evaluate musical ideas']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['analyse pipeline database information']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['provide guidelines for content development']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['maintain ICT server']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['use software design patterns']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['evaluate cost of software products']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['debug software']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['Microsoft Access']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['manage meteorological database']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['manage membership database']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['use e-procurement ']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['statistical analysis system software']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['Nessus']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['manage flight data communications programme']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['develop animations']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['perform image editing']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['design cloud architecture']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['analyse gambling data']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['evaluate translation technologies']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['monitor ICT research']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['install mechatronic equipment']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['green computing']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['utilise computer-aided software engineering tools']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['software interaction design']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['perform forensic preservations of digital devices']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['perform online data analysis']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['operate digital hardware']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['Engrade']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['use sound measuring instruments']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['create advocacy material']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['instrumentation engineering']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['develop ICT workflow']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['develop ICT safety information']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['add computer components']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['types of satellites']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['simulate transport problems']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['browse, search and filter data, information and digital content']
# Timed out Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=20). Waiting for 5 seconds.
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['produce scanned images']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['conduct analysis of ship data']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['apply desktop publishing techniques']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['design database backup specifications']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['smart grids systems']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['use databases']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['computer vision']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['use CAD for soles']

# %%
text_file = "generated/zero_shot_gpt4_tech_50_samples.txt"
save_generation(text_file, res)
# Out:
# Result saved in : ./generated/zero_shot_gpt4_tech_50_samples.txt

# %% [markdown]
# ### Zero shot GPT-4 with skills pairing

# %%
stochastic_gen_args = {
"total_generations" : 50, # number of samples
"threshold" : 0.87, # not considering skills that are less than .8 similar
"beam_size" : 50, # considering 20 skills
"temperature_skill" : 1, # we want to see diversity in generated words
"temperature_pairing": 2, # popularity to be skewed toward popular skills
"temperature_sample_size": 0.1,
"frequency_select": True, # wether we select within the NN acording to frequency
"upper_bound_skill_matching": 5
}

generations = gen.stochastic_inf_iter(**stochastic_gen_args)

# %%
res = datagen.generate_ds(generations, specific_few_shots=True, nb_few_shots=0)
# Out:
# 0it [00:00, ?it/s]
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['manage open publications', 'monitor ICT research']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['copyright and licenses related to digital content']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['manage database']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['collection management software']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['artificial neural networks']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['use internet to increase sales', 'e-commerce systems']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['normalise data']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['data analytics', 'data mining methods', 'perform data analysis', 'apply statistical analysis techniques', 'inspect data', 'use analytics for commercial purposes']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['plan marketing campaigns', 'plan digital marketing', 'plan social media marketing campaigns']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['design chassis', 'create 3D CAD footwear prototypes']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['search engine optimisation']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['Drupal', 'Joomla', 'WebCMS', 'WordPress']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['publishing strategy']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['maintain data entry requirements']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['rig 3D characters']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['printed circuit boards testing methods', 'hardware testing methods', 'test hardware']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['perform computer analyses of geotechnical structures']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['perform virtual simulation ']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['e-tailoring']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['electronic locks']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['use CADD software']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['collect real-time geolocation information']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['penetration testing tool', 'Parrot Security OS', 'WhiteHat Sentinel', 'THC Hydra', 'Metasploit']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['ICT system user requirements', 'analyse ICT system', 'identify ICT user needs', "assess users' interaction with ICT applications"]
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['develop digital educational materials', 'deliver online training']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['Jenkins (tools for software configuration management)']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['implement spam protection']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['record multi-track sound']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['collect data using GPS']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['database development tools', 'R']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['operate radar equipment', 'use radar navigation']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['Hadoop', 'MarkLogic', 'data extraction, transformation and loading tools']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['mobile device management']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['output electronic files']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['manage ICT virtualisation environments']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['product data management']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['perform ICT troubleshooting']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['create risk maps']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['advise customers on type of computer equipment']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['manage radiology information system']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['operate automated process control']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['analyse information systems', 'manage data collection systems']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['social media marketing techniques', 'plan social media marketing campaigns', 'digital marketing techniques']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['Visual Studio .NET']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['create 3D texture map', 'use performance 3D visualisation techniques ']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['create digital game characters', 'specify digital game scenes']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['evaluate information services using metrics']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['perform software recovery testing', 'execute software tests']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['sensors']
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['conduct radiotherapy computer planning']

# %%
text_file = "generated/zero_shot_gpt4_tech_50_samples_skill_pairing.txt"
save_generation(text_file, res)
# Out:
# Result saved in : ./generated/zero_shot_gpt4_tech_50_samples_skill_pairing.txt

# %% [markdown]
# ### Specific few shots GPT-4 with pairing

# %%
stochastic_gen_args = {
"total_generations" : 10, # number of samples
"threshold" : 0.87, # not considering skills that are less than .8 similar
"beam_size" : 50, # considering 20 skills
"temperature_skill" : 1, # we want to see diversity in generated words
"temperature_pairing": 2, # popularity to be skewed toward popular skills
"temperature_sample_size": 0.05,
"frequency_select": True, # wether we select within the NN acording to frequency
"upper_bound_skill_matching": 5
}

generations = gen.stochastic_inf_iter(**stochastic_gen_args)

generation_args = {
    "generations": generations, # sample generator
    "specific_gew_shots": True, # enable the use of specific few shots
    "nb_few_shots": 3, # number of few shots to use
    "shot_sim_treshold": 0.75,
    "model": "gpt-4"
}
res = datagen.generate_ds(**generation_args)
# Out:
# 0it [00:00, ?it/s]
# ##################################################
# [0.75619775 0.75559354 0.7481957 ]
# input skills :  ['manage quantitative data', 'inspect data', 'manage research data', 'record data from biomedical tests', 'collect ICT data', 'use data processing techniques']
# top sim ids :  [ 91 206 210]
# associated_skills :  ["skills: ['data extraction, transformation and loading tools', 'use databases', 'data extraction, transformation and loading tools']"
#  "skills: ['analyse test data']"
#  "skills: ['develop automated software tests', 'assess reliability of data', 'visual presentation techniques']"]
# ##################################################
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['data extraction, transformation and loading tools', 'use databases', 'data extraction, transformation and loading tools']
# Job Opening : Develop interfaces to ERP and POS software providers and work on ETL pipelines to integrate our customers data bases ..
# skills: ['analyse test data']
# Job Opening : Testing and analysis of test results.
# skills: ['develop automated software tests', 'assess reliability of data', 'visual presentation techniques']
# Job Opening : The role requires End to end automated testing with particular focus on data integrity performance and presentation quality ..
# skills: skills: ['develop automated software tests', 'assess reliability of data', 'visual presentation techniques']
# ##################################################
# [0.75852764 0.7205913  0.70634025]
# input skills :  ['video-games trends']
# top sim ids :  [176  99  16]
# associated_skills :  ["skills: ['adapt developed game to the market']"
#  "skills: ['entertainment industry']"
#  "skills: ['monitor technology trends', 'monitor technology trends']"]
# ##################################################
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['adapt developed game to the market']
# Job Opening : Previous experience with developing mobile games with a large amount of content delivery and a good sense of F2P game design.
# skills: ['entertainment industry']
# Job Opening : Entertainment Gaming Mobile Game.
# skills: ['monitor technology trends', 'monitor technology trends']
# Job Opening : * Knowledge of industry-wide technology trends and best practices.
# skills: skills: ['monitor technology trends', 'monitor technology trends']
# ##################################################
# [0.7306598  0.72714627 0.72001106]
# input skills :  ['control engineering', 'instrumentation engineering']
# top sim ids :  [239  62 328]
# associated_skills :  ["skills: ['design information system', 'information structure', 'algorithms']"
#  "skills: ['tools for ICT test automation']"
#  "skills: ['assess the life cycle of resources', 'quality assurance methodologies']"]
# ##################################################
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['design information system', 'information structure', 'algorithms']
# Job Opening : You have a deep understanding of system design data structures and algorithms.
# skills: ['tools for ICT test automation']
# Job Opening : Candidates will be expected to perform both Automation and Functional Testing for our Middle office platform for Futures Options and OTC ..
# skills: ['assess the life cycle of resources', 'quality assurance methodologies']
# Job Opening : • Lifecycle principles and quality assurance processes and methodologies ..
# skills: skills: ['assess the life cycle of resources', 'quality assurance methodologies']
# ##################################################
# [0.75506556 0.73302495 0.7210398 ]
# input skills :  ['provide multimedia content', 'use presentation software']
# top sim ids :  [101 129  36]
# associated_skills :  ["skills: ['create prototype of user experience solutions']"
#  "skills: ['adapt developed game to the market', 'design the physical outlook of games', 'design the physical outlook of games', 'Unity (digital game creation systems)']"
#  "skills: ['aesthetics']"]
# ##################################################
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['create prototype of user experience solutions']
# Job Opening : Experience in UX especially making user experiences at an interactive degree.
# skills: ['adapt developed game to the market', 'design the physical outlook of games', 'design the physical outlook of games', 'Unity (digital game creation systems)']
# Job Opening : In your day-to-day work you will be using Unity to implement new game features such as end-of-content features the family system and tournaments and will be responsible for making the designs look final and pretty for our end users ..
# skills: ['aesthetics']
# Job Opening : An eye for aesthetics design and faithful implementation.
# skills: skills: ['aesthetics']
# ##################################################
# [0.700212   0.6491366  0.63970053]
# input skills :  ['put uncut recordings into computer']
# top sim ids :  [264 296 115]
# associated_skills :  ["skills: ['identify problems']" "skills: ['use functional programming']"
#  "skills: ['create solutions to problems']"]
# ##################################################
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['identify problems']
# Job Opening : You will identify record document thoroughly and track bugs ..
# skills: ['use functional programming']
# Job Opening : equally are effusive about functional programming ..
# skills: ['create solutions to problems']
# Job Opening : Following up on issues raised.
# skills: skills: ['create solutions to problems']
# ##################################################
# [0.75891095 0.756069   0.7479507 ]
# input skills :  ['create data sets']
# top sim ids :  [ 87 207  44]
# associated_skills :  ["skills: ['design process']" "skills: ['identify service requirements']"
#  "skills: ['manage standard enterprise resource planning system']"]
# ##################################################
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['design process']
# Job Opening : Design ( and documenting ) of own solutions or sub-sets of solutions.
# skills: ['identify service requirements']
# Job Opening : That means defining and implementing services that make up a vital sub-system in your area ..
# skills: ['manage standard enterprise resource planning system']
# Job Opening : As a backend engineer you're part of the team that lays the foundation to our solution: We interact with different kinds of data sources and sinks such as enterprise resource planning ( ERP ) and point-of-sales ( POS ) systems ..
# skills: skills: ['manage standard enterprise resource planning system']
# ##################################################
# [0.75221634 0.74149626 0.7246577 ]
# input skills :  ['field-programmable gate arrays']
# top sim ids :  [241 185 110]
# associated_skills :  ["skills: ['design application interfaces']"
#  "skills: ['define software architecture']"
#  "skills: ['perform ICT troubleshooting']"]
# ##################################################
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['design application interfaces']
# Job Opening : You have experience defining and modelling a consumable API ..
# skills: ['define software architecture']
# Job Opening : Responsible for describing a solution architecture with the most important components and their interfaces.
# skills: ['perform ICT troubleshooting']
# Job Opening : Experienced in designing analyzing optimising code and troubleshooting large-scale distributed systems ..
# skills: skills: ['perform ICT troubleshooting']
# ##################################################
# [0.78661186 0.7480623  0.74609303]
# input skills :  ['develop reporting software']
# top sim ids :  [ 91 107 206]
# associated_skills :  ["skills: ['data extraction, transformation and loading tools', 'use databases', 'data extraction, transformation and loading tools']"
#  "skills: ['develop test procedures', 'Objective-C', 'Java (computer programming)']"
#  "skills: ['analyse test data']"]
# ##################################################
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['data extraction, transformation and loading tools', 'use databases', 'data extraction, transformation and loading tools']
# Job Opening : Develop interfaces to ERP and POS software providers and work on ETL pipelines to integrate our customers data bases ..
# skills: ['develop test procedures', 'Objective-C', 'Java (computer programming)']
# Job Opening : Experience with TDD ( test driven development ) Knowledge of other analytics tools and programming languages especially Objective C and Java.
# skills: ['analyse test data']
# Job Opening : Testing and analysis of test results.
# skills: skills: ['analyse test data']
# ##################################################
# [0.6766078 0.6765355 0.6675886]
# input skills :  ['green computing']
# top sim ids :  [ 44 110 252]
# associated_skills :  ["skills: ['manage standard enterprise resource planning system']"
#  "skills: ['perform ICT troubleshooting']"
#  "skills: ['integrate system components', 'administer ICT system', 'DevOps']"]
# ##################################################
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['manage standard enterprise resource planning system']
# Job Opening : As a backend engineer you're part of the team that lays the foundation to our solution: We interact with different kinds of data sources and sinks such as enterprise resource planning ( ERP ) and point-of-sales ( POS ) systems ..
# skills: ['perform ICT troubleshooting']
# Job Opening : Experienced in designing analyzing optimising code and troubleshooting large-scale distributed systems ..
# skills: ['integrate system components', 'administer ICT system', 'DevOps']
# Job Opening : You know DevOps inside out and you know how to build implement and operate a system ..
# skills: skills: ['integrate system components', 'administer ICT system', 'DevOps']
# ##################################################
# [0.73915625 0.71128875 0.70875585]
# input skills :  ['manage system security']
# top sim ids :  [106 110  59]
# associated_skills :  ["skills: ['perform ICT troubleshooting']"
#  "skills: ['perform ICT troubleshooting']"
#  "skills: ['apply information security policies']"]
# ##################################################
# ----------------------------------------------------------------------------------------------------
# You are a hiring manager for a big company. You need to define write a job opening for different skill requirements in your company.
#
# You are a hiring manager for a big company and your goal is to write the perfect sentence to describe job that uses a set of skills. You'll be given a set of skill, the job posting will reference each of them explicitely or implicitely. The job you describe must include capailities in each of these skills. No external skills should be mentionned. The description of the job should be one line long and be as specific as possible.
#
# skills: ['perform ICT troubleshooting']
# Job Opening : Experience in troubleshooting IT infrastructure related issues advantageous ..
# skills: ['perform ICT troubleshooting']
# Job Opening : Experienced in designing analyzing optimising code and troubleshooting large-scale distributed systems ..
# skills: ['apply information security policies']
# Job Opening : Azure Storage Azure EventHub Azure Functions Azure Data Lake Azure CosmosDB Security Principles ..
# skills: skills: ['apply information security policies']

# %%
datagen.generate_specific_few_shots(["SQL", "Scala"], 3, 0.0)
# Out:
# ##################################################
# [0.76983726 0.747653   0.7474016 ]
# input skills :  ['SQL', 'Scala']
# top sim ids :  [107 335 196]
# ["skills: ['develop test procedures', 'Objective-C', 'Java (computer programming)']\nJob Opening : Experience with TDD ( test driven development ) Knowledge of other analytics tools and programming languages especially Objective C and Java.\n", "skills: ['tools for ICT test automation']\nJob Opening : • Very good understanding of test automation frameworks ..\n", "skills: ['database management systems', 'Python (computer programming)']\nJob Opening : Strong familiarity with database structures webapp design in Python and ORMs ( Django ORM SQLAlchemy ) and can adapt them as required.\n"]
# ##################################################
# ["skills: ['develop test procedures', 'Objective-C', 'Java (computer programming)']\nJob Opening : Experience with TDD ( test driven development ) Knowledge of other analytics tools and programming languages especially Objective C and Java.\n",
#  "skills: ['tools for ICT test automation']\nJob Opening : • Very good understanding of test automation frameworks ..\n",
#  "skills: ['database management systems', 'Python (computer programming)']\nJob Opening : Strong familiarity with database structures webapp design in Python and ORMs ( Django ORM SQLAlchemy ) and can adapt them as required.\n"]

# %% [markdown]
# ### PAPER-GEN : prompts from the Arxiv:2037.03539

# %%
stochastic_gen_args = {
"total_generations" : 10, # number of samples
"threshold" : 0.87, # not considering skills that are less than .8 similar
"beam_size" : 50, # considering 20 skills
"temperature_skill" : 1, # we want to see diversity in generated words
"temperature_pairing": 2, # popularity to be skewed toward popular skills
"temperature_sample_size": 0.01,
"frequency_select": True, # wether we select within the NN acording to frequency
"upper_bound_skill_matching": 5
}
generations = gen.stochastic_inf_iter(**stochastic_gen_args)


generation_args = {
    "skill_generator": generations, # sample generator
    "specific_few_shots": False, # enable the use of specific few shots
    "model": "gpt-3.5",
    "gen_mode": "PAPER-GEN"
    }

res = datagen.generate_ds(**generation_args)
# Out:
# 0it [00:00, ?it/s]
# prompts arguments >  []
# prompts arguments >  ['implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide forty examples that could be found in a job ad and refer to the skill or knowledge component. You may be given a skill family to help you disambiguate if the skill name could refer to multiple things. Ensure that your examples are well written and could be found in real job advertisement. Write a variety of different sentences and ensure your examples are well diversified. Use a variety of styles. Write examples using both shorter and longer sentences, as well as examples using short paragraphs of a few sentences, where sometimes only one is directly relevant to the skill. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. At least two of your examples must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) colour grade images with digital intermediate : colour grade images with D.I. | colour grade images with DI | color  grade images with digital intermediate , 2) render 3D images : render 3D images , 3) edit digital moving images : edit digital images of movement | edit moving digital images | edit digital moving images | edit digital footage | edit digital images of animation , 4) edit negatives : alter negatives | editing of negatives | retouch negatives | edit negatives | edit the negatives , 5) perform image editing : complete image editing | implement image editing | image editing performance | perform image editing | undertake image editing | performing image editing , 6) apply 3D imaging techniques : apply 3D imaging techniques ,  Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['colour grade images with digital intermediate', 'render 3D images', 'edit digital moving images', 'edit negatives', 'perform image editing', 'apply 3D imaging techniques']
# prompts arguments >  []
# prompts arguments >  ['implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide forty examples that could be found in a job ad and refer to the skill or knowledge component. You may be given a skill family to help you disambiguate if the skill name could refer to multiple things. Ensure that your examples are well written and could be found in real job advertisement. Write a variety of different sentences and ensure your examples are well diversified. Use a variety of styles. Write examples using both shorter and longer sentences, as well as examples using short paragraphs of a few sentences, where sometimes only one is directly relevant to the skill. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. At least two of your examples must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) CADD software : computer-aided design and drafting software | CADD softwares | CADD software | CADD software specifications and operations , 2) CAD for garment manufacturing : computer-aided design for garments manufacturing | CAD for clothing manufacturing | manufacturing of garments with CAD | CAD for garments | computer-aided design for wearing apparel manufacturing | CAD wearing apparel for manufacturing | CAD for garment manufacturing | computer-aided design for clothing manufacturing , 3) CAD software : CADD software | computer assisted design | CAD software | software computer assisted design and drafting software , 4) Adobe Photoshop : Adobe Photoshop CS5 | Adobe Photoshop Elements | Adobe Photoshop CS6 | Adobe Photoshop CS4 | Adobe Photoshop CC | Adobe Photoshop CS3 | Adobe Photoshop , 5) create 3D CAD footwear prototypes : elaborate 3D CAD footwear prototypes | design 3D footwear prototypes with computer-aided designing | elaborate 3D digital footwear prototypes | design 3D digital footwear prototypes | create 3D footwear prototypes with CAD software | create 3D footwear prototypes with computer-aided design software | create 3D digital footwear prototypes | create 3D CAD footwear prototypes , 6) produce textile designs : produce a textile design | produce textile designs | produce designs for textiles | draw sketches for textile designs | create textile designs ,  Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['CADD software', 'CAD for garment manufacturing', 'CAD software', 'Adobe Photoshop', 'create 3D CAD footwear prototypes', 'produce textile designs']
# prompts arguments >  []
# prompts arguments >  ['implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide forty examples that could be found in a job ad and refer to the skill or knowledge component. You may be given a skill family to help you disambiguate if the skill name could refer to multiple things. Ensure that your examples are well written and could be found in real job advertisement. Write a variety of different sentences and ensure your examples are well diversified. Use a variety of styles. Write examples using both shorter and longer sentences, as well as examples using short paragraphs of a few sentences, where sometimes only one is directly relevant to the skill. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. At least two of your examples must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) tools for ICT test automation : tools for test automation | tools for ICT test automation | test automation tools | Selenium , 2) develop ICT test suite : design software testing | develop ICT test suite ,  Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['tools for ICT test automation', 'develop ICT test suite']
# prompts arguments >  []
# prompts arguments >  ['implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide forty examples that could be found in a job ad and refer to the skill or knowledge component. You may be given a skill family to help you disambiguate if the skill name could refer to multiple things. Ensure that your examples are well written and could be found in real job advertisement. Write a variety of different sentences and ensure your examples are well diversified. Use a variety of styles. Write examples using both shorter and longer sentences, as well as examples using short paragraphs of a few sentences, where sometimes only one is directly relevant to the skill. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. At least two of your examples must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) observe celestial objects : observe celestial object | observe celestial objects | see astral bodies | observing celestial objects | view celestial bodies ,  Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['observe celestial objects']
# prompts arguments >  []
# prompts arguments >  ['implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide forty examples that could be found in a job ad and refer to the skill or knowledge component. You may be given a skill family to help you disambiguate if the skill name could refer to multiple things. Ensure that your examples are well written and could be found in real job advertisement. Write a variety of different sentences and ensure your examples are well diversified. Use a variety of styles. Write examples using both shorter and longer sentences, as well as examples using short paragraphs of a few sentences, where sometimes only one is directly relevant to the skill. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. At least two of your examples must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) manage data, information and digital content : manage data, information and digital content ,  Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['manage data, information and digital content']
# prompts arguments >  []
# prompts arguments >  ['implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide forty examples that could be found in a job ad and refer to the skill or knowledge component. You may be given a skill family to help you disambiguate if the skill name could refer to multiple things. Ensure that your examples are well written and could be found in real job advertisement. Write a variety of different sentences and ensure your examples are well diversified. Use a variety of styles. Write examples using both shorter and longer sentences, as well as examples using short paragraphs of a few sentences, where sometimes only one is directly relevant to the skill. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. At least two of your examples must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) install automation components : automation component fitting | fitting automation components | automation components installing | automation component installing | install automation components | automation components fitting | fit automation components | installing automation components ,  Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['install automation components']
# prompts arguments >  []
# prompts arguments >  ['implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide forty examples that could be found in a job ad and refer to the skill or knowledge component. You may be given a skill family to help you disambiguate if the skill name could refer to multiple things. Ensure that your examples are well written and could be found in real job advertisement. Write a variety of different sentences and ensure your examples are well diversified. Use a variety of styles. Write examples using both shorter and longer sentences, as well as examples using short paragraphs of a few sentences, where sometimes only one is directly relevant to the skill. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. At least two of your examples must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) programmable logic controller : PLC technology | computer control system | technology of PLCs | logic controller that is programmable | programmable logic controller | PLC ,  Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['programmable logic controller']
# prompts arguments >  []
# prompts arguments >  ['implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide forty examples that could be found in a job ad and refer to the skill or knowledge component. You may be given a skill family to help you disambiguate if the skill name could refer to multiple things. Ensure that your examples are well written and could be found in real job advertisement. Write a variety of different sentences and ensure your examples are well diversified. Use a variety of styles. Write examples using both shorter and longer sentences, as well as examples using short paragraphs of a few sentences, where sometimes only one is directly relevant to the skill. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. At least two of your examples must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) manage radiology information system : manage radiology information system | manage radiology information systems | manage and distribute radiological images and data | handle radiology information system | develop and maintain radiology information system | manage radiology-information system ,  Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['manage radiology information system']
# prompts arguments >  []
# prompts arguments >  ['implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide forty examples that could be found in a job ad and refer to the skill or knowledge component. You may be given a skill family to help you disambiguate if the skill name could refer to multiple things. Ensure that your examples are well written and could be found in real job advertisement. Write a variety of different sentences and ensure your examples are well diversified. Use a variety of styles. Write examples using both shorter and longer sentences, as well as examples using short paragraphs of a few sentences, where sometimes only one is directly relevant to the skill. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. At least two of your examples must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) operate audio equipment : operate audio equipment | operate broadcast studio controls | apply audio technology , 2) use audio reproduction software : use audio reproduction software ,  Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['operate audio equipment', 'use audio reproduction software']
# prompts arguments >  []
# prompts arguments >  ['implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide forty examples that could be found in a job ad and refer to the skill or knowledge component. You may be given a skill family to help you disambiguate if the skill name could refer to multiple things. Ensure that your examples are well written and could be found in real job advertisement. Write a variety of different sentences and ensure your examples are well diversified. Use a variety of styles. Write examples using both shorter and longer sentences, as well as examples using short paragraphs of a few sentences, where sometimes only one is directly relevant to the skill. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. At least two of your examples must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) check in guests : register guests | sign in guests | checking in guests | check in guest | check in guests | check-in guests ,  Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['check in guests']

# %%
text_file = "generated/gpt3_zero_shot_paper_gen_40.txt"
save_generation(text_file, res)
# Out:
# Result saved in : ./generated/gpt3_zero_shot_paper_gen.txt

# %% [markdown]
# Generation with `nExamples = 5`, so only 5 generatd sentence per set of skills but more than one skill at a time for sake of testing.

# %%
text_file = "generated/gpt3_zero_shot_paper_gen_5_multiset.txt"
save_generation(text_file, res)
# Out:
# Result saved in : ./generated/gpt3_zero_shot_paper_gen_5_multiset.txt

# %% [markdown]
# ### GEN-A1 : GPT-3, generation of longer job postings

# %%
stochastic_gen_args = {
"total_generations" : 10, # number of samples
"threshold" : 0.87, # not considering skills that are less than .8 similar
"beam_size" : 50, # considering 20 skills
"temperature_skill" : 1, # we want to see diversity in generated words
"temperature_pairing": 2, # popularity to be skewed toward popular skills
"temperature_sample_size": 0.2,
"frequency_select": True, # wether we select within the NN acording to frequency
"upper_bound_skill_matching": 5
}
generations = list(gen.stochastic_inf_iter(**stochastic_gen_args))

# %%
generations
# Out:
# [['use e-services', 'work with e-services available to citizens'],
#  ['operate tote board'],
#  ['design control systems',
#   'control systems',
#   'embedded systems',
#   'instrumentation engineering',
#   'design power electronics'],
#  ['implement data quality processes', 'data quality assessment'],
#  ['manage library users queries'],
#  ['use 3D scanners for clothing',
#   'analyse scanned data of the body',
#   'create 3D CAD footwear prototypes'],
#  ['robotic components'],
#  ['edit recorded sound', 'perform video editing'],
#  ['manage membership database', 'manage donor database'],
#  ['operate mailing information systems']]

# %%
generation_args = {
    "skill_generator": generations, # sample generator
    "specific_few_shots": False, # enable the use of specific few shots
    "model": "gpt-3.5",
    "gen_mode": "GEN-A1"
    }

res = datagen.generate_ds(**generation_args)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) use e-services : can also be referred as : use e-services | use online payment solutions | use electronic services and described as : Use public and private online services, such as e-commerce, e-governance, e-banking, e-health services..2) work with e-services available to citizens : can also be referred as : manage utilization of e-services available to clients | work with e-services available to clients | work with clients e-services | work with e-services available to client | working with e-services available to clients | oversee use of e-services available to clients | work with eservices available to clients and described as : Use, manage and work with public and private online services, such as e-commerce, e-governance, e-banking, e-health services.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['use e-services', 'work with e-services available to citizens']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) operate tote board : can also be referred as : utilize tote board | operating tote board | use tote board | operate tote boards | operate tote board and described as : Operate a tote board, either manually or using software such as Autotote.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['operate tote board']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) design control systems : can also be referred as : plan control systems | control systems design | create control systems | develop control systems | design control systems | prepare control systems | define control systems and described as : Develop devices that command and manage the behaviour of other devices and systems, using engineering and electronics principles..2) control systems : can also be referred as : industrial control systems | regulatory systems | control devices | industrial control devices | control systems | system control | control system | industrial regulatory systems and described as : Devices or a set of devices that command and manage the performance and behaviour of other equipment and systems. This includes Industrial control systems (ICS) which are used for industrial production and manufacturing..3) embedded systems : can also be referred as : embedded systems software architectures | embedded systems and described as : The computer systems and components with a specialised and autonomous function within a larger system or machine such as embedded systems software architectures, embedded peripherals, design principles and development tools..4) instrumentation engineering : can also be referred as : science of control engineering | discipline control engineering | discipline of instrumentation engineering | control engineering | science of instrumentation engineering | instrumentation engineering and described as : The science and engineering discipline that attempts to control process variables of production and manufacturing. It also focuses on the design of systems with desired behaviours. These systems use sensors to measure the output performance of the device that is being controlled..5) design power electronics : can also be referred as : design power electronics system | develop power electronics and described as : Design and develop power electronics systems, products, and components according to specifications. Select suitable ancillary devices for the intended application.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['design control systems', 'control systems', 'embedded systems', 'instrumentation engineering', 'design power electronics']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) implement data quality processes : can also be referred as : verify data | implement data quality processes and described as : Apply quality analysis, validation and verification techniques on data to check data quality integrity..2) data quality assessment : can also be referred as : data quality analysis | data quality assessment | analyse data quality and described as : The process of revealing data issues using ​quality indicators, measures and metrics in order to plan data cleansing and data enrichment strategies according to data quality criteria.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['implement data quality processes', 'data quality assessment']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) manage library users queries : can also be referred as : manage library users queries | handle library users queries | manage library user queries | managing library users queries and described as : Search library databases and standard reference materials, including online sources, to help users should they have questions.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['manage library users queries']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) use 3D scanners for clothing : can also be referred as : operate 3D body scanners for clothing | use 3D body scanners for wearing apparel | employ body scanners for clothing | use 3D body scanners for garments | use 3D scanners for clothing | utilise 3D body scanners for clothing | use 3D body scanners applied to clothing and described as : Use different 3D body scanners and softwares to capture the shape and size of the human body in order to produce 3D body model for the creation of avatars and mannequins..2) analyse scanned data of the body : can also be referred as : examine scanned body data | analyse 3D scanner body data | analyze  scanned data of the body | examine and use scanned data of the body | analyse scanned body data | analyse 3D scanner data of the body | examine scanned data of the body | use 3D scanned data for computer-aided visualisation | use 3D scanned data for computer-aided visualization | examine and use scanned body data and described as : Analyse 3D scanned data for the development of prototypes, of avatars, for the creation of size charts, the garment pattern modification, alteration and manipulation, and for testing fit..3) create 3D CAD footwear prototypes : can also be referred as : elaborate 3D CAD footwear prototypes | design 3D footwear prototypes with computer-aided designing | elaborate 3D digital footwear prototypes | design 3D digital footwear prototypes | create 3D footwear prototypes with CAD software | create 3D footwear prototypes with computer-aided design software | create 3D digital footwear prototypes | create 3D CAD footwear prototypes and described as : Be able to read and understand visual elements and technical design specifications from hand-made or computer-made sketches, pictures and drawings. Digitise or scan the lasts. Create the design upon the shape of the lasts according to dimensional requirements of the customer. Perform 3D footwear modelling by using various functionalities of the CAD software such as producing, manipulating and testing virtual images for computer aided 3D artistic and technical design of footwear. Produce alternative designs and develop virtual models and collection lines. Make presentation boards and catalogues.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['use 3D scanners for clothing', 'analyse scanned data of the body', 'create 3D CAD footwear prototypes']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) robotic components : can also be referred as : types of robotic components | electronics | controllers | robotic components | kinds of robotic components | sensors | hydraulics | circuit boards | encoders | typology of robotic components | servomotors | range of robotic components | pneumatics | microprocessors and described as : The components that can be found in robotic systems, such as microprocessors, electronics, sensors, circuit boards, encoders, servomotors, controllers, pneumatics or hydraulics.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['robotic components']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) edit recorded sound : can also be referred as : edit sound recording | edit sound footage | edit audio recordings | edit recorded sounds | edit recorded sound and described as : Edit audio footage using a variety of sofware, tools, and techniques such as crossfading, speed effects, and removing unwanted noises..2) perform video editing : can also be referred as : use video editing techniques | perform  video edit | perform video editing | perform editing of video | master video editing techniques and described as : Rearrange and edit video footage in the course of the post-production process. Edit the footage using a variety of sofware, tools, and techniques such as colour correction and effects, speed effects, and audio enhancing.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['edit recorded sound', 'perform video editing']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) manage membership database : can also be referred as : oversee association database | operate membership database | manage membership database | supervise association database | supervise membership database | oversee membership database | operate association database and described as : Add and update membership information and analyze and report on statistical membership information..2) manage donor database : can also be referred as : manage donor databases | manage donor database | handle donor database | manage database of donors | create and update donor database | create and update donor databases and described as : Create and constantly update the database containing personal details and status of donors.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['manage membership database', 'manage donor database']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) operate mailing information systems : can also be referred as : utilise mailing information systems | process and handle mail using mailing information systems | operate mailing information systems | utilise mail information systems | operate mail information systems | perform mailing information system operations | use mailing information systems | carry out operations using mailing information systems | handle and process mail using mailing information systems | use mail information systems | perform operations using mailing information systems and described as : Operate mailing information systems in order to record the processing and handling of mail. Record faults and identify packages that were not delivered. Ensure mail and small packages are traceable until they are delivered to the recipients.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['operate mailing information systems']

# %%
text_file = "generated/gpt3_zero_shot_gena1_5_multiset.txt"
save_generation(text_file, res)
# Out:
# Result saved in : ./generated/gpt3_zero_shot_gena1_5_multiset.txt

# %%
additional_info["Haskell"]
# Out:
# {'status': 'released',
#  'skillType': 'knowledge',
#  'reuseLevel': 'sector-specific',
#  'altLabels': 'Haskell',
#  'description': 'The techniques and principles of software development, such as analysis, algorithms, coding, testing and compiling of programming paradigms in Haskell.'}

# %% [markdown]
# We add the definition of the skills in the additional information

# %%
stochastic_gen_args = {
"total_generations" : 10, # number of samples
"threshold" : 0.87, # not considering skills that are less than .8 similar
"beam_size" : 50, # considering 20 skills
"temperature_skill" : 1, # we want to see diversity in generated words
"temperature_pairing": 2, # popularity to be skewed toward popular skills
"temperature_sample_size": 2,
"frequency_select": True, # wether we select within the NN acording to frequency
"upper_bound_skill_matching": 5
}
generations = list(gen.stochastic_inf_iter(**stochastic_gen_args))
generations
# Out:
# [["assess users' interaction with ICT applications",
#   'ICT system user requirements'],
#  ['use presentation software', 'provide multimedia content'],
#  ['set up automotive robot'],
#  ['SQL Server',
#   'IBM Informix',
#   'database management systems',
#   'Filemaker (database management systems)'],
#  ['microchip scanners'],
#  ['establish an ICT security prevention plan'],
#  ['collect mapping data'],
#  ['design chassis', 'create 3D CAD footwear prototypes'],
#  ['IBM InfoSphere DataStage',
#   'QlikView Expressor',
#   'Informatica PowerCenter',
#   'Pentaho Data Integration',
#   'SAP Data Services',
#   'Teradata Database'],
#  ['ICT system user requirements',
#   "assess users' interaction with ICT applications",
#   'analyse ICT system',
#   'identify ICT user needs']]

# %%
generation_args = {
    "skill_generator": generations, # sample generator
    "specific_few_shots": False, # enable the use of specific few shots
    "model": "gpt-3.5",
    "gen_mode": "GEN-A1"
    }

res = datagen.generate_ds(**generation_args)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) assess users' interaction with ICT applications : can also be referred as : assess users' interaction with ICT applications and described as : Evaluate how users interact with ICT applications in order to analyse their behaviour, draw conclusions (for instance about their motives, expectations and goals) and improve applications' functionalities..2) ICT system user requirements : can also be referred as : ICT system user requirements and described as : The process intended to match user and organisation's needs with system components and services, by taking into consideration the available technologies and the techniques required to elicit and specify requirements, interrogating users to establish symptoms of problem and analysing symptoms.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ["assess users' interaction with ICT applications", 'ICT system user requirements']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) use presentation software : can also be referred as : produce electronic presentations | use presentation program | utilise presentation software | apply presentation software | SnagIt | Kingsoft Office Presentation | use presentation software | CustomShow | VisualBee | Preseria | Adobe Ovation | Prezi | Emaze | use slide show software | Articulate Presenter | make use of presentation software | Corel Presentations | ClearSlide | Haiku Deck | Slideshark | able to use presentation software | LibreOffice Impress | SlideDog | Google Slides | using presentation software | SlideShare | Microsoft Office PowerPoint | MediaShout | Adobe Persuation | GoAnimate | KnowledgeVision | Kineticast | Slide Bureau | Evernote Presentations | Powtoon and described as : Use software tools to create digital presentations which combine various elements, such as graphs, images, text and other multimedia..2) provide multimedia content : can also be referred as : provide multimedia content and described as : Develop multimedia materials such as screen shots, graphics, slide shows, animations and videos to be used as content integrated in a broader informational context.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['use presentation software', 'provide multimedia content']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) set up automotive robot : can also be referred as : erect automotive robotic machining systems | arrange automotive robotic machining systems | create automotive robot | create automotive robotic machining systems | assemble automotive robotic machining systems | set up automotive robot | erect automotive robot | arrange automotive robot | assemble automotive robot and described as : Set up and programme an automotive robot working on machine processes and substituting or collaboratively supporting human labour, such as the six-axis automotive robot.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['set up automotive robot']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) SQL Server : can also be referred as : SQL Server 2012 | SQL Server Standard Edition | SQL Server | Azure SQL Database | SQL Server 2008 | Microsoft SQL Server Compact | SQL Server Express Edition | SQL Server Developer Edition | MS SQL Server | SQL Server Workgroup Edition | SQL Server 2005 | SQL Server 2014 | SQL Server Web Edition | Microsoft SQL Server | SQL Server Enterprise Edition and described as : The computer program SQL Server is a tool for creating, updating and managing databases, developed by the software company Microsoft..2) IBM Informix : can also be referred as : Informix Advanced Workgroup Edition | Informix Workgroup Edition | Informix Dynamic Server | IBM Informix | Informix Express Edition | Informix Enterprise Edition | Informix Extended Parallel Server | Informix Advanced Enterprise Edition and described as : The computer program IBM Informix is a tool for creating, updating and managing databases, developed by the software company IBM..3) database management systems : can also be referred as : Jasmine ii | Db.star | Adaptive Server Enterprise | Model 204 | Informix Extended Parallel Server | UniSQL | Db.linux | Pervasive.SQL 2000 | DBMS | Oracle Lite | Objectivity DB | Interbase | PointBase Network Server | Quadbase SQL Server | YARD-SQL | POET Object Server Suite | Versant | NonStop SQL | Oracle 8I | Adabas D | Adabas | IMS DB | UniData | PointBase Mobile | DB engines | Informix Dynamic Server 2000 | TimesTen | Datacom | SUPRA | Rdb | IDMS | Cloudscape | Velocis | Pervasive.SQL Workgroup | Adaptive Server Anywhere | SQLBase | Raima Database Manager | DB2 Everyplace | Advantage Database Server | database management systems | PointBase Embedded | SQL | Ingres ii | database systems | R:Base and described as : The tools for creating, updating and managing databases, such as Oracle, MySQL and Microsoft SQL Server..4) Filemaker (database management systems) : can also be referred as : FileMaker Pro | FileMaker Go | FileMaker and described as : The computer program FileMaker is a tool for creating, updating and managing databases, developed by the software company FileMaker Inc.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['SQL Server', 'IBM Informix', 'database management systems', 'Filemaker (database management systems)']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) microchip scanners : can also be referred as : micro-chip scanner | micro-chip scanners | types of microchip scanners | microchip scanner | differences between microchip scanners | microchip scanners | knowledge of microchip scanners | limitations of microchip scanners and described as : The different types of scanners available, their limitations, and how to prepare, use and maintain them; the environmental constraints of using a scanner, including what external factors can affect the reading of a microchip, e.g. metal collars, proximity to computer screens etc.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['microchip scanners']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) establish an ICT security prevention plan : can also be referred as : establish an ICT security prevention plan and described as : Define a set of measures and responsibilities to ensure the confidentiality, integrity and availability of information. Implement policies to prevent data breaches, detect and respond to unathorised access to systems and resources, including up-to-date security applications and employee education.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['establish an ICT security prevention plan']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) collect mapping data : can also be referred as : conservation of mapping data | collect mapping data | preserving mapping data | conserve mapping data | collection of mapping data | preservation of mapping data | mapping data preservation | collecting mapping data | collecting of  mapping data | mapping data collection | preserve mapping data and described as : Collect and conserve mapping resources and mapping data.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['collect mapping data']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) design chassis : can also be referred as : design a chassis | chassis design | model chassis | produce chassis | arrange chassis | develop chassis | design chassis | designing a chassis and described as : Devise and manufacture a series of custom chassis using design software. Apply compliance with own plans, creations and blueprints..2) create 3D CAD footwear prototypes : can also be referred as : elaborate 3D CAD footwear prototypes | design 3D footwear prototypes with computer-aided designing | elaborate 3D digital footwear prototypes | design 3D digital footwear prototypes | create 3D footwear prototypes with CAD software | create 3D footwear prototypes with computer-aided design software | create 3D digital footwear prototypes | create 3D CAD footwear prototypes and described as : Be able to read and understand visual elements and technical design specifications from hand-made or computer-made sketches, pictures and drawings. Digitise or scan the lasts. Create the design upon the shape of the lasts according to dimensional requirements of the customer. Perform 3D footwear modelling by using various functionalities of the CAD software such as producing, manipulating and testing virtual images for computer aided 3D artistic and technical design of footwear. Produce alternative designs and develop virtual models and collection lines. Make presentation boards and catalogues.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['design chassis', 'create 3D CAD footwear prototypes']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) IBM InfoSphere DataStage : can also be referred as : Cognos Data Manager | IBM InfoSphere DataStage Workgroup Edition | InfoSphere DataStage MVS Edition | IBM InfoSphere DataStage and described as : The computer program IBM InfoSphere DataStage is a tool for integration of information from multiple applications, created and maintained by organisations, into one consistent and transparent data structure, developed by the software company IBM..2) QlikView Expressor : can also be referred as : QV Expressor | QVE | QlikView Expressor and described as : The computer program QlikView Expressor is a tool for integration of information from multiple applications, created and maintained by organisations, into one consistent and transparent data structure, developed by the software company Qlik..3) Informatica PowerCenter : can also be referred as : Informatica PowerCenter | Informatica Power Center | PowerCenter Informatica and described as : The computer program Informatica PowerCenter is a tool for integration of information from multiple applications, created and maintained by organisations, into one consistent and transparent data structure, developed by the software company Informatica..4) Pentaho Data Integration : can also be referred as : Pentaho Data Integration | Pentaho Kettle | PDI and described as : The computer program Pentaho Data Integration is a tool for integration of information from multiple applications, created and maintained by organisations, into one consistent and transparent data structure, developed by the software company Pentaho..5) SAP Data Services : can also be referred as : SAP Data Services and described as : The computer program SAP Data Services is a tool for integration of information from multiple applications, created and maintained by organisations, into one consistent and transparent data structure, developed by the software company SAP..6) Teradata Database : can also be referred as : Teradata Integrated Data Warehouse | Teradata | Teradata Database and described as : The computer program Teradata Database is a tool for creating, updating and managing databases, developed by the software company Teradata Corporation.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['IBM InfoSphere DataStage', 'QlikView Expressor', 'Informatica PowerCenter', 'Pentaho Data Integration', 'SAP Data Services', 'Teradata Database']
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five paragraphs of a few lines that could be found in a job ad and refer to all skill or knowledge component. You may be given a skill family to help you disambiguate if the skills names could refer to multiple things. Ensure that your paragraphs are well written and could be found in real job advertisement. Write a variety of different paragprahs and ensure your examples are well diversified. Use a variety of styles. Write paragraphs of a few sentences. You're trying to provide a representative sample of the many, many ways real job postings would evoke a skill. All the skills must be integrated into each paragraph. You must not integrate any skill not given in input to the paragraph. No  At least two of your paragraphs must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) ICT system user requirements : can also be referred as : ICT system user requirements and described as : The process intended to match user and organisation's needs with system components and services, by taking into consideration the available technologies and the techniques required to elicit and specify requirements, interrogating users to establish symptoms of problem and analysing symptoms..2) assess users' interaction with ICT applications : can also be referred as : assess users' interaction with ICT applications and described as : Evaluate how users interact with ICT applications in order to analyse their behaviour, draw conclusions (for instance about their motives, expectations and goals) and improve applications' functionalities..3) analyse ICT system : can also be referred as : analyze  ICT system and described as : Analyse the functioning and performance of information systems in order to define their goals, architecture and services and set procedures and operations to meet end users requirements..4) identify ICT user needs : can also be referred as : identify ICT user needs | ICT user needs identification techniques and described as : Determine the needs and requirements of ICT users of a specific system by applying analytical methods, such as target group analysis.. Avoid explicitly using the wording of this extra information in your examples.
#
# skills: ['ICT system user requirements', "assess users' interaction with ICT applications", 'analyse ICT system', 'identify ICT user needs']

# %%
text_file = "generated/gpt3_zero_shot_gena1_5_bigset.txt"
save_generation(text_file, res)
# Out:
# Result saved in : ./generated/gpt3_zero_shot_gena1_5_bigset.txt

# %% [markdown]
# ### GEN-A2 : GPT-3, full job postings
#
#
# You can see here that we loosen the similarity restriction on the associated skills and set a slightly higher temperature.

# %%
stochastic_gen_args = {
"total_generations" : 1, # number of samples
"threshold" : 0.7, # not considering skills that are less than .8 similar
"beam_size" : 20, # considering 20 skills
"temperature_skill" : 1, # we want to see diversity in generated words
"temperature_pairing": 2, # popularity to be skewed toward popular skills
"temperature_sample_size": 0.5,
"frequency_select": True, # wether we select within the NN acording to frequency
"upper_bound_skill_matching": 10
}
generations = list(gen.stochastic_inf_iter(**stochastic_gen_args))
generations
# Out:
# [['Microsoft Access',
#   'MySQL',
#   'Oracle Data Integrator',
#   'Sakai',
#   'Filemaker (database management systems)',
#   'SQL Server',
#   'Informatica PowerCenter',
#   'DB2',
#   'Oracle Relational Database',
#   'Pentaho Data Integration']]

# %%
generation_args = {
    "skill_generator": generations, # sample generator
    "specific_few_shots": False, # enable the use of specific few shots
    "model": "gpt-3.5",
    "gen_mode": "GEN-A2"
    }

res = datagen.generate_ds(**generation_args)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# prompts arguments >  []
# prompts arguments >  ['nExamples', 'implicitCount', 'typeOfAdditionalInfo', 'additionalInfo']
# ----------------------------------------------------------------------------------------------------
# You are the leading AI Writer at a large, multinational HR agency. You are considered as the world's best expert at expressing required skills and knowledge in a variety of clear ways. You are particularly proficient with the ESCO Occupation and Skills framework. As you are widely lauded for your job posting writing ability, you will assist the user in all job-posting, job requirements and occupational skills related tasks.
#
# You work in collaboration with ESCO to gather rigid standards for job postings. Given a list of ESCO skills and knowledges, you're asked to provide five complete job ads and refer to all skills or knowledge components. You may be given additional skill information such as alternative names and descriptions to help you disambiguate if the skills names could refer to multiple things. Ensure that your job postings are well written and could be a real job advertisement. Write a variety of different job advertisment and ensure your examples are well diversified. Use a variety of styles. Write job openings of a few paragraphs. You're trying to provide a representative sample of the many, many ways real job postings would evoke skills. All the skills must be integrated into all the job openings. A candidate should have different degrees of expertise in all the given skills. This degree should be specified. You must not integrate any skill not given in input to the paragraph. At least two of your job postings must not contain an explicit reference to the skill and must thus not contain the given skill string. Alternative names (you may discard this information if irrelevant): 1) Microsoft Access : can also be referred as : Access | Microsoft Access | MS Access | Microsoft Office Access and described as : The computer program Access is a tool for creating, updating and managing databases, developed by the software company Microsoft..2) MySQL : can also be referred as : MySQL Enterprise Edition | MySQL Embedded (OEM/ISV) | MySQL Classic Edition | MySQL Standard Edition | MySQL | MySQL Cluster CGE and described as : The computer program MySQL is a tool for creating, updating and managing databases, currently developed by the software company Oracle..3) Oracle Data Integrator : can also be referred as : Oracle Data Integrator | ODI and described as : The computer program Oracle Data Integrator is a tool for integration of information from multiple applications, created and maintained by organisations, into one consistent and transparent data structure, developed by the software company Oracle..4) Sakai : can also be referred as : Sakai | Sakai Project and described as : The computer program Sakai is a e-learning platform for creating, administrating, arranging, reporting and delivering e-learning education courses or training programs. It is developed by the software company Apereo..5) Filemaker (database management systems) : can also be referred as : FileMaker Pro | FileMaker Go | FileMaker and described as : The computer program FileMaker is a tool for creating, updating and managing databases, developed by the software company FileMaker Inc..6) SQL Server : can also be referred as : SQL Server 2012 | SQL Server Standard Edition | SQL Server | Azure SQL Database | SQL Server 2008 | Microsoft SQL Server Compact | SQL Server Express Edition | SQL Server Developer Edition | MS SQL Server | SQL Server Workgroup Edition | SQL Server 2005 | SQL Server 2014 | SQL Server Web Edition | Microsoft SQL Server | SQL Server Enterprise Edition and described as : The computer program SQL Server is a tool for creating, updating and managing databases, developed by the software company Microsoft..7) Informatica PowerCenter : can also be referred as : Informatica PowerCenter | Informatica Power Center | PowerCenter Informatica and described as : The computer program Informatica PowerCenter is a tool for integration of information from multiple applications, created and maintained by organisations, into one consistent and transparent data structure, developed by the software company Informatica..8) DB2 : can also be referred as : DB2 | DB2 database software | DB2 Connect | DB2 on Cloud | IBM DB2 database software | IBM DB2 | DB2 for Linux, UNIX and Windows | DB2 for z/OS | DB2 for i and described as : The computer program IBM DB2 is a tool for creating, updating and managing databases, developed by the software company IBM..9) Oracle Relational Database : ...
#
# skills: ['Microsoft Access', 'MySQL', 'Oracle Data Integrator', 'Sakai', 'Filemaker (database management systems)', 'SQL Server', 'Informatica PowerCenter', 'DB2', 'Oracle Relational Database', 'Pentaho Data Integration']

# %%
text_file = "generated/gpt3_zero_shot_gena2_1_superset.txt"
save_generation(text_file, res)
# Out:
# Result saved in : ./generated/gpt3_zero_shot_gena2_1_superset.txt

# %% [markdown]
# ### GEN-A3 : A2 but avoid writing down lists

# %%
## taking the same skills as the above example :
generations = [['Microsoft Access',
  'MySQL',
  'Oracle Data Integrator',
  'Sakai',
  'Filemaker (database management systems)',
  'SQL Server',
  'Informatica PowerCenter',
  'DB2',
  'Oracle Relational Database',
  'Pentaho Data Integration']]

# %%
generation_args = {
    "generations": generations, # sample generator
    "specific_gew_shots": True, # enable the use of specific few shots
    "nb_few_shots": 3, # number of few shots to use
    "shot_sim_treshold": 0.75,
    "model": "gpt-3.5",
    "gen_mode": "GEN-A3"
    }


res = datagen.generate_ds(**generation_args)
