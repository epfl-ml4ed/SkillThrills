# %%
generated_records = [{
        'skills': ['SQL', 'Hadoop', 'machine learning'],
        'sentence': 'We are currently seeking a skilled and dynamic Data Engineer to join our team. As a Data Engineer, you will be responsible for designing and optimizing our data infrastructure, utilizing your expertise in SQL, Hadoop, and machine learning. Your in-depth knowledge of SQL will enable you to design efficient and scalable database structures, while your experience with Hadoop will allow you to process and analyze large volumes of data. Additionally, your proficiency in machine learning will enable you to develop and implement advanced data models, helping us extract valuable insights from our vast datasets. The ideal candidate will possess a strong understanding of these technologies and a proven track record of successfully implementing data-driven solutions. Join us and contribute to our mission of leveraging data to drive business growth and innovation.'
    },
    {
        'skills': ['SQL', 'Hadoop', 'machine learning'],
        'sentence': 'We are seeking a highly skilled candidate with expertise in data manipulation using query languages, proficiency in big data processing frameworks, and a strong knowledge of advanced data analysis techniques.'
    }
]

# %%
import pickle
from api_key import API_KEY
import pandas as pd
from tqdm.notebook import tqdm
import sys
sys.path.append("../../skillExtract/")
from utils import (OPENAI,
                   Splitter,
                   select_candidates_from_taxonomy)
from api_key import API_KEY
from transformers import AutoModel, AutoTokenizer
import os
import torch
import torch.nn.functional as F

# %load_ext autoreload
# %autoreload 2

tqdm.pandas()

ESCO_DIR = "../../../esco/"

class Args():
    def __init__(self):
        self.taxonomy = ESCO_DIR + "tech_managment_taxonomy.csv" 

        ## RELATED TO PROMPT CREATION
        self.datapath = "remote-annotated-en"
        # self.candidates_method = "embeddings"  ## putting "rules" doesn't give the embeddings
        self.candidates_method = "mixed"
        self.shots = 6
        self.prompt_type = "skills"
        self.data_type = "en_job"
        
        ## RELATED TO CHAT GPT GENERATION
        self.max_tokens = 200      ## ?? default value but JobBERT suposedly takes 512
        self.api_key = API_KEY
        self.model = "gpt-3.5-turbo"
        self.temperature = 0       ## default val
        self.top_p = 1             ## default val
        self.frequency_penalty = 0 ## default val
        self.presence_penalty = 0  ## default val

args = Args()

## Loading the embedded taxonomy
word_emb = "jjzha/jobbert-base-cased"
word_emb_model = AutoModel.from_pretrained(word_emb)
word_emb_tokenizer = AutoTokenizer.from_pretrained(word_emb)

## ESCO technical skills
ESCO_DIR = "../../../../esco/"
tech_skills = pd.read_csv(ESCO_DIR + "tech_managment_taxonomy_narrow.csv")
tech_skills["name+definition"] = tech_skills["name+defintion"]
tech_skills["Example"] = tech_skills["altLabels"]


if(not os.path.exists(ESCO_DIR + "embedded_tech_management_tax.pkl")):
    tech_emb_tax = tech_skills[["name+definition", "name", "unique_id"]].copy()
    tech_emb_tax["embeddings"] = tech_emb_tax["name+definition"]\
                        .progress_apply(lambda st : \
                        word_emb_model(**word_emb_tokenizer(st, return_tensors="pt", max_length=768, padding=True, truncation=True))\
                        .last_hidden_state[:, 0, :]\
                        )
else:
    with open(ESCO_DIR + "embedded_tech_management_tax.pkl", "rb") as emb:
        tech_emb_tax =  pickle.load(emb)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at jjzha/jobbert-base-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
with open(ESCO_DIR + "embedded_tech_management_tax.pkl", "wb") as emb:
    pickle.dump(tech_emb_tax, emb)

# %%
def compute_prediction(generated_records):
    extraction_cost = 0
    matching_cost = 0
    ress = []
    for i, annotated_record in tqdm(enumerate(generated_records)):
        if(i>20):
            break
        print(annotated_record)

        ## EXTRACTION
        api = OPENAI(args, [annotated_record])
        sentences_res_list, cost = api.do_prediction("extraction")
        extraction_cost += cost
        

        ## CANDIDATE SELECTION
        if "extracted_skills" in sentences_res_list[0]:
            splitter = Splitter()
            max_candidates = 10
            for idxx, sample in enumerate(sentences_res_list):
                sample = select_candidates_from_taxonomy(
                    sample,
                    tech_skills,
                    splitter,
                    word_emb_model,
                    word_emb_tokenizer,
                    max_candidates,
                    method=args.candidates_method,
                    emb_tax=None if args.candidates_method == "rules" else tech_emb_tax
                )
                sentences_res_list[idxx] = sample


        if("skill_candidates" in sentences_res_list[0]):
            api = OPENAI(args, sentences_res_list)
            sentences_res_list, cost = api.do_prediction("matching")
            matching_cost += cost



        ress.append(sentences_res_list)
    return ress

# %%
compute_prediction([{
    "sentence": "We want someone who can use IBM Informix.",
    "skill": ["IBM Informix"]
}])

# %%
compute_prediction([{
    "sentence": "We want someone proficient with Hadoop and HDFS.",
    "skill": ["SQL"]
}])

# %%
ress = compute_prediction(generated_records)

# %%
for res in ress:
    print("-"*100)
    print("labels : ", res[0]["skills"])
    for sk in res[0]["matched_skills"]:
        print("span : ", sk)
        print("\t - ", res[0]["matched_skills"][sk]["name+definition"])
# Out:
# ----------------------------------------------------------------------------------------------------
# labels :  ['SQL', 'Hadoop', 'machine learning']
# span :  data engineer
# 	 -  use data processing techniques : gather, process and analyse relevant data and information, properly store and update data and represent figures and data using charts and statistical diagrams.
# span :  designing and optimizing our data infrastructure
# 	 -  database development tools : the methodologies and tools used for creating logical and physical structure of databases, such as logical data structures, diagrams, modelling methodologies and entity-relationships.
# span :  sql, hadoop, and machine learning
# 	 -  apply statistical analysis techniques : use models (descriptive or inferential statistics) and techniques (data mining or machine learning) for statistical analysis and ict tools to analyse data, uncover correlations and forecast trends.
# span :  sql
# 	 -  SQL : the computer language sql is a query language for retrieval of information from a database and of documents containing the needed information. it is developed by the american national standards institute and the international organization for standardization.
# span :  design efficient and scalable database structures
# 	 -  use databases : use software tools for managing and organising data in a structured environment which consists of attributes, tables and relationships in order to query and modify the stored data.
# span :  hadoop
# 	 -  Hadoop : the open-source data storing, analysis and processing framework which consists mainly in the mapreduce and hadoop distributed file system (hdfs) components and it is used to provide support for managing and analysing large datasets.
# span :  process and analyze large volumes of data
# 	 -  use data processing techniques : gather, process and analyse relevant data and information, properly store and update data and represent figures and data using charts and statistical diagrams.
# span :  machine learning
# 	 -  machine learning : the principles, methods and algorithms of machine learning, a subfield of artificial intelligence. common machine learning models such as supervised or unsupervised models, semi- supervised models and reinforcement learning models.
# span :  develop and implement advanced data models
# 	 -  apply statistical analysis techniques : use models (descriptive or inferential statistics) and techniques (data mining or machine learning) for statistical analysis and ict tools to analyse data, uncover correlations and forecast trends.
# span :  data-driven solutions
# 	 -  data analytics : the science of analysing and making decisions based on raw data collected from various sources. includes knowledge of techniques using algorithms that derive insights or trends from that data to support decision-making processes.
# ----------------------------------------------------------------------------------------------------
# labels :  ['SQL', 'Hadoop', 'machine learning']
# span :  data manipulation using query languages
# 	 -  use data processing techniques : gather, process and analyse relevant data and information, properly store and update data and represent figures and data using charts and statistical diagrams.
# span :  big data processing frameworks
# 	 -  use databases : use software tools for managing and organising data in a structured environment which consists of attributes, tables and relationships in order to query and modify the stored data.
# span :  advanced data analysis techniques
# 	 -  apply statistical analysis techniques : use models (descriptive or inferential statistics) and techniques (data mining or machine learning) for statistical analysis and ict tools to analyse data, uncover correlations and forecast trends.

# %% [markdown]
# ### Few specific embeddings
#
#
# The whole matching part consists of comparing the span and the skills but does it work ?

# %%
vec = word_emb_model(**word_emb_tokenizer("SQL", return_tensors="pt", max_length=768, padding=True, truncation=True)).last_hidden_state[:, 0, :]
tech_emb_tax["similarity"] = tech_emb_tax["embeddings"].apply(lambda x : F.cosine_similarity(vec, x).item())

quest = tech_emb_tax.sort_values("similarity", ascending=False).reset_index()
quest
# Out:
#       index                                    name+definition  \
# 0      1184  database management systems : the tools for cr...
# 1       783  operate relational database management system ...
# 2      1230  Jboss : the open-source application server jbo...
# 3      1548  Oracle Relational Database : the computer prog...
# 4       327  Octopus Deploy : the tool octopus deploy is a ...
# ...     ...                                                ...
# 1789   1282  engage in debates : construct and present argu...
# 1790    181  stimulate performers' imagination : use inspir...
# 1791   1452  develop cultural policies : develop programmes...
# 1792    462  conduct research on climate processes : conduc...
# 1793    285  motivate supporters : engage people to take ac...
#
#                                                name  unique_id  \
# 0                       database management systems       2184
# 1     operate relational database management system       1783
# 2                                             Jboss       2230
# 3                        Oracle Relational Database       2548
# 4                                    Octopus Deploy       1327
# ...                                             ...        ...
# 1789                              engage in debates       2282
# 1790              stimulate performers' imagination       1181
# 1791                      develop cultural policies       2452
# 1792          conduct research on climate processes       1462
# 1793                            motivate supporters       1285
#
#                                              embeddings  similarity  results
# 0     [[tensor(0.3259, grad_fn=<UnbindBackward0>), t...    0.638282    False
# 1     [[tensor(0.4806, grad_fn=<UnbindBackward0>), t...    0.627278    False
# 2     [[tensor(0.8781, grad_fn=<UnbindBackward0>), t...    0.623659    False
# 3     [[tensor(0.5813, grad_fn=<UnbindBackward0>), t...    0.618193    False
# 4     [[tensor(0.6682, grad_fn=<UnbindBackward0>), t...    0.617577    False
# ...                                                 ...         ...      ...
# 1789  [[tensor(0.7155, grad_fn=<UnbindBackward0>), t...    0.295587    False
# 1790  [[tensor(-0.3790, grad_fn=<UnbindBackward0>), ...    0.292352    False
# 1791  [[tensor(0.8760, grad_fn=<UnbindBackward0>), t...    0.290595    False
# 1792  [[tensor(0.1406, grad_fn=<UnbindBackward0>), t...    0.270809    False
# 1793  [[tensor(0.3384, grad_fn=<UnbindBackward0>), t...    0.257306    False
#
# [1794 rows x 7 columns]

# %%
display(quest[quest.name == "SQL"])
display(quest[quest.name == "NoSQL"])
# Out:
#      index                                    name+definition name  unique_id  \
# 170    615  SQL : the computer language sql is a query lan...  SQL       1615
#
#                                             embeddings  similarity
# 170  [[tensor(0.3752, grad_fn=<UnbindBackward0>), t...    0.529819
#     index                                    name+definition   name  \
# 24    814  NoSQL : the not only sql non-relational databa...  NoSQL
#
#     unique_id                                         embeddings  similarity
# 24       1814  [[tensor(0.2357, grad_fn=<UnbindBackward0>), t...     0.59077

# %%
vec = word_emb_model(**word_emb_tokenizer("sql", return_tensors="pt", max_length=768, padding=True, truncation=True)).last_hidden_state[:, 0, :]
tech_emb_tax["similarity"] = tech_emb_tax["embeddings"].apply(lambda x : F.cosine_similarity(vec, x).item())

quest = tech_emb_tax.sort_values("similarity", ascending=False).reset_index()
quest
# Out:
#       index                                    name+definition  \
# 0      1051             operate GPS systems : use gps systems.
# 1       587  Aircrack (penetration testing tool) : the comp...
# 2       291  strive for company growth : develop strategies...
# 3       718  STAF : the tool staf is a software program to ...
# 4       612  APL : the techniques and principles of softwar...
# ...     ...                                                ...
# 1789    523  increase the impact of science on policy and s...
# 1790     68  implement route planning in smart mobility ser...
# 1791   1282  engage in debates : construct and present argu...
# 1792    169  prevent fraudulent activities : identify and p...
# 1793    997  human-computer interaction : the study of the ...
#
#                                                    name  unique_id  \
# 0                                   operate GPS systems       2051
# 1                   Aircrack (penetration testing tool)       1587
# 2                             strive for company growth       1291
# 3                                                  STAF       1718
# 4                                                   APL       1612
# ...                                                 ...        ...
# 1789  increase the impact of science on policy and s...       1523
# 1790  implement route planning in smart mobility ser...       1068
# 1791                                  engage in debates       2282
# 1792                      prevent fraudulent activities       1169
# 1793                         human-computer interaction       1997
#
#                                              embeddings  similarity  results
# 0     [[tensor(1.0385, grad_fn=<UnbindBackward0>), t...    0.618310    False
# 1     [[tensor(1.2083, grad_fn=<UnbindBackward0>), t...    0.598707    False
# 2     [[tensor(0.6989, grad_fn=<UnbindBackward0>), t...    0.598563    False
# 3     [[tensor(0.6350, grad_fn=<UnbindBackward0>), t...    0.593602    False
# 4     [[tensor(0.8778, grad_fn=<UnbindBackward0>), t...    0.579703    False
# ...                                                 ...         ...      ...
# 1789  [[tensor(1.0667, grad_fn=<UnbindBackward0>), t...    0.329562    False
# 1790  [[tensor(0.6432, grad_fn=<UnbindBackward0>), t...    0.329421    False
# 1791  [[tensor(0.7155, grad_fn=<UnbindBackward0>), t...    0.321549    False
# 1792  [[tensor(0.5965, grad_fn=<UnbindBackward0>), t...    0.297933    False
# 1793  [[tensor(0.2708, grad_fn=<UnbindBackward0>), t...    0.277204    False
#
# [1794 rows x 7 columns]

# %%
vec = word_emb_model(**word_emb_tokenizer("NoSQL", return_tensors="pt", max_length=768, padding=True, truncation=True)).last_hidden_state[:, 0, :]
tech_emb_tax["similarity"] = tech_emb_tax["embeddings"].apply(lambda x : F.cosine_similarity(vec, x).item())

quest = tech_emb_tax.sort_values("similarity", ascending=False).reset_index()
quest
# Out:
#       index                                    name+definition  \
# 0       814  NoSQL : the not only sql non-relational databa...
# 1      1184  database management systems : the tools for cr...
# 2      1604  MarkLogic : the nosql enterprise non-relationa...
# 3      1116  search databases : search for information or p...
# 4      1230  Jboss : the open-source application server jbo...
# ...     ...                                                ...
# 1789    119  develop agricultural policies : develop progra...
# 1790    964  create an airport master plan : compose a mast...
# 1791    286  prepare exhibition marketing plan : develop ma...
# 1792     15  provide context to news stories : provide subs...
# 1793   1772  conduct public presentations : speak in public...
#
#                                    name  unique_id  \
# 0                                 NoSQL       1814
# 1           database management systems       2184
# 2                             MarkLogic       2604
# 3                      search databases       2116
# 4                                 Jboss       2230
# ...                                 ...        ...
# 1789      develop agricultural policies       1119
# 1790      create an airport master plan       1964
# 1791  prepare exhibition marketing plan       1286
# 1792    provide context to news stories       1015
# 1793       conduct public presentations       2772
#
#                                              embeddings  similarity  results
# 0     [[tensor(0.2357, grad_fn=<UnbindBackward0>), t...    0.640971    False
# 1     [[tensor(0.3259, grad_fn=<UnbindBackward0>), t...    0.613612    False
# 2     [[tensor(0.4266, grad_fn=<UnbindBackward0>), t...    0.603742    False
# 3     [[tensor(0.5731, grad_fn=<UnbindBackward0>), t...    0.599333    False
# 4     [[tensor(0.8781, grad_fn=<UnbindBackward0>), t...    0.593972    False
# ...                                                 ...         ...      ...
# 1789  [[tensor(0.8436, grad_fn=<UnbindBackward0>), t...    0.237274    False
# 1790  [[tensor(0.2353, grad_fn=<UnbindBackward0>), t...    0.236642    False
# 1791  [[tensor(1.1266, grad_fn=<UnbindBackward0>), t...    0.236013    False
# 1792  [[tensor(0.6254, grad_fn=<UnbindBackward0>), t...    0.229355    False
# 1793  [[tensor(0.5862, grad_fn=<UnbindBackward0>), t...    0.223491    False
#
# [1794 rows x 7 columns]

# %%
vec = word_emb_model(**word_emb_tokenizer("big data processing frameworks", return_tensors="pt", max_length=768, padding=True, truncation=True)).last_hidden_state[:, 0, :]
tech_emb_tax["similarity"] = tech_emb_tax["embeddings"].apply(lambda x : F.cosine_similarity(vec, x).item())

quest = tech_emb_tax.sort_values("similarity", ascending=False).reset_index()
quest
# Out:
#       index                                    name+definition  \
# 0      1580  Hadoop : the open-source data storing, analysi...
# 1       265  data mining : the methods of artificial intell...
# 2      1059  resource description framework query language ...
# 3       290  manage database : apply database design scheme...
# 4       902  utilise machine learning : use techniques and ...
# ...     ...                                                ...
# 1789   1178  participate in rabbinical court proceedings : ...
# 1790    688  develop outreach training plans : develop trai...
# 1791    485  provide testimony in court hearings : provide ...
# 1792   1268  provide animal related information for legal p...
# 1793   1282  engage in debates : construct and present argu...
#
#                                                    name  unique_id  \
# 0                                                Hadoop       2580
# 1                                           data mining       1265
# 2         resource description framework query language       2059
# 3                                       manage database       1290
# 4                              utilise machine learning       1902
# ...                                                 ...        ...
# 1789        participate in rabbinical court proceedings       2178
# 1790                    develop outreach training plans       1688
# 1791                provide testimony in court hearings       1485
# 1792  provide animal related information for legal p...       2268
# 1793                                  engage in debates       2282
#
#                                              embeddings  similarity  results
# 0     [[tensor(0.5392, grad_fn=<UnbindBackward0>), t...    0.822168    False
# 1     [[tensor(0.8332, grad_fn=<UnbindBackward0>), t...    0.802054    False
# 2     [[tensor(0.5560, grad_fn=<UnbindBackward0>), t...    0.787018    False
# 3     [[tensor(0.6113, grad_fn=<UnbindBackward0>), t...    0.786879    False
# 4     [[tensor(0.9736, grad_fn=<UnbindBackward0>), t...    0.780613    False
# ...                                                 ...         ...      ...
# 1789  [[tensor(0.3299, grad_fn=<UnbindBackward0>), t...    0.326043    False
# 1790  [[tensor(0.3241, grad_fn=<UnbindBackward0>), t...    0.324389    False
# 1791  [[tensor(0.6440, grad_fn=<UnbindBackward0>), t...    0.307927    False
# 1792  [[tensor(0.5757, grad_fn=<UnbindBackward0>), t...    0.305936    False
# 1793  [[tensor(0.7155, grad_fn=<UnbindBackward0>), t...    0.299197    False
#
# [1794 rows x 7 columns]

# %%
vec = word_emb_model(**word_emb_tokenizer("machine learning", return_tensors="pt", max_length=768, padding=True, truncation=True)).last_hidden_state[:, 0, :]
tech_emb_tax["similarity"] = tech_emb_tax["embeddings"].apply(lambda x : F.cosine_similarity(vec, x).item())

quest = tech_emb_tax.sort_values("similarity", ascending=False).reset_index()
quest
# Out:
#       index                                    name+definition  \
# 0       265  data mining : the methods of artificial intell...
# 1       902  utilise machine learning : use techniques and ...
# 2       388  machine learning : the principles, methods and...
# 3       290  manage database : apply database design scheme...
# 4      1059  resource description framework query language ...
# ...     ...                                                ...
# 1789   1268  provide animal related information for legal p...
# 1790    819  represent clients in courts : assume the posit...
# 1791   1178  participate in rabbinical court proceedings : ...
# 1792    485  provide testimony in court hearings : provide ...
# 1793   1282  engage in debates : construct and present argu...
#
#                                                    name  unique_id  \
# 0                                           data mining       1265
# 1                              utilise machine learning       1902
# 2                                      machine learning       1388
# 3                                       manage database       1290
# 4         resource description framework query language       2059
# ...                                                 ...        ...
# 1789  provide animal related information for legal p...       2268
# 1790                        represent clients in courts       1819
# 1791        participate in rabbinical court proceedings       2178
# 1792                provide testimony in court hearings       1485
# 1793                                  engage in debates       2282
#
#                                              embeddings  similarity  results
# 0     [[tensor(0.8332, grad_fn=<UnbindBackward0>), t...    0.744104    False
# 1     [[tensor(0.9736, grad_fn=<UnbindBackward0>), t...    0.692355    False
# 2     [[tensor(1.0222, grad_fn=<UnbindBackward0>), t...    0.688033    False
# 3     [[tensor(0.6113, grad_fn=<UnbindBackward0>), t...    0.656007    False
# 4     [[tensor(0.5560, grad_fn=<UnbindBackward0>), t...    0.652568    False
# ...                                                 ...         ...      ...
# 1789  [[tensor(0.5757, grad_fn=<UnbindBackward0>), t...    0.252162    False
# 1790  [[tensor(0.6174, grad_fn=<UnbindBackward0>), t...    0.250387    False
# 1791  [[tensor(0.3299, grad_fn=<UnbindBackward0>), t...    0.244656    False
# 1792  [[tensor(0.6440, grad_fn=<UnbindBackward0>), t...    0.240261    False
# 1793  [[tensor(0.7155, grad_fn=<UnbindBackward0>), t...    0.216897    False
#
# [1794 rows x 7 columns]

# %%
skills = tech_skills.name.values
self_reflection = []
for skill in tqdm(skills):
    vec = word_emb_model(**word_emb_tokenizer(skill, return_tensors="pt", max_length=768, padding=True, truncation=True)).last_hidden_state[:, 0, :]
    tech_emb_tax["similarity"] = tech_emb_tax["embeddings"].apply(lambda x : F.cosine_similarity(vec, x).item())

    quest = tech_emb_tax.sort_values("similarity", ascending=False).reset_index()
    self_reflection.append(quest[quest.name == skill].index[0])
# Out:
#   0%|          | 0/1794 [00:00<?, ?it/s]

# %%
self_reflection = pd.DataFrame({
    'skills': skills,
    "self_reflection": self_reflection
})

# %%
self_reflection.sort_values("self_reflection").describe()
# Out:
#        self_reflection
# count      1794.000000
# mean         18.784281
# std          89.751735
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           4.000000
# max        1463.000000

# %%
self_reflection[self_reflection.skills == "MySQL"]
# Out:
#     skills  self_reflection
# 526  MySQL                1

# %%
self_reflection[self_reflection.self_reflection >= 10].sample(50)
# Out:
#                                               skills  self_reflection
# 1003     integrated development environment software               46
# 1587                             SAS Data Management               12
# 1530                              study a collection               20
# 34                      perform online data analysis               46
# 419                     assemble hardware components               13
# 1410                            scientific modelling              215
# 541                      perform scientific research               14
# 642                           analyse business plans               70
# 20                                            Erlang               16
# 1063                         perform PESTEL analysis              160
# 555                                                R              337
# 1192                                identify fossils              588
# 1141                     information confidentiality               50
# 974                         log transmitter readings               28
# 292                           manage system security               15
# 304                            perform data analysis               25
# 929                         address identified risks               21
# 639                         analyse logistic changes               33
# 324                manage youth information services              211
# 861                             define risk policies              105
# 976                 manage dispatch software systems               12
# 612                                              APL              340
# 1466                                          Joomla              128
# 233                          perform forest analysis               17
# 214                             condense information               12
# 1038                         manage content metadata               14
# 1679  plan event marketing for promotional campaigns               10
# 678                          digital data processing               29
# 1372                  conduct research before survey               83
# 1664                   organise information services               21
# 79                          develop management plans               48
# 1694              apply customer engagement strategy               26
# 176                    develop irrigation strategies              110
# 130                            conduct shelf studies              221
# 220                manage technical security systems               18
# 24                             information structure               30
# 663                               analyse membership               39
# 1190               conduct jewellery market research              194
# 649                           research website users               12
# 534                     apply advanced manufacturing               54
# 411                         decision support systems              196
# 448                              industrial software              120
# 687                         use ICT ticketing system               21
# 412                                              DB2              403
# 775                          transmission technology              103
# 1205                           develop code exploits               15
# 1305                                          Moodle               44
# 1718                                    use IT tools               22
# 1151                                adjust projector               60
# 1100                      database development tools               82

# %%
self_reflection.sort_values("self_reflection", ascending=False).head(50)
# Out:
#                                          skills  self_reflection
# 271                                        LESS             1671
# 1464                           read manuscripts             1479
# 1208                                      SPARK             1401
# 925                             discuss artwork             1369
# 1612                             observe matter             1352
# 1172                                      Sakai             1295
# 932                                        JSSS             1221
# 1462                          model groundwater             1197
# 612                                         APL              970
# 196                                         MDX              943
# 530                                 TripleStore              936
# 1063                    perform PESTEL analysis              815
# 568                                       Vyper              739
# 1572                             study artworks              701
# 1143                                       LDAP              670
# 1192                           identify fossils              606
# 1333               evaluate spatial information              596
# 1792                                Capture One              596
# 237                                     Engrade              558
# 1705                             analyse issues              550
# 20                                       Erlang              534
# 412                                         DB2              523
# 21                                  taste wines              511
# 577                    conduct costume research              494
# 212                                      Drupal              491
# 1445                           mine dump design              436
# 1305                                     Moodle              426
# 1383                                       LINQ              424
# 713                      information extraction              423
# 1066                           ABBYY FineReader              416
# 1466                                     Joomla              410
# 1310                            security panels              406
# 1358                      application usability              402
# 718                                        STAF              392
# 1220                                     Synfig              390
# 961                              Ajax Framework              358
# 1321  perform risk assessment for fight actions              330
# 555                                           R              321
# 1549                                      COBOL              313
# 1061                               CoffeeScript              297
# 1730                     synthesise information              295
# 1604                                  MarkLogic              290
# 1573          advanced driver assistant systems              287
# 846                 analyse election procedures              273
# 891                    analyse education system              268
# 328          manage rubber products development              263
# 365             evaluate restoration procedures              249
# 1711                        maintain ICT server              242
# 199                    information architecture              240
# 1764                        maintain ICT system              239

# %%
display(self_reflection[self_reflection.skills == "SQL"])
display(self_reflection[self_reflection.skills == "machine learning"])
display(self_reflection[self_reflection.skills == "Hadoop"])
# Out:
#     skills  self_reflection
# 615    SQL              170
#                skills  self_reflection
# 388  machine learning                2
#       skills  self_reflection
# 1580  Hadoop                1

# %% [markdown]
# With only lowercase :

# %%
skills = tech_skills.name.values
self_reflection = []
for skill in tqdm(skills):
    vec = word_emb_model(**word_emb_tokenizer(skill.lower(), return_tensors="pt", max_length=768, padding=True, truncation=True)).last_hidden_state[:, 0, :]
    tech_emb_tax["similarity"] = tech_emb_tax["embeddings"].apply(lambda x : F.cosine_similarity(vec, x).item())

    quest = tech_emb_tax.sort_values("similarity", ascending=False).reset_index()
    self_reflection.append(quest[quest.name == skill].index[0])
# Out:
#   0%|          | 0/1794 [00:00<?, ?it/s]

# %%
lower_self_reflection = pd.DataFrame({
    'skills': skills,
    "self_reflection": self_reflection
})

# %%
display(lower_self_reflection[lower_self_reflection.skills=="Hadoop"])
display(lower_self_reflection[lower_self_reflection.skills=="SQL"])
# Out:
#       skills  self_reflection
# 1580  Hadoop               37
#     skills  self_reflection
# 615    SQL              206

# %%
lower_self_reflection[lower_self_reflection.self_reflection >= 10].describe()
# Out:
#        self_reflection
# count       327.000000
# mean        120.058104
# std         241.821322
# min          10.000000
# 25%          16.000000
# 50%          35.000000
# 75%          99.500000
# max        1639.000000

# %% [markdown]
# ## Analysing prototype generation

# %%
generated_records = pd.read_csv("./generated/PROTOTYPE/prototype.csv").drop("Unnamed: 0", axis=1).to_dict("records")
generated_records
# Out:
# [{'skills': "['check quality of enamel']",
#   'sentence': 'We are seeking a detail-oriented individual with expertise in inspecting and evaluating the enamel finish to ensure exceptional quality and adherence to specifications.',
#   'sentence_len': 31,
#   'skill_number': 1},
#  {'skills': "['check quality of enamel']",
#   'sentence': "We are seeking a meticulous and detail-oriented individual to join our team as a Quality Assurance Specialist. In this role, you will be responsible for ensuring the highest standards of enamel quality are maintained throughout our production process. You will utilize your keen eye for detail and expertise in quality control methodologies to carefully inspect enamel products, identify any defects or imperfections, and make recommendations for improvement. Your in-depth knowledge of enamel properties and characteristics will play a vital role in guaranteeing the final product meets our clients' exacting standards. As the ideal candidate, you will have a proven track record of consistently delivering impeccable quality results and a passion for maintaining excellence in every aspect of your work.",
#   'sentence_len': 151,
#   'skill_number': 1},
#  {'skills': "['contribute to high level health strategic decisions']",
#   'sentence': 'Join our team and use your expertise in shaping the future of healthcare by providing valuable insights to guide high-level strategic decisions that impact health outcomes.',
#   'sentence_len': 32,
#   'skill_number': 1},
#  {'skills': "['contribute to high level health strategic decisions']",
#   'sentence': 'We are seeking a dynamic individual to join our team as a Health Strategy Specialist. In this role, you will play a pivotal role in shaping and contributing to high-level health strategic decisions. Drawing upon your expertise in healthcare management and policy, you will collaborate with key stakeholders to develop innovative strategies that enhance the delivery of healthcare services. Your ability to analyze complex data, anticipate future trends, and provide insightful recommendations will be instrumental in driving organizational success. The ideal candidate will possess a strong understanding of the healthcare landscape, a proven track record in strategic planning, and the ability to effectively communicate and influence stakeholders at all levels. If you are passionate about making a difference in the healthcare sector and possess the skills to contribute to high-level health strategic decisions, we invite you to apply for this exciting opportunity.',
#   'sentence_len': 164,
#   'skill_number': 1},
#  {'skills': "['create underwriting guidelines', 'develop procurement strategy', 'create credit policy', 'identify if a company is a going concern', 'define security policies', 'assess reliability of data', 'develop taxation policies', 'advise on environmental risk management systems', 'ensure compliance with disclosure criteria of accounting information', 'define risk policies']",
#   'sentence': 'We are seeking a highly skilled candidate to join our team as a Policy and Risk Management Specialist. In this role, you will be responsible for developing and implementing a comprehensive set of underwriting guidelines and credit policies. Your expertise in assessing the reliability of data and ensuring compliance with disclosure criteria of accounting information will be essential in analyzing and identifying if a company is a going concern. Additionally, you will be tasked with defining security policies and advising on environmental risk management systems. Your ability to develop procurement and taxation policies will contribute to the overall success of our organization. As a Policy and Risk Management Specialist, you will play a crucial role in defining our risk policies and ensuring their effective implementation throughout the company. The ideal candidate will possess a deep understanding of these areas, along with excellent analytical and strategic thinking skills.',
#   'sentence_len': 162,
#   'skill_number': 10},
#  {'skills': "['analyse the artistic concept based on stage actions', 'draw up artistic programming policy', 'verify feasibility']",
#   'sentence': 'We are seeking a highly skilled individual who can critically evaluate and interpret the artistic vision in order to develop and implement a comprehensive artistic programming strategy, ensuring the feasibility and practicality of stage actions.',
#   'sentence_len': 42,
#   'skill_number': 3},
#  {'skills': "['analyse the artistic concept based on stage actions', 'draw up artistic programming policy', 'verify feasibility']",
#   'sentence': "We are currently seeking a highly skilled and creative individual to join our team as an Artistic Programming Specialist. In this role, you will be responsible for analyzing stage actions and critically evaluating the artistic concept to ensure it aligns with our organization's vision and objectives. Your main task will be to draw up a comprehensive artistic programming policy that encompasses a wide range of artistic disciplines and genres. You must have a keen eye for detail and the ability to verify the feasibility of proposed artistic projects, taking into consideration technical, logistical, and budgetary constraints. The ideal candidate will possess a deep understanding of the artistic landscape, strong analytical skills, and the ability to think outside the box to curate innovative and engaging programs that will captivate our diverse audience.",
#   'sentence_len': 156,
#   'skill_number': 3},
#  {'skills': "['microchip scanners']",
#   'sentence': 'We are seeking a highly skilled and experienced individual who demonstrates a deep understanding of advanced technology systems, including expertise in using cutting-edge scanning equipment for microchip analysis and identification.',
#   'sentence_len': 38,
#   'skill_number': 1},
#  {'skills': "['microchip scanners']",
#   'sentence': 'We are seeking a highly skilled individual to join our team as a Technical Support Engineer. In this role, you will be responsible for providing expert assistance in troubleshooting and resolving technical issues related to our microchip scanners. Your extensive knowledge and experience in diagnosing and repairing microchip scanners will be essential in ensuring smooth operations and high-quality services for our clients. Additionally, you will have the opportunity to collaborate with our R&D team to enhance the functionality and performance of our scanners. The ideal candidate will possess strong problem-solving skills, a thorough understanding of microchip scanner technology, and the ability to effectively communicate complex technical concepts to both technical and non-technical stakeholders. Join us and be part of a dynamic team at the forefront of innovation in microchip scanning technology.',
#   'sentence_len': 172,
#   'skill_number': 1},
#  {'skills': "['develop scientific research protocols', 'conduct research on speech-related topics', 'develop methods for choreographic integration']",
#   'sentence': 'We are seeking a highly skilled and experienced candidate who has a comprehensive understanding of scientific research protocols to conduct in-depth research on speech-related topics and develop innovative methods for integrating choreography seamlessly into our productions.',
#   'sentence_len': 45,
#   'skill_number': 3},
#  {'skills': "['develop scientific research protocols', 'conduct research on speech-related topics', 'develop methods for choreographic integration']",
#   'sentence': 'We are seeking a highly skilled and innovative Researcher to join our team. As a key member of the research department, you will be responsible for designing and implementing scientific research protocols to investigate speech-related topics. Your expertise in developing and refining research methodologies will be crucial in ensuring the accuracy and reliability of our findings. Additionally, your ability to analyze and interpret data will enable you to identify patterns and trends within the field. The successful candidate will have a proven track record in conducting research and a strong knowledge of speech-related topics. Your keen eye for detail and excellent organizational skills will ensure the successful execution of research projects. Furthermore, your ability to communicate and collaborate effectively with multidisciplinary teams will be essential in integrating research findings into actionable insights. Overall, you will play a vital role in expanding our knowledge and furthering the field of speech-related research.',
#   'sentence_len': 176,
#   'skill_number': 3},
#  {'skills': "['apply desktop publishing techniques', 'lay out digital written content', 'use digital illustration techniques', 'desktop publishing']",
#   'sentence': 'We are looking for a skilled candidate with expertise in applying various techniques for desktop publishing, laying out digital written content, and utilizing digital illustration techniques to create visually appealing and engaging materials.',
#   'sentence_len': 38,
#   'skill_number': 4},
#  {'skills': "['apply desktop publishing techniques', 'lay out digital written content', 'use digital illustration techniques', 'desktop publishing']",
#   'sentence': 'We are currently seeking a talented individual to join our creative team as a Digital Content Designer. In this role, you will be responsible for applying your expertise in desktop publishing to create visually stunning and engaging digital content. Your skills in laying out digital written content will be crucial in ensuring a seamless user experience. Additionally, your proficiency in using digital illustration techniques will allow you to bring our ideas to life and captivate our audience. If you have a creative eye, a strong attention to detail, and a passion for creating visually compelling materials, we would love to hear from you. Join us and be part of an innovative and dynamic team where your skills in desktop publishing will be put to great use.',
#   'sentence_len': 145,
#   'skill_number': 4},
#  {'skills': "['perform backups', 'use back-up and recovery tools']",
#   'sentence': 'We are seeking a highly skilled candidate with expertise in ensuring data safety through regular data protection measures and leveraging relevant software for data restoration in our organization.',
#   'sentence_len': 32,
#   'skill_number': 2},
#  {'skills': "['perform backups', 'use back-up and recovery tools']",
#   'sentence': "We are seeking a highly skilled individual to join our team as a Data Protection Specialist. In this role, you will be responsible for ensuring the integrity and security of our organization's data. Your expertise in performing backups and using back-up and recovery tools will be essential in safeguarding our valuable information. You will be expected to have a deep understanding of data protection principles and best practices, as well as the ability to implement and maintain robust backup solutions. Additionally, you will play a key role in disaster recovery planning and execution. The ideal candidate will have proven experience in managing data protection operations, with a keen attention to detail and a strong problem-solving mindset.",
#   'sentence_len': 138,
#   'skill_number': 2},
#  {'skills': "['use methods of logistical data analysis', 'data mining methods', 'conduct analysis of ship data', 'perform data analysis', 'analyse big data', 'apply statistical analysis techniques']",
#   'sentence': 'We are currently seeking a highly skilled Data Analyst to join our dynamic team. The ideal candidate should have a strong background in data analysis and possess expertise in using methods of logistical data analysis, data mining methods, and statistical analysis techniques. As a Data Analyst, you will be responsible for conducting in-depth analysis of ship data, performing data analysis, and analyzing big data sets. Your analytical insights will play a crucial role in informing business decisions and driving operational efficiency. Strong problem-solving abilities, attention to detail, and proficiency in applying statistical analysis techniques are a must-have for this role. If you thrive in a fast-paced environment and have a passion for uncovering meaningful insights from complex data, we invite you to apply for this exciting opportunity.',
#   'sentence_len': 161,
#   'skill_number': 6},
#  {'skills': "['conduct fish populations studies', 'develop aquaculture breeding strategies', 'conduct ecological surveys', 'conduct fish mortality studies', 'collect growth rate information']",
#   'sentence': 'We are seeking a skilled and knowledgeable candidate to join our team as a Fisheries Research Scientist. As a key member of our research team, you will be responsible for conducting various fish populations studies, including ecological surveys and fish mortality studies. Your expertise in collecting growth rate information and analyzing data will be crucial in providing valuable insights into the health and sustainability of aquatic ecosystems. Additionally, your ability to develop innovative aquaculture breeding strategies will contribute to the advancement of our industry. We are looking for an individual with a strong background in fisheries research and a demonstrated passion for environmental conservation. The ideal candidate will possess excellent analytical and problem-solving skills, as well as the ability to effectively communicate findings to both scientific and non-scientific audiences. Join our team and make a significant impact in the field of fisheries research.',
#   'sentence_len': 164,
#   'skill_number': 5},
#  {'skills': "['mark the stage area']",
#   'sentence': 'We are seeking a highly skilled individual who can efficiently identify and delineate the designated areas on the stage for performers and props placement, ensuring smooth transitions and seamless performances.',
#   'sentence_len': 39,
#   'skill_number': 1},
#  {'skills': "['mark the stage area']",
#   'sentence': 'We are seeking a detail-oriented Stage Manager to join our dynamic team. The ideal candidate will have a keen eye for precision and be responsible for overseeing the stage setup and ensuring that all technical elements are seamlessly integrated. As the Stage Manager, you will be responsible for coordinating with the production team to mark the stage area accurately, ensuring that props, lighting, and sound cues are executed flawlessly. You will play a pivotal role in maintaining a smooth flow of the performance, ensuring that all performers are positioned correctly and have clear cues. The successful candidate will have a strong understanding of stage logistics and be able to adapt quickly to any changes during rehearsals and live shows. If you are passionate about creating unforgettable performances and have a knack for marking the stage area meticulously, we would love to have you as part of our team.',
#   'sentence_len': 177,
#   'skill_number': 1},
#  {'skills': "['analyse relation between supply chain improvement and profit', 'identify process improvements', 'meet productivity targets']",
#   'sentence': 'We are seeking a highly skilled professional who can effectively assess the correlation between supply chain optimization and financial growth, propose and implement process enhancements, and consistently achieve and surpass productivity goals.',
#   'sentence_len': 39,
#   'skill_number': 3},
#  {'skills': "['analyse relation between supply chain improvement and profit', 'identify process improvements', 'meet productivity targets']",
#   'sentence': 'We are seeking a highly motivated candidate to join our team as a Supply Chain Analyst. As the ideal candidate, you will have a deep understanding of the correlation between supply chain improvements and profitability, allowing you to provide valuable insights into our operations. You will be responsible for identifying process improvements across various departments, working closely with cross-functional teams to streamline our operations and drive efficiency. Additionally, you will play a crucial role in meeting productivity targets by analyzing key performance indicators and recommending strategies to optimize our processes. If you are a detail-oriented and analytical thinker with a passion for continuous improvement, we would love to hear from you. Apply today and become an integral part of our success.',
#   'sentence_len': 148,
#   'skill_number': 3},
#  {'skills': "['address identified risks', 'develop appropriate health and safety measures in accordance with available resources', 'perform feasibility study on geothermal energy', 'draw up risk assessment']",
#   'sentence': '1. We are seeking a diligent candidate with a strong understanding of safety protocols, who can effectively evaluate potential risks and devise tailored strategies to mitigate them, ensuring the development and implementation of appropriate health and safety measures based on the available resources.\n\n2. Our company is looking for an experienced professional capable of conducting comprehensive feasibility studies on geothermal energy projects, analyzing potential risks, and formulating actionable plans to address them, ensuring the optimal utilization of resources.\n\n3. Join our team and contribute to our commitment to a safe working environment by using your expertise to assess and manage risks, as well as create robust risk assessments that comply with industry standards and guidelines.\n\n4. Are you an exceptional problem-solver with a thorough understanding of risk management? We are seeking a candidate who can confidently address identified risks, developing cost-effective health and safety measures aligned with available resources.\n\n5. We are in search of an analytical individual who can conduct in-depth feasibility studies on geothermal energy, assessing potential risks, and providing strategic recommendations to minimize their impact, while optimizing resource utilization.\n\n6. If you have a keen eye for detail and possess the ability to draw up risk assessments that adhere to strict regulations, we invite you to apply for the position, where you will play a crucial role in ensuring the safety and well-being of our employees and stakeholders.\n\n7. Join our team of experts and utilize your knowledge and skills to analyze and address identified risks, while developing comprehensive health and safety measures that align with our available resources.\n\n8. We are looking for a candidate who can perform detailed feasibility studies on geothermal energy projects, identifying potential risks and proposing effective strategies to manage them, ensuring the successful implementation of required measures.\n\n9. As a valuable member of our team, you will be responsible for proactively addressing identified risks, utilizing your expertise to develop and implement appropriate health and safety measures, while efficiently managing available resources.\n\n10. If you have a passion for renewable energy and possess the ability to draw up comprehensive risk assessments, we encourage you to apply for this position, where you will contribute to the evaluation of geothermal energy projects and the development of appropriate risk mitigation strategies.',
#   'sentence_len': 462,
#   'skill_number': 4},
#  {'skills': "['address identified risks', 'develop appropriate health and safety measures in accordance with available resources', 'perform feasibility study on geothermal energy', 'draw up risk assessment']",
#   'sentence': 'We are seeking a highly skilled and proactive professional to join our team as a Health and Safety Specialist. In this role, you will be responsible for addressing identified risks and developing appropriate health and safety measures that align with available resources. You will conduct in-depth feasibility studies on geothermal energy and provide recommendations based on your findings. Additionally, you will play a key role in ensuring compliance by drawing up comprehensive risk assessments. The ideal candidate will have a strong background in risk management, exceptional analytical skills, and the ability to implement effective health and safety measures in a dynamic and ever-changing environment.',
#   'sentence_len': 125,
#   'skill_number': 4},
#  {'skills': "['interpret seismic data', 'carry out geological explorations', 'prepare well data sheets', 'plan geotechnical investigations in the field', 'collect geological data', 'assist with geophysical surveys']",
#   'sentence': 'We are currently seeking a skilled professional to join our team as a Geotechnical Analyst. In this role, you will be responsible for interpreting seismic data and carrying out geological explorations to identify potential mineral deposits. Your expertise in preparing well data sheets and planning geotechnical investigations in the field will be essential in supporting our exploration efforts. Additionally, your ability to collect geological data and assist with geophysical surveys will play a crucial role in our research and analysis. The ideal candidate will have a strong background in geology and geotechnical engineering, with a proven track record in utilizing their skills to drive successful exploration projects. If you are passionate about contributing to the field of earth sciences and are ready to take on new challenges, we invite you to apply for this exciting opportunity.',
#   'sentence_len': 164,
#   'skill_number': 6},
#  {'skills': "['scientific modelling', 'enrich the key idea', 'research human behaviour']",
#   'sentence': 'We are seeking a highly skilled individual who can apply advanced analytical techniques to study and understand human behavior, while concurrently generating innovative concepts that enhance the central idea through scientific modeling.',
#   'sentence_len': 36,
#   'skill_number': 3},
#  {'skills': "['scientific modelling', 'enrich the key idea', 'research human behaviour']",
#   'sentence': 'We are seeking a highly analytical candidate to join our research team. As a Research Scientist, you will be responsible for conducting scientific modeling and analysis to enrich the key idea of our projects. Your expertise in understanding and predicting human behavior will be crucial in shaping our research initiatives. In this role, you will collaborate closely with cross-functional teams to translate complex data into actionable insights. The successful candidate will have a deep understanding of research methodologies and be adept at leveraging data-driven approaches to drive innovation. Strong critical thinking and problem-solving skills are essential to thrive in this dynamic environment. If you have a passion for scientific research and a proven track record of uncovering unique patterns in human behavior, we want to hear from you. Apply now to join our team and contribute to groundbreaking research in our organization.',
#   'sentence_len': 172,
#   'skill_number': 3},
#  {'skills': "['operate climate control']",
#   'sentence': 'We are seeking a highly skilled individual with a strong background in system operations and environmental control, capable of effectively managing and maintaining a complex climate control infrastructure.',
#   'sentence_len': 32,
#   'skill_number': 1},
#  {'skills': "['operate climate control']",
#   'sentence': 'Looking for a skilled professional to join our team! We are seeking an experienced individual with a strong background in managing and optimizing climate control systems. The ideal candidate will have a thorough understanding of operating climate control equipment and ensuring optimal environmental conditions are maintained. Additionally, knowledge of industry best practices and the ability to troubleshoot and resolve any issues that may arise is essential. If you have a proven track record in operating climate control systems and are passionate about creating the perfect environment, then we want to hear from you!',
#   'sentence_len': 105,
#   'skill_number': 1},
#  {'skills': "['oversee record management']",
#   'sentence': 'We are seeking a detail-oriented candidate with a strong ability to efficiently manage and maintain records, ensuring compliance with organizational protocols and industry regulations, while optimizing accessibility and confidentiality.',
#   'sentence_len': 40,
#   'skill_number': 1},
#  {'skills': "['oversee record management']",
#   'sentence': "We are currently seeking a detail-oriented and organized individual to join our team as a Records Management Specialist. In this role, you will be responsible for overseeing the efficient and effective management of all records within the organization. Your expertise in record management will be essential as you ensure compliance with industry regulations and implement best practices for data classification, retention, and disposal. The successful candidate will possess excellent organizational skills, strong attention to detail, and a deep understanding of records management principles. You will play a critical role in maintaining the integrity and security of our records, while also supporting the broader goals of the company. If you have a proven track record in overseeing record management and a passion for maintaining accurate and accessible information, we would love to hear from you. Come join our team and make a valuable contribution to our organization's success.",
#   'sentence_len': 167,
#   'skill_number': 1},
#  {'skills': "['VBScript', 'Erlang', 'Common Lisp', 'JavaScript']",
#   'sentence': '1. We are seeking a highly skilled Full Stack Developer with expertise in a variety of programming languages, including VBScript, Erlang, Common Lisp, and JavaScript, to join our dynamic team.\n2. We are looking for a talented Software Engineer who possesses a strong command of VBScript, Erlang, Common Lisp, and JavaScript, and can leverage their expertise to design and develop innovative solutions.\n3. The ideal candidate for this position will have a solid background in VBScript, Erlang, Common Lisp, and JavaScript, and will be able to seamlessly integrate these languages to create efficient and scalable software applications.\n4. As a Senior Software Developer, you will be responsible for utilizing your advanced knowledge of VBScript, Erlang, Common Lisp, and JavaScript to architect and implement cutting-edge solutions for our clients.\n5. We are seeking a highly motivated and detail-oriented individual with extensive experience in VBScript, Erlang, Common Lisp, and JavaScript, who can deliver high-quality code within tight deadlines.\n6. The successful candidate will possess a deep understanding of VBScript, Erlang, Common Lisp, and JavaScript, and will be able to effectively communicate complex concepts to both technical and non-technical stakeholders.\n7. We require a versatile and adaptable Software Engineer with expertise in VBScript, Erlang, Common Lisp, and JavaScript, who can quickly learn and apply new technologies to solve complex business problems.\n8. The ideal candidate for this role will have a proven track record of success in developing robust solutions using VBScript, Erlang, Common Lisp, and JavaScript, along with a strong understanding of industry best practices.\n9. We are seeking a highly skilled and innovative Developer who is proficient in VBScript, Erlang, Common Lisp, and JavaScript, and can contribute to the continuous improvement of our software products and systems.\n10. The successful candidate will have a breadth of experience in VBScript, Erlang, Common Lisp, and JavaScript, and will be able to work collaboratively with cross-functional teams to deliver high-quality software solutions.',
#   'sentence_len': 469,
#   'skill_number': 4},
#  {'skills': "['VBScript', 'Erlang', 'Common Lisp', 'JavaScript']",
#   'sentence': 'We are seeking a skilled software developer to join our dynamic team. The ideal candidate should have a strong background in programming languages such as VBScript, Erlang, Common Lisp, and JavaScript. A deep understanding of scripting languages is essential, as you will be responsible for developing and maintaining robust software solutions. The ability to effectively collaborate with cross-functional teams and communicate technical concepts to non-technical stakeholders is crucial. Furthermore, a proven track record of problem-solving and troubleshooting in a fast-paced environment will be advantageous. If you have a passion for innovation and possess expertise in these programming languages, we want to hear from you!',
#   'sentence_len': 136,
#   'skill_number': 4},
#  {'skills': "['normalise data']",
#   'sentence': 'We are looking for a detail-oriented Data Analyst with expertise in preparing and streamlining datasets to ensure consistent and standardized information across our organization.',
#   'sentence_len': 33,
#   'skill_number': 1},
#  {'skills': "['normalise data']",
#   'sentence': 'We are seeking a meticulous Data Analyst to join our team. As a Data Analyst, you will be responsible for ensuring the accuracy and integrity of our data by normalizing and standardizing it. You will utilize your expertise in data normalization techniques to identify and resolve inconsistencies, ensuring that our data is reliable and consistent across all systems. In addition, you will collaborate with cross-functional teams to design and implement data normalization processes that optimize data quality and improve overall efficiency. The ideal candidate will have a strong understanding of data normalization methodologies and the ability to apply them in a fast-paced and dynamic environment. Attention to detail and a focus on data accuracy are key attributes for success in this role. Join us and make a significant impact on our data integrity initiatives.',
#   'sentence_len': 170,
#   'skill_number': 1},
#  {'skills': '[\'process medical insurance claims\', \'check information on prescriptions\', "obtain healthcare user\'s medical status information"]',
#   'sentence': 'We are seeking a highly skilled individual with expertise in managing medical billing and insurance claims, ensuring accuracy and efficiency. The ideal candidate will also possess the ability to review and verify prescription information, as well as gather and assess medical status information from healthcare users.',
#   'sentence_len': 53,
#   'skill_number': 3},
#  {'skills': '[\'process medical insurance claims\', \'check information on prescriptions\', "obtain healthcare user\'s medical status information"]',
#   'sentence': "We are seeking a detail-oriented and organized individual to join our team as a Medical Claims Administrator. In this role, you will be responsible for accurately processing medical insurance claims, ensuring all information is complete and correct. You will utilize your strong attention to detail as you carefully check information on prescriptions to ensure accuracy and adherence to regulatory guidelines. Additionally, you will work closely with healthcare professionals to obtain and verify healthcare users' medical status information, providing essential support in maintaining accurate records. The ideal candidate will have previous experience in medical claims processing and possess a thorough understanding of insurance protocols and regulations. Strong communication and problem-solving skills are essential, as you will collaborate with various stakeholders to ensure timely and accurate claim submissions. Join our team and make a significant impact on the healthcare insurance process.",
#   'sentence_len': 165,
#   'skill_number': 3},
#  {'skills': "['manage clinical risk', 'undertake risk assessment of social service users', 'apply risk management in sports', 'assess health services within the community', 'develop contingency plans for emergencies']",
#   'sentence': 'We are currently seeking a skilled professional to join our team as a Risk Management Specialist. In this role, you will be responsible for managing clinical risk and ensuring the safety and well-being of our social service users. Your expertise in undertaking risk assessments and applying risk management in various contexts, including sports, will be crucial in identifying and mitigating potential hazards. Additionally, you will have the opportunity to assess health services within the community and contribute to the development of contingency plans for emergencies. The ideal candidate will have a strong background in risk management and a demonstrated ability to develop comprehensive strategies to minimize risks and maximize safety.',
#   'sentence_len': 130,
#   'skill_number': 5},
#  {'skills': "['use milk control software', 'analyse milk control test results']",
#   'sentence': 'We are seeking a highly skilled candidate with expertise in managing and analyzing milk quality data using specialized software, ensuring accurate and efficient interpretation of milk control test results.',
#   'sentence_len': 33,
#   'skill_number': 2},
#  {'skills': "['use milk control software', 'analyse milk control test results']",
#   'sentence': 'We are seeking a skilled individual to join our team as a Milk Control Specialist. In this role, you will be responsible for utilizing milk control software to ensure the quality and safety of our milk products. Your expertise in analyzing milk control test results will play a crucial role in identifying any deviations or abnormalities that may occur during the production process. With your attention to detail and strong analytical abilities, you will contribute to maintaining the highest standards in milk quality. Experience in using milk control software and analyzing test results is required for this position.',
#   'sentence_len': 110,
#   'skill_number': 2},
#  {'skills': "['use ICT systems', 'use ICT resources to solve work related tasks']",
#   'sentence': 'We are seeking a candidate who possesses advanced proficiency in leveraging technology to efficiently use digital tools and resources in order to accomplish job-related assignments and projects.',
#   'sentence_len': 34,
#   'skill_number': 2},
#  {'skills': "['use ICT systems', 'use ICT resources to solve work related tasks']",
#   'sentence': "Are you a tech-savvy individual with a passion for utilizing cutting-edge technology to drive business efficiency? We are seeking a highly skilled professional who can expertly navigate ICT systems and leverage ICT resources to seamlessly solve a wide range of work-related tasks. As our ideal candidate, you will have a deep understanding of the latest technologies, allowing you to identify and implement innovative solutions that enhance productivity and streamline processes. Whether it's harnessing the power of cloud computing or using data analytics tools to gain valuable insights, your expertise in leveraging ICT systems will be instrumental in driving our organization's success. Join our dynamic team and make a significant impact by harnessing the full potential of ICT resources to overcome challenges and achieve outstanding results",
#   'sentence_len': 160,
#   'skill_number': 2},
#  {'skills': "['draw up risk assessment', 'advise on risk management', 'develop appropriate health and safety measures in accordance with available resources', 'review development process of an organisation', 'evaluate benefit plans', 'write risk assessment on performing arts production']",
#   'sentence': 'We are currently seeking a highly skilled professional to join our team as a Risk Assessment Specialist. In this role, you will be responsible for evaluating and advising on risk management strategies, drawing up comprehensive risk assessments, and developing appropriate health and safety measures. You will also review the development process of our organization, ensuring that all necessary precautions are taken to mitigate potential risks. Additionally, you will play a crucial role in evaluating benefit plans and writing risk assessments for our performing arts production. The ideal candidate will have a strong background in risk assessment and management, with a keen eye for detail and the ability to identify potential hazards. Experience in developing health and safety measures in accordance with available resources is essential. If you thrive in a fast-paced environment and are passionate about promoting a safe and secure working environment, we would love to hear from you.',
#   'sentence_len': 173,
#   'skill_number': 6},
#  {'skills': "['Cain and Abel (penetration testing tool)', 'implement a firewall']",
#   'sentence': 'We are looking for a skilled candidate who possesses expertise in network security tools and technologies, with the ability to effectively assess vulnerabilities and ensure the implementation of robust firewall systems.',
#   'sentence_len': 40,
#   'skill_number': 2},
#  {'skills': "['Cain and Abel (penetration testing tool)', 'implement a firewall']",
#   'sentence': 'We are seeking a talented and experienced cybersecurity professional to join our team. The ideal candidate should have a strong expertise in various cybersecurity tools and technologies, including those related to network security and penetration testing. In this role, you will be responsible for implementing and maintaining robust firewalls to protect our network infrastructure from potential threats. Additionally, you will utilize your knowledge of various penetration testing tools, such as Cain and Abel, to identify vulnerabilities and strengthen our overall security posture. The ability to analyze and mitigate risks, while ensuring compliance with industry regulations, is also essential. If you have a proven track record in implementing firewalls and utilizing advanced penetration testing techniques, then we want to hear from you. Join us and be a part of our mission to safeguard our organization from cyber threats.',
#   'sentence_len': 175,
#   'skill_number': 2},
#  {'skills': "['evaluate clinical psychological measures', 'provide psychological health assessment strategies', 'collect healthcare user data under supervision', 'implement scientific decision making in healthcare', 'address identified risks', 'evaluate psychological health measures']",
#   'sentence': 'We are currently seeking a highly skilled and motivated professional to join our team as a Healthcare Data Analyst. In this role, you will be responsible for evaluating and analyzing clinical psychological measures to assess the psychological well-being of healthcare users. Utilizing your expertise, you will develop and implement strategic assessment strategies to address identified risks and gather essential healthcare user data under supervision. Your exceptional scientific decision-making abilities will be critical in identifying trends and patterns, ultimately aiding in the development of effective psychological health measures. As a crucial member of our team, you will contribute to the overall improvement of healthcare outcomes by providing valuable insights and recommendations based on your evaluation of these measures. The ideal candidate will have a strong background in healthcare data analysis and a deep understanding of implementing rigorous evaluation methodologies in a healthcare setting.',
#   'sentence_len': 164,
#   'skill_number': 6},
#  {'skills': "['perform clinical research in radiography', 'engage in physiotherapy research', 'undertake clinical chiropractic research', 'interpret medical results', 'conduct research on hearing topics', 'clinical decision-making at advanced practice']",
#   'sentence': 'We are currently seeking a highly skilled and dynamic individual to join our dedicated team as a Research Specialist. The successful candidate will have extensive experience in performing clinical research in radiography, engaging in physiotherapy research, and undertaking clinical chiropractic research. They will be responsible for interpreting medical results and conducting research on hearing topics. Additionally, the candidate will demonstrate advanced clinical decision-making skills in their practice. If you are a motivated and detail-oriented individual with a passion for research and a strong background in the medical field, we invite you to apply for this exciting opportunity.',
#   'sentence_len': 122,
#   'skill_number': 6},
#  {'skills': "['determine train operational safety actions', 'assess reliability of data', 'create risk reports', 'make independent operating decisions', 'anticipate potential deficiencies', 'analyse ship operations']",
#   'sentence': 'We are currently seeking a highly skilled and knowledgeable individual for the role of Operations Safety Analyst. As the Operations Safety Analyst, you will be responsible for determining and implementing operational safety actions for our train operations. Your expertise in assessing the reliability of data will be instrumental in creating accurate risk reports, which will be used to make independent operating decisions. You will be relied upon to anticipate potential deficiencies in our operations and analyze ship operations to ensure their efficiency and compliance with safety regulations. The ideal candidate will possess a deep understanding of train operations and be able to effectively analyze and address any risks or deficiencies that may arise. Join our team and play a crucial role in ensuring the safety and smooth operation of our train services.',
#   'sentence_len': 154,
#   'skill_number': 6},
#  {'skills': '["collect healthcare user\'s general data", \'tabulate survey results\', \'collect statistics on medical records\', \'analyse scientific data\', \'collect healthcare user data under supervision\']',
#   'sentence': 'We are currently seeking a highly organized and detail-oriented individual to join our healthcare research team. As a key member of the team, you will be responsible for collecting and organizing healthcare user data, under the supervision of senior researchers. Your role will involve gathering general data from healthcare users, tabulating survey results, and analyzing scientific data to identify trends and patterns. Additionally, you will have the opportunity to contribute to the collection of statistics on medical records, ensuring accurate and reliable information is obtained. The ideal candidate will possess excellent data collection and analysis skills, with a strong attention to detail.',
#   'sentence_len': 120,
#   'skill_number': 5},
#  {'skills': "['develop immigration policies', 'develop competition policies']",
#   'sentence': 'We are seeking a candidate with a profound understanding of regulatory frameworks and the ability to shape policies that promote fair and balanced competition, ensuring a level playing field for all market participants, as well as a comprehensive knowledge of immigration legislation to design and implement policies that effectively manage the movement of individuals across borders.',
#   'sentence_len': 62,
#   'skill_number': 2},
#  {'skills': "['develop immigration policies', 'develop competition policies']",
#   'sentence': "We are currently seeking a skilled policy analyst to join our team. As a policy analyst, you will play a crucial role in developing and implementing effective policies that drive our organization's growth. Your expertise in immigration policies and competition policies will be essential in ensuring that our organization remains compliant with regulatory requirements while fostering healthy competition within the industry. You will also be responsible for conducting thorough research, analyzing data, and collaborating with stakeholders to develop well-informed policies that address key challenges and opportunities. The ideal candidate will have a strong understanding of the legal framework surrounding immigration and competition, as well as the ability to navigate complex policy landscapes. If you are passionate about influencing policy decisions and driving impactful change, we invite you to apply for this role.",
#   'sentence_len': 155,
#   'skill_number': 2},
#  {'skills': "['manage access programmes', 'support sport activities in education', 'develop corporate training programmes', 'manage corporate training programmes', 'analyse curriculum', 'assess data collected to improve community arts programme']",
#   'sentence': 'We are currently seeking a highly skilled individual to join our team as a Training Program Manager. In this role, you will be responsible for managing and overseeing our corporate training programs, ensuring that they are effectively designed and meet the needs of our organization. You will analyze curriculum and assess data collected to continuously improve our community arts program. Your expertise in managing access programs and supporting sport activities in education will be essential in collaborating with various stakeholders to develop and implement comprehensive training initiatives. The successful candidate will have a demonstrated ability to develop innovative training programs that enhance employee skills and knowledge. If you have a passion for training and development, along with strong analytical and leadership skills, we would love to hear from you. Apply today and take your career to the next level.',
#   'sentence_len': 154,
#   'skill_number': 6},
#  {'skills': "['manage content metadata', 'digital content creation', 'manage data, information and digital content', 'apply tools for content development', 'provide guidelines for content development']",
#   'sentence': 'We are currently seeking a highly skilled Content Manager to join our dynamic team. As the Content Manager, you will be responsible for managing and organizing content metadata to ensure accurate and efficient categorization of our digital assets. With your expertise in digital content creation, you will also play a crucial role in developing engaging and compelling content that aligns with our brand image. Your ability to manage data, information, and digital content will be vital in maintaining a well-structured and easily accessible content library. Additionally, you will apply various tools for content development, allowing for seamless content creation and delivery across multiple platforms. Your extensive knowledge and experience in this field will enable you to provide valuable guidelines and best practices for content development, ensuring consistency and quality throughout our organization. If you are a detail-oriented and innovative professional with a deep understanding of content management and digital content creation, we invite you to apply for this exciting opportunity.',
#   'sentence_len': 189,
#   'skill_number': 5},
#  {'skills': "['create safe working protocols']",
#   'sentence': 'We are seeking an experienced candidate with expertise in establishing and implementing robust operational procedures to ensure a secure and hazard-free work environment.',
#   'sentence_len': 28,
#   'skill_number': 1},
#  {'skills': "['create safe working protocols']",
#   'sentence': 'We are looking for a diligent and safety-conscious individual to join our team as a [Job Title]. As a [Job Title], you will be responsible for ensuring the implementation of robust safety protocols and procedures to maintain a secure and hazard-free work environment. Your expertise in creating safe working protocols will be essential in identifying potential risks, developing preventive measures, and ensuring compliance with industry standards. You will collaborate with cross-functional teams to establish and communicate safety guidelines, conduct regular safety audits, and provide necessary training to employees. A successful candidate will possess strong problem-solving skills, attention to detail, and the ability to effectively communicate safety-related information to all levels of the organization. Join us and contribute to our commitment to the highest safety standards in the industry.',
#   'sentence_len': 161,
#   'skill_number': 1},
#  {'skills': "['use remote control equipment']",
# ...
#   'sentence': 'We are seeking a talented individual with exceptional knowledge of sourcing and managing suppliers of cutting-edge software components to join our team and contribute to the development of innovative software solutions.',
#   'sentence_len': 37,
#   'skill_number': 1},
#  {'skills': "['software components suppliers']",
#   'sentence': 'We are seeking a highly skilled candidate with expertise in sourcing software components to join our team as a Procurement Specialist. As a key member of our procurement department, you will be responsible for identifying and evaluating suppliers for software components. Your role will involve assessing the quality, reliability, and cost-effectiveness of various suppliers to ensure the smooth operation and development of our software systems. The ideal candidate will have a strong background in supplier management and exceptional negotiation skills to secure competitive pricing and favorable contract terms. If you are a detail-oriented individual with a proven track record in software component procurement, we would love to hear from you. Apply today to join our dynamic team and contribute to our continued success.',
#   'sentence_len': 145,
#   'skill_number': 1},
#  {'skills': "['develop competitive strategies in sport', 'develop opportunities for progression in sport']",
#   'sentence': "1. Seeking a dynamic Sports Strategist with a deep understanding of the ever-evolving landscape of sports competition, who can excel in developing and implementing innovative strategies to ensure sustained success in the highly competitive sports industry, while constantly identifying and leveraging new avenues for athletes' personal and professional growth.\n\n2. We are looking for a passionate Sports Development Manager who possesses expert knowledge in augmenting competitive strategies within the realm of sports, alongside adeptly creating and fostering diverse opportunities to maximize athletes' progress and achievement within their respective fields.\n\n3. Join our team as a Skilled Sports Analyst, responsible for conducting in-depth market research and utilizing your proficiency in developing cutting-edge competitive strategies in the sports domain, whilst actively identifying, nurturing, and expanding the scope of progression opportunities for aspiring athletes.\n\n4. Are you a visionary Sports Innovator with proven expertise in formulating strategic plans to stay ahead of the competition in the fast-paced sports industry? If you possess an uncanny ability to identify untapped potential and create forward-thinking opportunities for athletes' advancement, we want to hear from you.\n\n5. We are currently hiring a Sports Strategy Consultant who can successfully sculpt competitive strategies tailored to the ever-changing dynamics of the sports sector, facilitating the growth of athletes through groundbreaking opportunities that accelerate their development and elevate their professional career paths.",
#   'sentence_len': 295,
#   'skill_number': 2},
#  {'skills': "['develop competitive strategies in sport', 'develop opportunities for progression in sport']",
#   'sentence': "We are seeking a dynamic and visionary individual to join our team as a Sports Development Manager. As the ideal candidate, you possess a deep understanding of the sporting landscape and have a proven track record in developing competitive strategies in sport. You will play a crucial role in identifying and capitalizing on opportunities for progression in sport, ensuring that our organization remains at the forefront of the industry. Your strategic thinking, strong leadership abilities, and ability to build collaborative partnerships will drive our organization's success. Join us and make a lasting impact on the future of sport.",
#   'sentence_len': 114,
#   'skill_number': 2},
#  {'skills': "['Swift (computer programming)']",
#   'sentence': 'We are seeking a highly skilled and experienced software engineer with expertise in a modern, object-oriented programming language commonly used in iOS development.',
#   'sentence_len': 29,
#   'skill_number': 1},
#  {'skills': "['Swift (computer programming)']",
#   'sentence': "We are seeking a highly skilled mobile application developer with a strong command of iOS development. The ideal candidate should have a proven track record in building cutting-edge mobile applications using Swift programming language. In-depth knowledge of the latest iOS frameworks and libraries is essential. The successful candidate will be responsible for developing and maintaining high-quality, scalable mobile applications that align with our clients' business requirements. Strong problem-solving skills and attention to detail are crucial to succeed in this role. As a member of our agile development team, you will collaborate closely with designers, product managers, and other developers to deliver innovative solutions that push the boundaries of mobile technology. If you have a passion for mobile development and the drive to stay up-to-date with the latest industry trends, we want to hear from you.",
#   'sentence_len': 168,
#   'skill_number': 1},
#  {'skills': "['operate on-board computer systems']",
#   'sentence': 'We are seeking a highly skilled professional with extensive experience in seamlessly navigating and managing advanced computer systems integrated within our operational platforms.',
#   'sentence_len': 30,
#   'skill_number': 1},
#  {'skills': "['operate on-board computer systems']",
#   'sentence': "We are currently seeking a highly skilled individual to join our team as a Computer Systems Operator. As the Computer Systems Operator, you will be responsible for effectively managing and operating on-board computer systems to ensure seamless and efficient operations. Your expertise in troubleshooting and maintaining computer systems will be crucial in providing technical support to our team. In addition, your knowledge of software applications and hardware configurations will contribute to the continuous improvement and optimization of our systems. The ideal candidate will possess a deep understanding of computer networks and possess strong problem-solving skills. Join us in this exciting opportunity and showcase your proficiency in operating on-board computer systems to drive our organization's success.",
#   'sentence_len': 141,
#   'skill_number': 1},
#  {'skills': "['define rigging needs for circus acts']",
#   'sentence': 'We are seeking a meticulous and experienced professional who can expertly assess and tailor rigging requirements for a variety of dynamic circus performances, ensuring the safety and seamless execution of each act.',
#   'sentence_len': 43,
#   'skill_number': 1},
#  {'skills': "['define rigging needs for circus acts']",
#   'sentence': 'We are searching for a skilled professional to join our dynamic team as a Rigging Specialist. In this role, you will be responsible for assessing and determining the specific rigging requirements for a wide range of circus acts. Your expertise in analyzing the unique characteristics of each act and identifying the appropriate rigging techniques will ensure the safety and smooth execution of our performances. The ideal candidate will have a comprehensive knowledge and understanding of circus rigging, including the ability to anticipate potential challenges and develop effective solutions. Strong communication and collaboration skills are essential for working closely with our performers and production crew. If you have a passion for the circus arts and the expertise to define rigging needs for performances, we invite you to apply for this exciting opportunity.',
#   'sentence_len': 150,
#   'skill_number': 1},
#  {'skills': "['Hadoop', 'SAP Data Services', 'SAS Data Management']",
#   'sentence': 'We are seeking a highly skilled candidate with an expertise in big data processing and analytics, utilizing advanced technologies and platforms such as distributed data processing frameworks, enterprise data integration tools, and data management software.',
#   'sentence_len': 44,
#   'skill_number': 3},
#  {'skills': "['Hadoop', 'SAP Data Services', 'SAS Data Management']",
#   'sentence': 'We are currently seeking a highly skilled individual to join our team as a Data Management Specialist. The ideal candidate will have a strong background in Big Data technologies such as Hadoop and possess expertise in data integration tools like SAP Data Services. In addition, proficiency in SAS Data Management is essential for this role. The successful candidate will be responsible for designing and implementing efficient data management solutions, ensuring data quality and integrity, and optimizing data workflows. Strong analytical and problem-solving skills, along with excellent communication and collaboration abilities, are also required. If you have a passion for managing and transforming data using cutting-edge technologies, we want to hear from you!',
#   'sentence_len': 137,
#   'skill_number': 3},
#  {'skills': "['convert different audiovisual formats', 'use audio reproduction software']",
#   'sentence': '1. Our ideal candidate possesses extensive experience in manipulating various audio and visual file types, and has a strong command of industry-standard software for playback and reproduction.\n\n2. We are seeking an individual with expertise in the seamless conversion of diverse audiovisual formats, coupled with a deep understanding of audio reproduction software and its functionalities.\n\n3. We are looking for a candidate who can proficiently handle the conversion of audio and visual files across different formats, and is well-versed in utilizing software tools for high-quality audio reproduction.\n\n4. Join our team if you have a knack for effortlessly converting audiovisual content to meet diverse format requirements, and are adept at utilizing cutting-edge audio software systems.\n\n5. As a valuable addition to our organization, you will be required to have a solid aptitude for converting audiovisual materials across various formats, alongside a strong background in using software for audio reproduction.',
#   'sentence_len': 195,
#   'skill_number': 2},
#  {'skills': "['convert different audiovisual formats', 'use audio reproduction software']",
#   'sentence': "We're looking for a highly skilled individual to join our dynamic team as a Multimedia Specialist. As the Multimedia Specialist, you will be responsible for handling audiovisual content and ensuring its seamless integration into various formats. Your expertise in converting different audiovisual formats will be crucial in ensuring that our content is accessible and engaging to a wide audience. Additionally, your proficiency in using audio reproduction software will allow you to manipulate sound effectively, enhancing the overall quality of our multimedia projects. Attention to detail and a creative mindset are essential as you collaborate with the team to produce visually stunning and compelling content. If you have a proven track record in audiovisual conversion and mastery of audio reproduction software, we want to hear from you. Join us and make your mark in the exciting world of multimedia production.",
#   'sentence_len': 170,
#   'skill_number': 2},
#  {'skills': "['tend CNC grinding machine', 'tend CNC milling machine', 'tend CNC drilling machine']",
#   'sentence': '1. We are looking for a candidate with extensive experience in operating and maintaining various CNC machines, such as grinding, milling, and drilling machines, who can ensure precision and accuracy in the production process.\n\n2. Seeking a skilled technician who can proficiently operate CNC machinery, including grinding, milling, and drilling machines, to perform intricate tasks and deliver high-quality output.\n\n3. Join our team as a CNC operator, responsible for overseeing the operation of different types of CNC machines, such as grinding, milling, and drilling machines, to meet specified production requirements.\n\n4. We are in need of a detail-oriented individual with expertise in operating CNC machinery, specifically working with grinding, milling, and drilling machines, to produce parts with tight tolerances and complex shapes.\n\n5. Looking for a CNC technician who can effectively handle the operation and maintenance of CNC equipment, including grinding, milling, and drilling machines, to achieve precise results and meet production targets.\n\n6. We are seeking a candidate with hands-on experience in operating CNC equipment, specializing in grinding, milling, and drilling machines, to contribute to the efficient production of high-precision components.\n\n7. Join our team as a CNC machine operator, utilizing your expertise in managing and running various CNC machines, such as grinding, milling, and drilling machines, to ensure optimal performance and productivity.\n\n8. Seeking an experienced individual capable of operating multiple types of CNC machines, including grinding, milling, and drilling machines, to support the manufacturing process and maintain consistent quality standards.\n\n9. We are looking for a skilled professional who can confidently operate CNC machinery, with a focus on grinding, milling, and drilling machines, and perform routine maintenance to ensure smooth operations and minimal downtime.\n\n10. Join our company as a CNC specialist, applying your knowledge and proficiency in operating CNC machines, including grinding, milling, and drilling machines, to meet production targets and uphold strict quality standards.',
#   'sentence_len': 408,
#   'skill_number': 3},
#  {'skills': "['tend CNC grinding machine', 'tend CNC milling machine', 'tend CNC drilling machine']",
#   'sentence': 'We are currently seeking a skilled machinist to join our team. As a machinist, you will be responsible for operating and maintaining various CNC machines, including grinding, milling, and drilling machines. Your expertise with these machines will ensure precise and accurate production of components. Additionally, you will need to possess a strong understanding of machine setup, tooling selection, and inspection techniques to ensure quality output. Your attention to detail, ability to troubleshoot and resolve issues, and commitment to safety will be vital in this role. If you have a proven track record of tending CNC grinding, milling, and drilling machines, we would love to hear from you. Apply now to join our team of skilled professionals.',
#   'sentence_len': 148,
#   'skill_number': 3},
#  {'skills': "['organise projects to fill education needs', 'provide learning support in healthcare']",
#   'sentence': 'We are seeking a dynamic Project Coordinator with a strong background in education and healthcare, who can effectively plan and manage projects to meet the educational needs of our diverse community, while also providing exceptional learning support within a healthcare environment.',
#   'sentence_len': 46,
#   'skill_number': 2},
#  {'skills': "['organise projects to fill education needs', 'provide learning support in healthcare']",
#   'sentence': 'We are seeking a dynamic and proactive individual to join our team as an Education Projects Coordinator. In this role, you will be responsible for organizing and managing projects to address the ever-evolving education needs of our organization. Your keen ability to anticipate and plan for these needs will be essential as you develop project timelines, coordinate resources, and ensure successful project delivery. Additionally, you will provide valuable learning support in the healthcare sector, working closely with healthcare professionals to develop and implement educational programs. The ideal candidate will have a strong background in project management, with a proven track record of successfully organizing projects to fill education needs. Previous experience in providing learning support in healthcare settings will be a significant advantage.',
#   'sentence_len': 143,
#   'skill_number': 2},
#  ...]

# %%
tech_emb_tax
# Out:
#                                         name+definition  \
# 0     Haskell : the techniques and principles of sof...
# 1     develop energy saving concepts : use current r...
# 2     conduct research on flora : collect and analys...
# 3     Incremental development : the incremental deve...
# 4     develop terminology databases : collect and su...
# ...                                                 ...
# 1789  perform nutrition analysis : determine and cal...
# 1790  analyse work-related written reports : read an...
# 1791  perform energy simulations : replicate the bui...
# 1792  Capture One : the computer program capture one...
# 1793  Scala : the techniques and principles of softw...
#
#                                       name  unique_id  \
# 0                                  Haskell       1000
# 1           develop energy saving concepts       1001
# 2                conduct research on flora       1002
# 3                  Incremental development       1003
# 4            develop terminology databases       1004
# ...                                    ...        ...
# 1789            perform nutrition analysis       2789
# 1790  analyse work-related written reports       2790
# 1791            perform energy simulations       2791
# 1792                           Capture One       2792
# 1793                                 Scala       2793
#
#                                              embeddings
# 0     [[tensor(0.9955, grad_fn=<UnbindBackward0>), t...
# 1     [[tensor(0.9279, grad_fn=<UnbindBackward0>), t...
# 2     [[tensor(1.4147, grad_fn=<UnbindBackward0>), t...
# 3     [[tensor(0.6862, grad_fn=<UnbindBackward0>), t...
# 4     [[tensor(0.5370, grad_fn=<UnbindBackward0>), t...
# ...                                                 ...
# 1789  [[tensor(1.2306, grad_fn=<UnbindBackward0>), t...
# 1790  [[tensor(0.6360, grad_fn=<UnbindBackward0>), t...
# 1791  [[tensor(0.4674, grad_fn=<UnbindBackward0>), t...
# 1792  [[tensor(1.0190, grad_fn=<UnbindBackward0>), t...
# 1793  [[tensor(0.8858, grad_fn=<UnbindBackward0>), t...
#
# [1794 rows x 4 columns]
