# %%
from dataset_evaluation import Predictor


predictor = Predictor(test_domain="SkillSpan-test",
                      train_domain="SkillSpan", ## no training will be used anyway
                      candidates_method="mixed")

ds = predictor.support_set
ds = ds[ds.spans.apply(len) > 0]
records = ds.head(5).to_dict("records")

# %%
records
# Out:
# [{'sentence': 'As the key link between our engineering and design teams, you will play a vital role in fostering seamless collaboration and effective communication, ensuring the successful integration and implementation of engineering principles into our innovative design solutions.',
#   'embeddings': tensor([[-8.7748e-02, -4.4046e-01, -6.3104e-01,  1.2028e+00,  1.0250e+00,
#            -7.0604e-01, -4.5214e-01,  3.5603e-01,  1.1087e-01, -9.7677e-02,
#             2.6844e-01, -2.5333e-01,  3.8253e-01, -2.1824e-01, -6.0960e-01,
#             5.9922e-01, -3.6927e-01, -5.3826e-01,  4.4903e-01,  1.6942e-01,
#            -8.1123e-01, -7.0206e-01, -6.7087e-01,  1.4744e+00,  1.0416e+00,
#            -1.0658e+00,  3.2663e-02,  1.1048e+00, -7.6053e-02,  1.0713e+00,
#            -3.5427e-01, -1.9056e-01, -2.6431e-01, -9.1619e-01,  1.7701e-02,
#            -7.1667e-01, -3.3366e-01,  1.6055e-01, -2.0255e-02,  1.2603e-01,
# ...

# %% [markdown]
# ### Dataset for Matching Part

# %%
train_ds = [
    predictor.prepare_support(record, nb_candidates=10).split("\nAnswer:")
    for record in records
]

# %%
for train_sample in train_ds:
    print("-"*150)
    print("Input : ")
    print(train_sample[0])
    print("Excepted output : ")
    print(train_sample[1])
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Input :
# Sentence: As the key link between our engineering and design teams, you will play a vital role in fostering seamless collaboration and effective communication, ensuring the successful integration and implementation of engineering principles into our innovative design solutions.
# Skill : fostering seamless collaboration and effective communication
# Options:
# A: collaborate with engineers
# B: establish collaborative relations : establish a connection between organisations or individuals which may benefit from communicating with one another in order to facilitate an enduring positive collaborative relationship between both parties.
# ...

# %% [markdown]
# ### Dataset for extraction part:

# %%
train_ds = [
    (record["sentence"], record["annotated_sentence"])    for record in records
]

for train_sample in train_ds:
    print("-"*150)
    print("Input : ")
    print(train_sample[0])
    print("Excepted output : ")
    print(train_sample[1])
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Input :
# As the key link between our engineering and design teams, you will play a vital role in fostering seamless collaboration and effective communication, ensuring the successful integration and implementation of engineering principles into our innovative design solutions.
# Excepted output :
# As the key link between our engineering and design teams, you will play a vital role in @@fostering seamless collaboration and effective communication##, @@collaborating with engineers## and designers, ensuring the successful integration and implementation of engineering principles into our innovative design solutions.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Input :
# ...
