# %%
import pandas as pd
from evaluate_src import *
import os

# %%
res_df = pd.DataFrame(columns=['path','seqeval_precision', 'seqeval_recall', 'seqeval_f1', 'skillevel_precision', 'skillevel_recall', 'skillevel_f1', 'filtered_skillevel_precision', 'filtered_skillevel_recall', 'filtered_skillevel_f1', 'filtered_seqeval_precision', 'filtered_seqeval_recall', 'filtered_seqeval_f1'])
for shots in [5]:
    for model in ['gpt-3.5-turbo']:
        for prompt_type in ['ner', 'extract']:
            for dataset_name in ['green', 'skillspan', 'fijo', 'sayfullina', 'kompetencer', 'gnehm']:
                save_path = 'output/' + dataset_name + '_' + model + '_' + prompt_type + '_' + str(shots) + '-shots_knn.json'
                if not os.path.exists(save_path):
                    continue
                all_metrics = eval(save_path)
                res_df = pd.concat([res_df, pd.DataFrame([{'path': save_path, **all_metrics}])], ignore_index=True)
# Out:
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.26356589147286824, 'seqeval_recall': 0.3434343434343434, 'seqeval_f1': 0.29824561403508776}
# skill_level_scores: {'skillevel_precision': 0.538, 'skillevel_recall': 0.443, 'skillevel_f1': 0.462}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.41975308641975306, 'filtered_seqeval_recall': 0.3434343434343434, 'filtered_seqeval_f1': 0.37777777777777777}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.923, 'filtered_skillevel_recall': 0.76, 'filtered_skillevel_f1': 0.792}
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.4583333333333333, 'seqeval_recall': 0.5238095238095238, 'seqeval_f1': 0.4888888888888889}
# skill_level_scores: {'skillevel_precision': 0.13, 'skillevel_recall': 0.133, 'skillevel_f1': 0.129}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.6875, 'filtered_seqeval_recall': 0.5238095238095238, 'filtered_seqeval_f1': 0.5945945945945946}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.65, 'filtered_skillevel_recall': 0.667, 'filtered_skillevel_f1': 0.647}
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# /tmp/ipykernel_3403759/3626410723.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df = pd.concat([res_df, pd.DataFrame([{'path': save_path, **all_metrics}])], ignore_index=True)
# seqeval_score: {'seqeval_precision': 0.4166666666666667, 'seqeval_recall': 0.391304347826087, 'seqeval_f1': 0.40358744394618834}
# skill_level_scores: {'skillevel_precision': 0.701, 'skillevel_recall': 0.645, 'skillevel_f1': 0.619}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.4326923076923077, 'filtered_seqeval_recall': 0.391304347826087, 'filtered_seqeval_f1': 0.41095890410958913}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.837, 'filtered_skillevel_recall': 0.771, 'filtered_skillevel_f1': 0.74}
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.24074074074074073, 'seqeval_recall': 0.2765957446808511, 'seqeval_f1': 0.25742574257425743}
# skill_level_scores: {'skillevel_precision': 0.383, 'skillevel_recall': 0.489, 'skillevel_f1': 0.415}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.24074074074074073, 'filtered_seqeval_recall': 0.2765957446808511, 'filtered_seqeval_f1': 0.25742574257425743}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.383, 'filtered_skillevel_recall': 0.489, 'filtered_skillevel_f1': 0.415}
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.15, 'seqeval_recall': 0.4, 'seqeval_f1': 0.21818181818181814}
# skill_level_scores: {'skillevel_precision': 0.059, 'skillevel_recall': 0.082, 'skillevel_f1': 0.066}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.5, 'filtered_seqeval_recall': 0.4, 'filtered_seqeval_f1': 0.4444444444444445}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.414, 'filtered_skillevel_recall': 0.571, 'filtered_skillevel_f1': 0.463}
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.3333333333333333, 'seqeval_recall': 0.6896551724137931, 'seqeval_f1': 0.449438202247191}
# skill_level_scores: {'skillevel_precision': 0.159, 'skillevel_recall': 0.166, 'skillevel_f1': 0.157}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.6451612903225806, 'filtered_seqeval_recall': 0.6896551724137931, 'filtered_seqeval_f1': 0.6666666666666667}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.78, 'filtered_skillevel_recall': 0.816, 'filtered_skillevel_f1': 0.768}

# %%
res_df
# Out:
#                                                 path  seqeval_precision  \
# 0    output/green_gpt-3.5-turbo_ner_5-shots_knn.json           0.263566
# 1  output/skillspan_gpt-3.5-turbo_ner_5-shots_knn...           0.458333
# 2     output/fijo_gpt-3.5-turbo_ner_5-shots_knn.json           0.416667
# 3  output/sayfullina_gpt-3.5-turbo_ner_5-shots_kn...           0.240741
# 4  output/kompetencer_gpt-3.5-turbo_ner_5-shots_k...           0.150000
# 5    output/gnehm_gpt-3.5-turbo_ner_5-shots_knn.json           0.333333
#
#    seqeval_recall  seqeval_f1  skillevel_precision  skillevel_recall  \
# 0        0.343434    0.298246                0.538             0.443
# 1        0.523810    0.488889                0.130             0.133
# 2        0.391304    0.403587                0.701             0.645
# 3        0.276596    0.257426                0.383             0.489
# 4        0.400000    0.218182                0.059             0.082
# 5        0.689655    0.449438                0.159             0.166
#
#    skillevel_f1  filtered_skillevel_precision  filtered_skillevel_recall  \
# 0         0.462                         0.923                      0.760
# 1         0.129                         0.650                      0.667
# 2         0.619                         0.837                      0.771
# 3         0.415                         0.383                      0.489
# 4         0.066                         0.414                      0.571
# 5         0.157                         0.780                      0.816
#
#    filtered_skillevel_f1  filtered_seqeval_precision  filtered_seqeval_recall  \
# 0                  0.792                    0.419753                 0.343434
# 1                  0.647                    0.687500                 0.523810
# 2                  0.740                    0.432692                 0.391304
# 3                  0.415                    0.240741                 0.276596
# 4                  0.463                    0.500000                 0.400000
# 5                  0.768                    0.645161                 0.689655
#
#    filtered_seqeval_f1
# 0             0.377778
# 1             0.594595
# 2             0.410959
# 3             0.257426
# 4             0.444444
# 5             0.666667

# %%
res_df
# Out:
# Empty DataFrame
# Columns: [path, seqeval_precision, seqeval_recall, seqeval_f1, skillevel_precision, skillevel_recall, skillevel_f1, filtered_skillevel_precision, filtered_skillevel_recall, filtered_skillevel_f1, filtered_seqeval_precision, filtered_seqeval_recall, filtered_seqeval_f1]
# Index: []
