# %%
import pandas as pd
from evaluate_src import *
import os

# %%
res_df = pd.DataFrame(columns=['path','seqeval_precision', 'seqeval_recall', 'seqeval_f1', 'skillevel_precision', 'skillevel_recall', 'skillevel_f1', 'filtered_skillevel_precision', 'filtered_skillevel_recall', 'filtered_skillevel_f1', 'filtered_seqeval_precision', 'filtered_seqeval_recall', 'filtered_seqeval_f1'])
for shots in [4]:
    for model in ['gpt-3.5-turbo']:
        for prompt_type in ['ner', 'extract']:
            for dataset_name in ['green', 'skillspan', 'fijo', 'sayfullina', 'kompetencer', 'gnehm']:
                save_path = 'output/' + dataset_name + '_' + model + '_' + prompt_type + '_' + str(shots) + '-shots_knn.json'
                if not os.path.exists(save_path):
                    continue
                all_metrics = eval(save_path)
                res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)
# Out:
# Removing examples where the number of spans and the number of predictions don't match: 2
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.3360655737704918, 'seqeval_recall': 0.22043010752688172, 'seqeval_f1': 0.2662337662337662}
# skill_level_scores: {'skillevel_precision': 0.487, 'skillevel_recall': 0.357, 'skillevel_f1': 0.374}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.3867924528301887, 'filtered_seqeval_recall': 0.22043010752688172, 'filtered_seqeval_f1': 0.28082191780821913}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.78, 'filtered_skillevel_recall': 0.571, 'filtered_skillevel_f1': 0.599}
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.11764705882352941, 'seqeval_recall': 0.43478260869565216, 'seqeval_f1': 0.1851851851851852}
# skill_level_scores: {'skillevel_precision': 0.091, 'skillevel_recall': 0.093, 'skillevel_f1': 0.09}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.5263157894736842, 'filtered_seqeval_recall': 0.43478260869565216, 'filtered_seqeval_f1': 0.47619047619047616}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.681, 'filtered_skillevel_recall': 0.694, 'filtered_skillevel_f1': 0.672}
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.4, 'seqeval_recall': 0.2857142857142857, 'seqeval_f1': 0.3333333333333333}
# skill_level_scores: {'skillevel_precision': 0.354, 'skillevel_recall': 0.289, 'skillevel_f1': 0.282}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.5, 'filtered_seqeval_recall': 0.2857142857142857, 'filtered_seqeval_f1': 0.36363636363636365}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.532, 'filtered_skillevel_recall': 0.433, 'filtered_skillevel_f1': 0.423}
# Removing examples where the number of spans and the number of predictions don't match: 1
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.23577235772357724, 'seqeval_recall': 0.3020833333333333, 'seqeval_f1': 0.2648401826484018}
# skill_level_scores: {'skillevel_precision': 0.361, 'skillevel_recall': 0.521, 'skillevel_f1': 0.408}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.23577235772357724, 'filtered_seqeval_recall': 0.3020833333333333, 'filtered_seqeval_f1': 0.2648401826484018}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.361, 'filtered_skillevel_recall': 0.521, 'filtered_skillevel_f1': 0.408}
# Removing examples where the number of spans and the number of predictions don't match: 8
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.14035087719298245, 'seqeval_recall': 0.5714285714285714, 'seqeval_f1': 0.22535211267605634}
# skill_level_scores: {'skillevel_precision': 0.078, 'skillevel_recall': 0.096, 'skillevel_f1': 0.084}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.42105263157894735, 'filtered_seqeval_recall': 0.5714285714285714, 'filtered_seqeval_f1': 0.48484848484848486}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.758, 'filtered_skillevel_recall': 0.938, 'filtered_skillevel_f1': 0.817}
# Removing examples where the number of spans and the number of predictions don't match: 1
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.40384615384615385, 'seqeval_recall': 0.5526315789473685, 'seqeval_f1': 0.46666666666666673}
# skill_level_scores: {'skillevel_precision': 0.096, 'skillevel_recall': 0.093, 'skillevel_f1': 0.092}
# filtered avg:
# /tmp/ipykernel_150967/2207964275.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)
# /tmp/ipykernel_150967/2207964275.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)
# /tmp/ipykernel_150967/2207964275.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)
# /tmp/ipykernel_150967/2207964275.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)
# /tmp/ipykernel_150967/2207964275.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)
# /tmp/ipykernel_150967/2207964275.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.65625, 'filtered_seqeval_recall': 0.5526315789473685, 'filtered_seqeval_f1': 0.6}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.506, 'filtered_skillevel_recall': 0.491, 'filtered_skillevel_f1': 0.484}
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.30246913580246915, 'seqeval_recall': 0.3202614379084967, 'seqeval_f1': 0.3111111111111111}
# skill_level_scores: {'skillevel_precision': 0.499, 'skillevel_recall': 0.434, 'skillevel_f1': 0.437}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.3888888888888889, 'filtered_seqeval_recall': 0.3202614379084967, 'filtered_seqeval_f1': 0.3512544802867384}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.815, 'filtered_skillevel_recall': 0.708, 'filtered_skillevel_f1': 0.713}
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.171875, 'seqeval_recall': 0.4583333333333333, 'seqeval_f1': 0.25}
# skill_level_scores: {'skillevel_precision': 0.076, 'skillevel_recall': 0.083, 'skillevel_f1': 0.077}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.6470588235294118, 'filtered_seqeval_recall': 0.4583333333333333, 'filtered_seqeval_f1': 0.5365853658536585}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.659, 'filtered_skillevel_recall': 0.727, 'filtered_skillevel_f1': 0.673}
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.32116788321167883, 'seqeval_recall': 0.3893805309734513, 'seqeval_f1': 0.352}
# skill_level_scores: {'skillevel_precision': 0.633, 'skillevel_recall': 0.738, 'skillevel_f1': 0.651}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.34375, 'filtered_seqeval_recall': 0.3893805309734513, 'filtered_seqeval_f1': 0.3651452282157676}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.766, 'filtered_skillevel_recall': 0.893, 'filtered_skillevel_f1': 0.788}
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.27722772277227725, 'seqeval_recall': 0.28865979381443296, 'seqeval_f1': 0.2828282828282828}
# skill_level_scores: {'skillevel_precision': 0.365, 'skillevel_recall': 0.485, 'skillevel_f1': 0.397}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.27722772277227725, 'filtered_seqeval_recall': 0.28865979381443296, 'filtered_seqeval_f1': 0.2828282828282828}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.365, 'filtered_skillevel_recall': 0.485, 'filtered_skillevel_f1': 0.397}
# Removing examples where the number of spans and the number of predictions don't match: 0
# /tmp/ipykernel_150967/2207964275.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)
# /tmp/ipykernel_150967/2207964275.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)
# /tmp/ipykernel_150967/2207964275.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)
# /tmp/ipykernel_150967/2207964275.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)
# /tmp/ipykernel_150967/2207964275.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.13978494623655913, 'seqeval_recall': 0.35135135135135137, 'seqeval_f1': 0.2}
# skill_level_scores: {'skillevel_precision': 0.091, 'skillevel_recall': 0.127, 'skillevel_f1': 0.102}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.28888888888888886, 'filtered_seqeval_recall': 0.35135135135135137, 'filtered_seqeval_f1': 0.31707317073170727}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.603, 'filtered_skillevel_recall': 0.841, 'filtered_skillevel_f1': 0.679}
# Removing examples where the number of spans and the number of predictions don't match: 0
# non-filtered avg:
# seqeval_score: {'seqeval_precision': 0.3333333333333333, 'seqeval_recall': 0.6842105263157895, 'seqeval_f1': 0.44827586206896547}
# skill_level_scores: {'skillevel_precision': 0.096, 'skillevel_recall': 0.132, 'skillevel_f1': 0.105}
# filtered avg:
# seqeval_score_filtered: {'filtered_seqeval_precision': 0.4482758620689655, 'filtered_seqeval_recall': 0.6842105263157895, 'filtered_seqeval_f1': 0.5416666666666666}
# skill_level_scores_filtered: {'filtered_skillevel_precision': 0.511, 'filtered_skillevel_recall': 0.702, 'filtered_skillevel_f1': 0.558}
# /tmp/ipykernel_150967/2207964275.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res_df = res_df.append({'path': save_path, **all_metrics}, ignore_index=True)

# %%
res_df
# Out:
#                                                  path  seqeval_precision  \
# 0     output/green_gpt-3.5-turbo_ner_4-shots_knn.json           0.336066
# 1   output/skillspan_gpt-3.5-turbo_ner_4-shots_knn...           0.117647
# 2      output/fijo_gpt-3.5-turbo_ner_4-shots_knn.json           0.400000
# 3   output/sayfullina_gpt-3.5-turbo_ner_4-shots_kn...           0.235772
# 4   output/kompetencer_gpt-3.5-turbo_ner_4-shots_k...           0.140351
# 5     output/gnehm_gpt-3.5-turbo_ner_4-shots_knn.json           0.403846
# 6   output/green_gpt-3.5-turbo_extract_4-shots_knn...           0.302469
# 7   output/skillspan_gpt-3.5-turbo_extract_4-shots...           0.171875
# 8   output/fijo_gpt-3.5-turbo_extract_4-shots_knn....           0.321168
# 9   output/sayfullina_gpt-3.5-turbo_extract_4-shot...           0.277228
# 10  output/kompetencer_gpt-3.5-turbo_extract_4-sho...           0.139785
# 11  output/gnehm_gpt-3.5-turbo_extract_4-shots_knn...           0.333333
#
#     seqeval_recall  seqeval_f1  skillevel_precision  skillevel_recall  \
# 0         0.220430    0.266234                0.487             0.357
# 1         0.434783    0.185185                0.091             0.093
# 2         0.285714    0.333333                0.354             0.289
# 3         0.302083    0.264840                0.361             0.521
# 4         0.571429    0.225352                0.078             0.096
# 5         0.552632    0.466667                0.096             0.093
# 6         0.320261    0.311111                0.499             0.434
# 7         0.458333    0.250000                0.076             0.083
# 8         0.389381    0.352000                0.633             0.738
# 9         0.288660    0.282828                0.365             0.485
# 10        0.351351    0.200000                0.091             0.127
# 11        0.684211    0.448276                0.096             0.132
#
#     skillevel_f1  filtered_skillevel_precision  filtered_skillevel_recall  \
# 0          0.374                         0.780                      0.571
# 1          0.090                         0.681                      0.694
# 2          0.282                         0.532                      0.433
# 3          0.408                         0.361                      0.521
# 4          0.084                         0.758                      0.938
# 5          0.092                         0.506                      0.491
# 6          0.437                         0.815                      0.708
# 7          0.077                         0.659                      0.727
# 8          0.651                         0.766                      0.893
# 9          0.397                         0.365                      0.485
# 10         0.102                         0.603                      0.841
# 11         0.105                         0.511                      0.702
#
#     filtered_skillevel_f1  filtered_seqeval_precision  \
# 0                   0.599                    0.386792
# 1                   0.672                    0.526316
# 2                   0.423                    0.500000
# 3                   0.408                    0.235772
# 4                   0.817                    0.421053
# 5                   0.484                    0.656250
# 6                   0.713                    0.388889
# 7                   0.673                    0.647059
# 8                   0.788                    0.343750
# 9                   0.397                    0.277228
# 10                  0.679                    0.288889
# 11                  0.558                    0.448276
#
#     filtered_seqeval_recall  filtered_seqeval_f1
# 0                  0.220430             0.280822
# 1                  0.434783             0.476190
# 2                  0.285714             0.363636
# 3                  0.302083             0.264840
# 4                  0.571429             0.484848
# 5                  0.552632             0.600000
# 6                  0.320261             0.351254
# 7                  0.458333             0.536585
# 8                  0.389381             0.365145
# 9                  0.288660             0.282828
# 10                 0.351351             0.317073
# 11                 0.684211             0.541667

# %%
res_df
# Out:
#                                                 path  precision  recall  \
# 0        output/gnehm_gpt-3.5-turbo_ner_4-shots.json      0.010   0.010
# 1        output/green_gpt-3.5-turbo_ner_4-shots.json      0.197   0.191
# 2    output/skillspan_gpt-3.5-turbo_ner_4-shots.json      0.000   0.000
# 3   output/sayfullina_gpt-3.5-turbo_ner_4-shots.json      0.137   0.220
# 4  output/kompetencer_gpt-3.5-turbo_ner_4-shots.json      0.015   0.013
# 5    output/gnehm_gpt-3.5-turbo_extract_4-shots.json      0.066   0.074
# 6    output/green_gpt-3.5-turbo_extract_4-shots.json      0.116   0.180
# 7  output/skillspan_gpt-3.5-turbo_extract_4-shots...      0.037   0.035
# 8  output/sayfullina_gpt-3.5-turbo_extract_4-shot...      0.117   0.270
# 9  output/kompetencer_gpt-3.5-turbo_extract_4-sho...      0.020   0.023
#
#       f1 skill_level_accuracy  filtered_precision  filtered_recall  \
# 0  0.010                 None               0.050            0.050
# 1  0.184                 None               0.307            0.298
# 2  0.000                 None               0.000            0.000
# 3  0.160                 None               0.137            0.220
# 4  0.014                 None               0.100            0.089
# 5  0.063                 None               0.332            0.371
# 6  0.124                 None               0.181            0.281
# 7  0.035                 None               0.262            0.250
# 8  0.156                 None               0.117            0.270
# 9  0.020                 None               0.132            0.154
#
#    filtered_f1  filtered_skill_level_accuracy
# 0        0.050                          0.193
# 1        0.288                          0.579
# 2        0.000                          0.143
# 3        0.160                          0.390
# 4        0.093                          0.278
# 5        0.315                          0.593
# 6        0.194                          0.798
# 7        0.248                          0.821
# 8        0.156                          0.540
# 9        0.135                          0.685
